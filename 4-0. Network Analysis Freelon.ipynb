# %%
#Import modules
# %matplotlib inline

#handling data
import pandas as pd
import numpy as np
from scipy import stats
from operator import itemgetter

#handling information
import re
import json

#handling plots
import matplotlib.pyplot as plt
import seaborn as sns

#for network creation
import networkx as nx
import tsm
import collections
import community
import copy
import csv
import networkx as nx
import operator
import random
import re

# %%
# Read json into a pandas dataframe
tweets_df = pd.read_csv("data/processed/tweets_08010807_notverified.csv")
# Out:
# /Users/yuikondo/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (0,8,9,12,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
tweets_df.columns
# Out:
# Index(['Unnamed: 0', 'tweet_id', 'conversation_id', 'created_at', 'text',
#        'retweet_count', 'reply_count', 'like_count', 'quote_count', 'user_id',
#        'username', 'user_full_name', 'user_following', 'user_followers',
#        'user_bio', 'in_reply_to_user_id', 'in_reply_to_username',
#        'in_reply_to_user_full_name', 'in_reply_to_user_following',
#        'in_reply_to_user_followers', 'in_reply_to_user_bio',
#        'referenced_user_id', 'referenced_username',
#        'referenced_user_full_name', 'referenced_user_following',
#        'referenced_user_followers', 'referenced_user_bio',
#        'referenced_tweet_id', 'referenced_tweet_type', 'referenced_tweet_text',
#        'referenced_tweet_created_at', 'referenced_tweet_author_id',
#        'referenced_tweet_conversation_id'],
#       dtype='object')

# %%
# dataを抽出
tweets_final = tweets_df[["username",'text','created_at']]

# %%
tweets_final
tweets_final.to_csv("data/processed/tweets_08010807_notverified_freelon.csv")
# Out:
#               username                                               text  \
# 0              atm09rs  RT @5sasha5sasha5: 旧統一教会と政治の関係　塚田穂高氏「国会で検証し国民に...
# 1               ipppen  RT @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教...
# 2        bessei_family  選択的夫婦別姓制度は、全ての人に夫婦別姓を求めるものではありません。夫婦別姓を求める夫婦には...
# 3            hiro_npwr  RT @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教...
# 4           subaru1000  @sabutibi777 よくある、「俺の周りで、夫婦別姓に賛成してる奴なんか見たことない」...
# ...                ...                                                ...
# 19829       nauciccafe  「選択的夫婦別姓」にすると「家庭が崩壊」するから反対という山谷は、「統一教会への献金」で貧困...
# 19830  fCjZwp9AOoqmQbL  RT @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」...
# 19831            tcy79  RT @hotaka_tsukada: 山谷先生、一年生議員の時から、統一教会系『世界日報』...
# 19832          TannyE7  RT @futaba28281: @mainichi どう考えてもどっぷり洗脳されてるよ。夫...
# 19833          aka6446  RT @hotaka_tsukada: 山谷先生、一年生議員の時から、統一教会系『世界日報』...
#
#                      created_at
# 0      2022-08-02T10:53:43.000Z
# 1      2022-08-02T10:53:20.000Z
# 2      2022-08-02T10:53:16.000Z
# 3      2022-08-02T10:53:09.000Z
# 4      2022-08-02T10:52:47.000Z
# ...                         ...
# 19829  2022-08-03T14:39:39.000Z
# 19830  2022-08-03T14:39:07.000Z
# 19831  2022-08-03T14:38:37.000Z
# 19832  2022-08-03T14:38:05.000Z
# 19833  2022-08-03T14:37:59.000Z
#
# [19834 rows x 3 columns]

# %%
tweet_data = 'data/processed/tweets_08010807_notverified_freelon.csv'
# top_communities = tsm.get_top_communities(edgelist)
# ei_indices_A = tsm.calc_ei(top_communities_A.node_list,edgelist_A,'ON')
# ei_indices_B = tsm.calc_ei(top_communities_B.node_list,edgelist_B,'ON')
# top_rts_A = tsm.get_top_rts(tweet_file_A,top_communities_A.node_list)
# top_rts_B = tsm.get_top_rts(tweet_file_B,top_communities_B.node_list)
# community_matches = tsm.match_communities(top_communities_A.node_list,top_communities_B.node_list)
# intermediaries_A = tsm.get_intermediaries(top_communities_A.node_list,edgelist_A)
# intermediaries_B = tsm.get_intermediaries(top_communities_B.node_list,edgelist_B)
# top_hashtags_A = tsm.get_top_hashtags(tweet_file_A,top_communities_A.node_list)
# top_hashtags_B = tsm.get_top_hashtags(tweet_file_B,top_communities_B.node_list)
# top_links_A = tsm.get_top_links(tweet_file_A,top_communities_A.node_list)
# top_links_B = tsm.get_top_links(tweet_file_B,top_communities_B.node_list)
# grid_A = tsm.shared_ties_grid(ei_indices_A,calc_propor=True)
# grid_B = tsm.shared_ties_grid(ei_indices_B,calc_propor=True)

# print("Now feel free to inspect the variables...")

# %%
tweet_data
# Out:
# 'data/processed/tweets_08010807_notverified_freelon.csv'

# %%
tweets_final
# Out:
#               username                                               text  \
# 0              atm09rs  RT @5sasha5sasha5: 旧統一教会と政治の関係　塚田穂高氏「国会で検証し国民に...
# 1               ipppen  RT @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教...
# 2        bessei_family  選択的夫婦別姓制度は、全ての人に夫婦別姓を求めるものではありません。夫婦別姓を求める夫婦には...
# 3            hiro_npwr  RT @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教...
# 4           subaru1000  @sabutibi777 よくある、「俺の周りで、夫婦別姓に賛成してる奴なんか見たことない」...
# ...                ...                                                ...
# 19829       nauciccafe  「選択的夫婦別姓」にすると「家庭が崩壊」するから反対という山谷は、「統一教会への献金」で貧困...
# 19830  fCjZwp9AOoqmQbL  RT @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」...
# 19831            tcy79  RT @hotaka_tsukada: 山谷先生、一年生議員の時から、統一教会系『世界日報』...
# 19832          TannyE7  RT @futaba28281: @mainichi どう考えてもどっぷり洗脳されてるよ。夫...
# 19833          aka6446  RT @hotaka_tsukada: 山谷先生、一年生議員の時から、統一教会系『世界日報』...
#
#                      created_at
# 0      2022-08-02T10:53:43.000Z
# 1      2022-08-02T10:53:20.000Z
# 2      2022-08-02T10:53:16.000Z
# 3      2022-08-02T10:53:09.000Z
# 4      2022-08-02T10:52:47.000Z
# ...                         ...
# 19829  2022-08-03T14:39:39.000Z
# 19830  2022-08-03T14:39:07.000Z
# 19831  2022-08-03T14:38:37.000Z
# 19832  2022-08-03T14:38:05.000Z
# 19833  2022-08-03T14:37:59.000Z
#
# [19834 rows x 3 columns]

# %%
f = open('data/processed/tweets_08010807_notverified_freelon.csv','r',encoding = 'utf-8',errors = 'replace')

# %%
csvreader = csv.reader(f)
# tweet_data = csv.reader(f)
# tweet_data

# %%
authors = []
tweets = []
for row in csvreader:
      authors.append(re.sub('[^A-Za-z0-9_]','',str(row[1]).lower().strip()))
      tweets.append(' ' + row[2].lower() + ' ')
authors
tweets
# Out:
# [' text ',
#  ' rt @5sasha5sasha5: 旧統一教会と政治の関係\u3000塚田穂高氏「国会で検証し国民に明示を」 | 毎日新聞 https://t.co/2zfggmnhdx 「夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新… ',
#  ' rt @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな『共産主義』的価値観として敵視するように」→\nhttps://t.co/4aaif6… ',
#  ' 選択的夫婦別姓制度は、全ての人に夫婦別姓を求めるものではありません。夫婦別姓を求める夫婦にはそれぞれの環境や立場、考え方があって夫婦別姓を選択するものです。\n#選択的夫婦別姓\u3000#夫婦別姓 ',
#  ' rt @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな『共産主義』的価値観として敵視するように」→\nhttps://t.co/4aaif6… ',
#  ' @sabutibi777 よくある、「俺の周りで、夫婦別姓に賛成してる奴なんか見たことない」ってやつと似てますね。そりゃ、あんたには言わないでしょうよ、っていう… ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @hosakanobuto: 問題は、統一教会側の政界工作の対象となって、支援を受けてきた国会議員が、自らの政策判断や主張を同調させて政治的に増幅する役割を果たしたのではないかという疑問だ。「選択的夫婦別姓」「ジェンダーフリー」「同性カップル」「性教育」等を敵視して動き、… ',
#  ' rt @aiko33151709: ネット上では流布していたカルト統一教会と自民党との密接な関係が今回公衆の前に明らかにされた。夫婦別姓反対、同性婚反対、lgbt反対、家庭中心主義等の自民党の政策は統一教会の教義と同一なのが判明。自民は選挙協力欲しさに彼らの特異な教義を自民の政… ',
#  ' rt @2kuow: 「選択的夫婦別姓の子供の姓」について統一することが出来てませんよね？\n\n現行法維持派は事実婚を否定してないので、二つ目は間違えてますよ。\n\n他人の思想をカルトと認定するのは失礼極まりないですね。 ',
#  ' rt @sollevante2022: 表だって選択的夫婦別姓に反対している団体なんて\n神道政治連盟と幸福の科学、日本会議、\nそして統一教会くらいですね。\n\nほかにはもうないんじゃないかねえ。 ',
#  ' rt @sollevante2022: 表だって選択的夫婦別姓に反対している団体なんて\n神道政治連盟と幸福の科学、日本会議、\nそして統一教会くらいですね。\n\nほかにはもうないんじゃないかねえ。 ',
#  ' 日本で頑なに同性婚と夫婦別姓が認められないのってマジでそういう事だったん？ [ [928380653] https://t.co/wlekquupoo ',
#  ' rt @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな『共産主義』的価値観として敵視するように」→\nhttps://t.co/4aaif6… ',
#  ' rt @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな『共産主義』的価値観として敵視するように」→\nhttps://t.co/4aaif6… ',
#  ' 夫婦別姓も国会で議題になっているが、無能な警察官や軍人どもは、姓を廃止して畑や田んぼに縛り付けておけばいい。日本は無能な役人を大量に抱えており、彼らから刀を取り上げて鍬や鋤や鎌を与えて、百姓にさせて食料自給率を高めるべきだ。こういう連中には悪知恵を付けるだけの学問は不要だ。 ',
#  ' rt @kakitama: もう２０年越しの、「男女共同参画の弱体化」「反ジェンダーフリー(平等)・選択的夫婦別姓」「反lgbt・同性婚」は今に続く”見える成果”です。直近でも子ども庁→子ども家庭庁での山谷えり子議員、更に参院選での井上義行議員の「同性愛差別発言・統一教会の選挙… ',
#  ' rt @aiko33151709: ネット上では流布していたカルト統一教会と自民党との密接な関係が今回公衆の前に明らかにされた。夫婦別姓反対、同性婚反対、lgbt反対、家庭中心主義等の自民党の政策は統一教会の教義と同一なのが判明。自民は選挙協力欲しさに彼らの特異な教義を自民の政… ',
#  ' rt @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな『共産主義』的価値観として敵視するように」→\nhttps://t.co/4aaif6… ',
#  ' rt @kenkenrokujapan: 選択的夫婦別姓の活動の最終目標は「戸籍制度の改定」だそうです。\n\n選択的夫婦別姓の実現はその第一歩。\n\nまさに蟻の一穴。\n\n彼らが選択的夫婦別姓は何も問題ないと叫び続けるのは、この計画を進めるためなのでしょう。\n\n#選択的夫婦別姓 #自… ',
#  ' rt @gun81288955: つか⬇️まず招待状に #選択的夫婦別姓\u3000講演有りと告知しなよ…知らずに来て聞かされる反対の人はムカつくわ🗯 自分が招待された式で…選択的夫婦別姓反対講演あったら⁇ よく考えろって😮\u200d💨👎\nつか金取るの⁇ 儲け口だから賛同者にアピってんの🤢⁇\n#… ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @edokaiki: 中国や朝鮮は夫婦別姓であり、子供は否応なく夫である父親の姓に入る。つまり妻である母親は「家系には入れない」「（父方の姓を名乗ることになる）子供を生むだけ」という女性へのトンでもない差別的な制度が（中国・朝鮮方式の）夫婦別姓なのである。 ',
#  ' rt @nemuribi: 私は選択的夫婦別姓に賛成していますし、ありもしない伝統を振り翳して差別や不備を煽動・放置する流れにも反対ですが、「低レベルなものは宗教のせい」と定義も曖昧なままに関係のないものをマイナス要素に紐付けし、一纏めに見下す言動は非常に差別的だと感じます。撤… ',
#  ' rt @sollevante2022: 表だって選択的夫婦別姓に反対している団体なんて\n神道政治連盟と幸福の科学、日本会議、\nそして統一教会くらいですね。\n\nほかにはもうないんじゃないかねえ。 ',
#  ' rt @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな『共産主義』的価値観として敵視するように」→\nhttps://t.co/4aaif6… ',
#  ' rt @2kuow: 「選択的夫婦別姓の子供の姓」について統一することが出来てませんよね？\n\n現行法維持派は事実婚を否定してないので、二つ目は間違えてますよ。\n\n他人の思想をカルトと認定するのは失礼極まりないですね。 ',
#  ' rt @kenkenrokujapan: 選択的夫婦別姓の活動の最終目標は「戸籍制度の改定」だそうです。\n\n選択的夫婦別姓の実現はその第一歩。\n\nまさに蟻の一穴。\n\n彼らが選択的夫婦別姓は何も問題ないと叫び続けるのは、この計画を進めるためなのでしょう。\n\n#選択的夫婦別姓 #自… ',
#  ' @chiakitokai @matsukawa_rui 田中均を尊敬している時点でアウト❗\n夫婦別姓賛成で安倍総理のお通夜か葬儀だったか自撮りしてたらしいですね。野田聖子の類ぽい。 ',
#  ' rt @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな『共産主義』的価値観として敵視するように」→\nhttps://t.co/4aaif6… ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな『共産主義』的価値観として敵視するように」→\nhttps://t.co/4aaif6… ',
#  ' rt @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな『共産主義』的価値観として敵視するように」→\nhttps://t.co/4aaif6… ',
#  ' 夫婦別姓に文句を言う人は、女性が運動靴をはきたいと言っても文句を言うし、女性が化粧をやめたいと言っても文句を言うし、女性が毛を剃るのをやめたいと言っても文句を言うし、女性が服にポケットつけてほしいと言っても文句を言う。とにかく女性が何か意見を言うのがものすごく嫌みたい。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @aiko33151709: ネット上では流布していたカルト統一教会と自民党との密接な関係が今回公衆の前に明らかにされた。夫婦別姓反対、同性婚反対、lgbt反対、家庭中心主義等の自民党の政策は統一教会の教義と同一なのが判明。自民は選挙協力欲しさに彼らの特異な教義を自民の政… ',
#  ' @cafelattenaruto @ts80115785 @sabutibi777 防御策が必要かは僕は分からないですけど、少なくともあなたの知人のケースでは、夫婦別姓の導入で何か変わるということはないですね。\n現行法で目的達成できちゃいますから。 ',
#  ' rt @aiko33151709: ネット上では流布していたカルト統一教会と自民党との密接な関係が今回公衆の前に明らかにされた。夫婦別姓反対、同性婚反対、lgbt反対、家庭中心主義等の自民党の政策は統一教会の教義と同一なのが判明。自民は選挙協力欲しさに彼らの特異な教義を自民の政… ',
#  ' rt @hasegawakenjiro: ポリタスtvのおかげで山口さんの指摘が理解できる。\n\n特に憲法24条の改憲案は、夫婦別姓、同性婚、ジェンダーフリーを阻止する基礎になる。\n\n家父長制度の復活をめざす\n旧統一教会、\n日本政策研究センター、\n日本会議、\nの価値観がほぼ同じ。… ',
#  ' rt @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな『共産主義』的価値観として敵視するように」→\nhttps://t.co/4aaif6… ',
#  ' rt @nana77rey1: 人生初のご依頼\n「結婚式で選択的夫婦別姓の講演」😃\n\n2人の新しい門出の日💐\nお互いの氏名を尊重したくて婚姻届が出せない理由もまた、大切な人たちに理解してもらえたら…と新婦さん。\n\n今の法律のことまったく知らないご親族やご友人もいるよね。堅苦しく… ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' @sen_yuui 夫婦別姓…w\nうちも複雑な関係になったよww ',
#  ' 「宗教団体の言説に詳しい評論家の古谷経衡氏は『日本会議や神社本庁などの《宗教右派団体》は、自民草案に一定の影響を与えてきた。旧統一教会とも共通するのは、復古的な家族観、夫婦別姓反対などだ。そうした《雑念》が自民草案には入っているといえる』と説く」https://t.co/eectfonztt ',
#  ' @tayosei_hosetsu 夫婦別姓を唱えるなら通名を禁止しようよ\n\n帰化人なら帰化前の外国名で暮らせばいい\n\nアイデンティティを大切にしたいなら\n\n偽名でなく本名で生活して貰おう\n\nそしたら日本人に成りすましながら反日活動できない\n\n特に顔で見分けが付かない中韓\n\n中国系、韓国系として堂々と生きたらいい\n\nこれぞ多様性 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @kenkenrokujapan: 選択的夫婦別姓の活動の最終目標は「戸籍制度の改定」だそうです。\n\n選択的夫婦別姓の実現はその第一歩。\n\nまさに蟻の一穴。\n\n彼らが選択的夫婦別姓は何も問題ないと叫び続けるのは、この計画を進めるためなのでしょう。\n\n#選択的夫婦別姓 #自… ',
#  ' その通りだな。\n夫婦別姓も可能になった上で。 https://t.co/umsv4119dm ',
#  ' rt @akikuri: @onoderamasaru @sankei_news 夫婦別姓はその国の社会を分断させる事を目的とした政治的工作ツールの一つ。その発祥は戦前のマルクス主義フランクフルト学派達。(米国に亡命後大学で教鞭、後のblm運動家の師匠筋に)\nターゲットの国をこ… ',
#  ' rt @bululunwagtail: 男女同権を認めているのだから、夫婦別姓にしなければならない理由とは何なのか？\n何か夫婦別姓にすることで社会的に都合が良いことでもあるのか？ https://t.co/1mdfmfkzn3 ',
#  ' @ayaka_catlove ねぇねww\nうち、夫婦別姓なのかもしれんww ',
#  ' rt @kenkenrokujapan: 選択的夫婦別姓の活動の最終目標は「戸籍制度の改定」だそうです。\n\n選択的夫婦別姓の実現はその第一歩。\n\nまさに蟻の一穴。\n\n彼らが選択的夫婦別姓は何も問題ないと叫び続けるのは、この計画を進めるためなのでしょう。\n\n#選択的夫婦別姓 #自… ',
#  ' @tayosei_hosetsu 夫婦別姓にしたいなら事実婚でok\n\n事実婚契約書という公的証明を作れば\n\n正式婚と同じ権利が得られる\n\n遺産も入院手続きも可能\n\n住民票には未届配偶者と記載されて証明も可能\n\n正式婚との違いは戸籍に載るか載らないかだけ\n\n戸籍法を変える事ばかり布教せず,事実婚普及すべき\nhttps://t.co/do8mkgmsoe ',
#  ' @rockhearts737 「小さな改修」って、私が言ったっけ？\n\n比較した場合、戸籍だけでなく社会全体のシステムと連携を考えると、旧姓の通称使用拡大よりも、選択的夫婦別姓の方が合理的。(という主張はしてる)\n\n大元が戸籍姓を本名として出せば、周辺システムは今までと同じ連携。 ',
#  ' rt @hakofugu_net: 【寄稿】「選択的夫婦別姓」の導入は、日本社会の綻びを広げ、やがて解体していく岐路である \nhttps://t.co/lazqoktmtn ',
#  ' rt @edokaiki: 中国や朝鮮は夫婦別姓であり、子供は否応なく夫である父親の姓に入る。つまり妻である母親は「家系には入れない」「（父方の姓を名乗ることになる）子供を生むだけ」という女性へのトンでもない差別的な制度が（中国・朝鮮方式の）夫婦別姓なのである。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @vnrespectfn: 96年答申案で\n唯一まだ改正されてないのが\n選択的夫婦別姓。\n一人歩きさせたら危険なら\nさっさと改正だろ。 ',
#  ' rt @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな『共産主義』的価値観として敵視するように」→\nhttps://t.co/4aaif6… ',
#  ' rt @kenkenrokujapan: 選択的夫婦別姓の活動の最終目標は「戸籍制度の改定」だそうです。\n\n選択的夫婦別姓の実現はその第一歩。\n\nまさに蟻の一穴。\n\n彼らが選択的夫婦別姓は何も問題ないと叫び続けるのは、この計画を進めるためなのでしょう。\n\n#選択的夫婦別姓 #自… ',
#  ' rt @seiryukai: 選択的夫婦別姓 反対twitter演説会のショートムービーです。\n演説会動画は完成しだいyoutubeにアップし皆さんにお知らせいたします。\n皆さんの力を結集して夫婦別姓を阻止しましょう！！\n演説場所を募集しています。ご一緒に、夫婦別姓反対運動をし… ',
#  ' rt @kenkenrokujapan: 選択的夫婦別姓の活動の最終目標は「戸籍制度の改定」だそうです。\n\n選択的夫婦別姓の実現はその第一歩。\n\nまさに蟻の一穴。\n\n彼らが選択的夫婦別姓は何も問題ないと叫び続けるのは、この計画を進めるためなのでしょう。\n\n#選択的夫婦別姓 #自… ',
#  ' rt @5sasha5sasha5: 旧統一教会と政治の関係\u3000塚田穂高氏「国会で検証し国民に明示を」 | 毎日新聞 https://t.co/2zfggmnhdx 「夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新… ',
#  ' rt @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな『共産主義』的価値観として敵視するように」→\nhttps://t.co/4aaif6… ',
#  ' rt @kenkenrokujapan: 選択的夫婦別姓の活動の最終目標は「戸籍制度の改定」だそうです。\n\n選択的夫婦別姓の実現はその第一歩。\n\nまさに蟻の一穴。\n\n彼らが選択的夫婦別姓は何も問題ないと叫び続けるのは、この計画を進めるためなのでしょう。\n\n#選択的夫婦別姓 #自… ',
#  ' #自民党政権が日本を滅ぼす\u3000だってそうでしょ？\u3000改憲も選択的夫婦別姓等法律も、韓国の言いなりだよ？\u3000\n日本の愛国者みんな大嫌い韓国の言いなりだよ？\n韓国反社の内政干渉だ！と騒ぐべきでしょ、愛国者ほど。沈黙してると貴様も韓国か!? て疑われるよ？\n#統一教会と関わった議員の辞職を求めます ',
#  ' rt @kenkenrokujapan: 選択的夫婦別姓の活動の最終目標は「戸籍制度の改定」だそうです。\n\n選択的夫婦別姓の実現はその第一歩。\n\nまさに蟻の一穴。\n\n彼らが選択的夫婦別姓は何も問題ないと叫び続けるのは、この計画を進めるためなのでしょう。\n\n#選択的夫婦別姓 #自… ',
#  ' rt @kakitama: もう２０年越しの、「男女共同参画の弱体化」「反ジェンダーフリー(平等)・選択的夫婦別姓」「反lgbt・同性婚」は今に続く”見える成果”です。直近でも子ども庁→子ども家庭庁での山谷えり子議員、更に参院選での井上義行議員の「同性愛差別発言・統一教会の選挙… ',
#  ' 選択的夫婦別姓の活動の最終目標は「戸籍制度の改定」だそうです。\n\n選択的夫婦別姓の実現はその第一歩。\n\nまさに蟻の一穴。\n\n彼らが選択的夫婦別姓は何も問題ないと叫び続けるのは、この計画を進めるためなのでしょう。\n\n#選択的夫婦別姓 #自民党 @jimin_koho https://t.co/492imom4kr ',
#  ' rt @7q3dsgoqopixflu: 旧統一教会側と自民党、改憲案が「一致」\u3000緊急事態条項、家族条項…濃厚な関係が影響？\n\n#スッキリ\n#めざまし8\n進展しない夫婦別姓や同性婚\n長年の緊縮に自己責任と新自由主義、不況時で何度も増税\n\n統一教会か…\u3000\nなるほどね\n\n政治の力… ',
#  ' rt @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな『共産主義』的価値観として敵視するように」→\nhttps://t.co/4aaif6… ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @seiryukai: 夫婦別姓反対街頭演説会を妨害し、米店へ営業妨害的行為をした しばき隊の黒川氏から繋がった日本基督教団。その関連として日本キリスト教協議会があった。団体の総幹事は在日大韓基督教会である。系図では、社民党．立憲民主党の辻本清美氏．北朝鮮政府へと繋がる。… ',
#  ' rt @kakitama: もう２０年越しの、「男女共同参画の弱体化」「反ジェンダーフリー(平等)・選択的夫婦別姓」「反lgbt・同性婚」は今に続く”見える成果”です。直近でも子ども庁→子ども家庭庁での山谷えり子議員、更に参院選での井上義行議員の「同性愛差別発言・統一教会の選挙… ',
#  ' rt @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな『共産主義』的価値観として敵視するように」→\nhttps://t.co/4aaif6… ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @edokaiki: 中国や朝鮮は夫婦別姓であり、子供は否応なく夫である父親の姓に入る。つまり妻である母親は「家系には入れない」「（父方の姓を名乗ることになる）子供を生むだけ」という女性へのトンでもない差別的な制度が（中国・朝鮮方式の）夫婦別姓なのである。 ',
#  ' rt @gun81288955: つか⬇️まず招待状に #選択的夫婦別姓\u3000講演有りと告知しなよ…知らずに来て聞かされる反対の人はムカつくわ🗯 自分が招待された式で…選択的夫婦別姓反対講演あったら⁇ よく考えろって😮\u200d💨👎\nつか金取るの⁇ 儲け口だから賛同者にアピってんの🤢⁇\n#… ',
#  ' rt @edokaiki: 中国や朝鮮は夫婦別姓であり、子供は否応なく夫である父親の姓に入る。つまり妻である母親は「家系には入れない」「（父方の姓を名乗ることになる）子供を生むだけ」という女性へのトンでもない差別的な制度が（中国・朝鮮方式の）夫婦別姓なのである。 ',
#  ' rt @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな『共産主義』的価値観として敵視するように」→\nhttps://t.co/4aaif6… ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな『共産主義』的価値観として敵視するように」→\nhttps://t.co/4aaif6… ',
#  ' rt @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな『共産主義』的価値観として敵視するように」→\nhttps://t.co/4aaif6… ',
#  ' rt @hasegawakenjiro: ポリタスtvのおかげで山口さんの指摘が理解できる。\n\n特に憲法24条の改憲案は、夫婦別姓、同性婚、ジェンダーフリーを阻止する基礎になる。\n\n家父長制度の復活をめざす\n旧統一教会、\n日本政策研究センター、\n日本会議、\nの価値観がほぼ同じ。… ',
#  ' 追加で夫婦別姓\u3000政教分離も共産主義運動\nと\u3000言っても分かる人少ないだろうな・・・ https://t.co/yciwqamac9 ',
#  ' この問題で言えば、じゃあ男性のポケットを取れっていうのでも、女性はそのまま我慢しろ、でもなく。\n経済で言えば「もはや昭和云々」はむしろ時代逆行だし、同性結婚も夫婦別姓も、行われたところでそれによって誰かが損をしますか？という。選択肢は多いに越したことないじゃない ',
#  ' rt @fukubonzzz: 現在の婚姻制度はカルトと言うわけですね。選択的夫婦別姓を選択しない人はおかしいかのようなカルト的な言動にますますドン引きです🤢 ',
#  ' rt @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな『共産主義』的価値観として敵視するように」→\nhttps://t.co/4aaif6… ',
#  ' @gurugurugrass いえ。同性婚やlgbt、夫婦別姓等は断固反対の立場は変わらないけど、制度を悪用する人間も増えている為に帰化や入国など厳格化せざるを得ない位に思う。技能実習生も行方不明者が多いし、逃亡者？と思わしき人間が農作物の盗難が相次いでいる為に自民党や野党には技能実習生廃止してほしい位。 ',
#  ' みんなからの匿名質問を募集中！\n\nこんな質問に答えてるよ\n● 家電を買うならヨドバシカメラ、…\n● 夫婦別姓制度には賛成？反対？\n● 何かバイト経験はありますか？\n● 犬派？ハムスター派？\n#質問箱 #匿名質問募集中\n\nhttps://t.co/7moh2iy3le ',
#  ' 夫婦別姓オッケーのタイミングでヤマサキとヤマザキどっちかに統一してくれんかな ',
#  ' rt @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな『共産主義』的価値観として敵視するように」→\nhttps://t.co/4aaif6… ',
#  ' 現代ソースだと割引いて考えないといけないけど、世耕さんも岸田さんも選択的夫婦別姓に賛成なので期待しちゃうな\nhttps://t.co/ydihzzviot ',
#  ' rt @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな『共産主義』的価値観として敵視するように」→\nhttps://t.co/4aaif6… ',
#  ' rt @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな『共産主義』的価値観として敵視するように」→\nhttps://t.co/4aaif6… ',
#  ' rt @kakitama: 旧統一教会と政治の関係\u3000塚田穂高氏 | https://t.co/cp4hnqcakb \n”また、家族や性的「純潔」を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新た… ',
#  ' 中国や朝鮮は夫婦別姓であり、子供は否応なく夫である父親の姓に入る。つまり妻である母親は「家系には入れない」「（父方の姓を名乗ることになる）子供を生むだけ」という女性へのトンでもない差別的な制度が（中国・朝鮮方式の）夫婦別姓なのである。 ',
#  ' rt @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな『共産主義』的価値観として敵視するように」→\nhttps://t.co/4aaif6… ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな『共産主義』的価値観として敵視するように」→\nhttps://t.co/4aaif6… ',
#  ' rt @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな『共産主義』的価値観として敵視するように」→\nhttps://t.co/4aaif6… ',
#  ' 旧統一教会と政治の関係\u3000塚田穂高氏 | https://t.co/cp4hnqcakb \n”また、家族や性的「純潔」を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな「共産主義」的価値観として敵視するようになりました。” ',
#  ' rt @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな『共産主義』的価値観として敵視するように」→\nhttps://t.co/4aaif6… ',
#  ' rt @kenkenrokujapan: 一部の人たちが騒いでいる選択的夫婦別姓ですが、岡山県議会で反対の意見書が可決されましたね。\n\nこうした良識ある地方議会には頑張って欲しいものです。\n\n#選択的夫婦別姓\n\n選択的夫婦別姓制度の反対意見書を可決\u3000岡山県議会 \nhttps:/… ',
#  ' rt @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな『共産主義』的価値観として敵視するように」→\nhttps://t.co/4aaif6… ',
#  ' rt @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな『共産主義』的価値観として敵視するように」→\nhttps://t.co/4aaif6… ',
#  ' rt @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな『共産主義』的価値観として敵視するように」→\nhttps://t.co/4aaif6… ',
#  ' rt @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな『共産主義』的価値観として敵視するように」→\nhttps://t.co/4aaif6… ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな『共産主義』的価値観として敵視するように」→\nhttps://t.co/4aaif6… ',
#  ' rt @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな『共産主義』的価値観として敵視するように」→\nhttps://t.co/4aaif6… ',
#  ' rt @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな『共産主義』的価値観として敵視するように」→\nhttps://t.co/4aaif6… ',
#  ' rt @pablichenkosssr: 教祖夫妻が別姓国出身で別姓だったのにそんなわけないじゃないですか。\nむしろ家族の解体を是とし、早い段階から別姓選択を可能にしていた共産主義国や社会主義国と夫婦別姓の方が関係ありますよ。 ',
#  ' rt @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな『共産主義』的価値観として敵視するように」→\nhttps://t.co/4aaif6… ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな『共産主義』的価値観として敵視するように」→\nhttps://t.co/4aaif6… ',
#  ' rt @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな『共産主義』的価値観として敵視するように」→\nhttps://t.co/4aaif6… ',
#  ' rt @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな『共産主義』的価値観として敵視するように」→\nhttps://t.co/4aaif6… ',
#  ' rt @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな『共産主義』的価値観として敵視するように」→\nhttps://t.co/4aaif6… ',
#  ' rt @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな『共産主義』的価値観として敵視するように」→\nhttps://t.co/4aaif6… ',
#  ' 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな『共産主義』的価値観として敵視するように」→\nhttps://t.co/4aaif6z6uh ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @sollevante2022: 表だって選択的夫婦別姓に反対している団体なんて\n神道政治連盟と幸福の科学、日本会議、\nそして統一教会くらいですね。\n\nほかにはもうないんじゃないかねえ。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' @nipponichi8 追悼したいなら国民の税金を使わずにやればいいだけ。\n他人の追悼を邪魔しようとはしていない。\n税金を私物化するなって言っているだけ。\n税金を自分のものと勘違いする輩が信じられない。\n統一教会が反対する選択的夫婦別姓を退ける言い訳と一緒だな。迷惑。 ',
#  ' rt @sollevante2022: 表だって選択的夫婦別姓に反対している団体なんて\n神道政治連盟と幸福の科学、日本会議、\nそして統一教会くらいですね。\n\nほかにはもうないんじゃないかねえ。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @id_seiron: 「具体例を出せ！具体例を出せ！」と言ってる選択的夫婦別姓推進派ほど出さない具体例\n\n改姓が原因で\n・キャリアを失った\n・論文の著作権を失った\n・資格を失った\n\n具体的な例は何一つ聞いたことがない（笑） ',
#  ' rt @5sasha5sasha5: 旧統一教会と政治の関係\u3000塚田穂高氏「国会で検証し国民に明示を」 | 毎日新聞 https://t.co/2zfggmnhdx 「夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新… ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' 早く日本人同士でも夫婦別姓を選択できるようになってくれ\u3000#選択的夫婦別姓を求めます ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @kakitama: もう２０年越しの、「男女共同参画の弱体化」「反ジェンダーフリー(平等)・選択的夫婦別姓」「反lgbt・同性婚」は今に続く”見える成果”です。直近でも子ども庁→子ども家庭庁での山谷えり子議員、更に参院選での井上義行議員の「同性愛差別発言・統一教会の選挙… ',
#  ' rt @jn_lyio: ジェンダー平等になると不幸な女性が減る→宗教に走る人が少なくなる→新興宗教的には困る→ジェンダー平等反対！夫婦別姓反対！になる。なのかも？金曜日のポリタス、石井千湖さんの回観ててふと気づいてしまった。 ',
#  ' 自民党の党首討論では、普通に政策論がぶつかる場面がありました。\n\nつまり、それだけ国論を二分する議論にも切り込んでるから。\n\n・消費税減税の期間\n・敵基地反撃能力\n・核共有\n・選択的夫婦別姓\n・統一協会への対応\n\nなど、意見が分かれる\nかつ国民の関心の高い政策を\n議論すべき。 https://t.co/h0ojohmp1u ',
#  ' rt @suzumiya_na_gi: ここ、明確に、外国人には恩恵ないよ、と伝えないといけないところですね。\n何故か、外国人が夫婦別姓で利益を受ける前提の立論が散見されている。 ',
#  ' rt @x2can3joy: なんか知らんけど、選択的夫婦別姓に反対している人の書いている内容に突っ込みを入れると、それだけで『レッテル貼り』と言い出す人多い。\n\n反対派の間で流行ってる？\n\nそう言えば、偶然かもしれないけど、旧・統一教会の抗議文書にも『レッテル貼り』の文言あっ… ',
#  ' rt @uyoel2103: @sankei_news 維新の会は、上海電力の件で説明責任を果たしていないし、選択的夫婦別姓も賛成でロシア擁護に中國擁護の偽保守政党だと\n判明しました。保守のフリして有権者はを騙した罪は重い。 ',
#  ' rt @yuki_3_3837: ﾏｽｺﾐ\n意図を持って報道\u3000反ﾆﾁ\n・スパイ防止法制定を阻止\n・選択的夫婦別姓の自由＆\n外国人住民投票権を推奨\u3000（ウイグルは侵略されました）\n\n・中○-ﾅｶﾖｼ-公○党＝s学会\n・○国に都合の悪い安倍元総理を散々捏造で批判\n暗殺事件の本質隠し… ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' rt @kakitama: もう２０年越しの、「男女共同参画の弱体化」「反ジェンダーフリー(平等)・選択的夫婦別姓」「反lgbt・同性婚」は今に続く”見える成果”です。直近でも子ども庁→子ども家庭庁での山谷えり子議員、更に参院選での井上義行議員の「同性愛差別発言・統一教会の選挙… ',
#  ' 自民党が夫婦別姓やlgbtなどに頑なに反対するのを、奇異に感じていた ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' 現在の婚姻制度はカルトと言うわけですね。選択的夫婦別姓を選択しない人はおかしいかのようなカルト的な言動にますますドン引きです🤢 https://t.co/w0gny28pqn ',
#  ' rt @kakitama: もう２０年越しの、「男女共同参画の弱体化」「反ジェンダーフリー(平等)・選択的夫婦別姓」「反lgbt・同性婚」は今に続く”見える成果”です。直近でも子ども庁→子ども家庭庁での山谷えり子議員、更に参院選での井上義行議員の「同性愛差別発言・統一教会の選挙… ',
#  ' rt @kenkenrokujapan: 一部の人が騒いでいる選択的夫婦別姓ですが、熊本県議会でも反対の意見書が可決されましたね。\n\nこうした良識のある地方議会は頑張って欲しいものです。\n\n#選択的夫婦別姓\n\n夫婦別姓反対の意見書、熊本県議会が可決\u3000自民など賛成\nhttps:/… ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @5sasha5sasha5: 旧統一教会と政治の関係\u3000塚田穂高氏「国会で検証し国民に明示を」 | 毎日新聞 https://t.co/2zfggmnhdx 「夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新… ',
#  ' rt @nabesan_go: 私は全然左派ではないが、自民党の合理性に欠ける行政・政策のいくつかは統一教会の影響を疑わざる得ないです。\n・統一教会の名称変更認可\n・hpvワクチン反対\n・こども庁の名称問題\n・同性婚反対\n・夫婦別姓反対 ',
#  ' rt @besseibot: 選択的夫婦別姓は戸籍と共存できます。むしろ、現在戸籍を作らず事実婚にしている夫婦や、子連れ再婚で同一戸籍に入れない家族にとっても、戸籍が本来の目的を果たせるようになります。やることは「同一戸籍・同一氏（姓）」の制限を外すだけです。 ',
#  ' @na7719961212 @sabutibi777 結婚していづれは帰化ということです。ちなみに帰化とは日本人になることです。\n\n改姓しなくてよければ国籍取得目的で今すぐ結婚すると言う人がいるという現実を見ると、\n選択的夫婦別姓にしたらこういう国籍取得目的の結婚がしやすくならないか？ということです。 ',
#  ' この前のナイトスクープ結婚して苗字を変えるかどうかの話、選択制夫婦別姓にすりゃいいんだよなぁ……選択制だよ、そうしたい人だけがそうする、それでいいんじゃないの\nまぁ壺に妨害されてたんか知らんけど……反対する意味がわかんない ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @kenkenrokujapan: 選択的夫婦別姓で活動する理由は「家に従属する女」という呪いを断ち切るためだそうです。\n\n何ですかこれ？\n\nこんな理由に自民党は協力するのですか？\n\n#選択的夫婦別姓 #自民党 @jimin_koho https://t.co/khjhl… ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' 結婚式のスピーチで時代錯誤な男女の役割論聞かされて帰りたくなることなんて山のようにあるけどね。結婚式は2人のスタンスや生き方を示す場でもあるから、大事な親戚や知り合いが集まってる場所で井田さんに選択的夫婦別姓についてスピーチしてもらうのとかめっちゃ良い機会だと思う💗 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @powertopeople5: 子ども家庭庁。「家庭」を入れさした統一教会。\n統一教会の教義の原罪はエバとサタンとの禁断関係。統一教会は男女関係をメシア文鮮明が作る。二世は恋愛も罪。夫婦別姓、lgbtqを否定。財源は日本の信者からの搾取。世界に展開。邪教とズブズブの自民… ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' 1982年発売の松田聖子さんのアルバム曲『未来の花嫁』♫\nさまざまなものに対する価値観が変化する中、結婚に関してはさほど大きな変化はないのでは。\n夫婦別姓の議論は進まず、結婚はするもの、という意識は多少の揺らぎが見られる程度。\n今後どうなっていくかは、若い世代の価値観次第だと思います😌 ',
#  ' rt @powertopeople5: 子ども家庭庁。「家庭」を入れさした統一教会。\n統一教会の教義の原罪はエバとサタンとの禁断関係。統一教会は男女関係をメシア文鮮明が作る。二世は恋愛も罪。夫婦別姓、lgbtqを否定。財源は日本の信者からの搾取。世界に展開。邪教とズブズブの自民… ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @emma78004812: 色々おかしいなとは思っていたんですけれどねぇ…\n★山谷えり子氏が国家公安委員長\n★総理の美しい国発言\n★子ども庁→子ども家庭庁\n★夫婦別姓・同性婚反対\n★報道が偏ってきた\n等々\nでもまさかここまで統一教会に魂を売っていたとは😰\n #この時点で… ',
#  ' rt @hnr5utvhipxqs2v: @ozawa_jimusho 統一教会が自民党案に寄せてるだけでしょ？だって統一教会は「夫婦別姓に反対」って言ってますが、韓国も教祖夫妻も別姓で、「自民党に寄せるために夫婦別姓反対を言ってる」ってのは明らかでしょ？ ',
#  ' rt @powertopeople5: 子ども家庭庁。「家庭」を入れさした統一教会。\n統一教会の教義の原罪はエバとサタンとの禁断関係。統一教会は男女関係をメシア文鮮明が作る。二世は恋愛も罪。夫婦別姓、lgbtqを否定。財源は日本の信者からの搾取。世界に展開。邪教とズブズブの自民… ',
#  ' rt @forthman: 国葬なんて、国民は関心ない。\nモリカケなんて、国民は関心ない。\n選択的夫婦別姓なんて、国民は関心ない。\n\u3000\n何を言うのも自由な国です。 ',
#  ' @t_moonnight 複雑に法が連動しあっているため何年も費やす必要がありそうですね。国会で選択的夫婦別姓だけに的を絞るわけにもいきませんし、確かにいろいろ揉めそうです。\n\n今の子供達が大人になる頃には、選択肢が一つ増えているかな？…くらいの長いスパンで考えておきますw\n\nご教授ありがとうございます。 ',
#  ' rt @7q3dsgoqopixflu: @chizurua1 #日本を取り戻す\n\n進展しない夫婦別姓や同性婚\n長年の緊縮に自己責任と新自由主義、国民には重税を課し、そして改憲\n\n子ども庁から子ども家庭庁へ…\n自公政権に統一教会か\nなるほどね\n\n#統一教会\n政治の力\n http… ',
#  ' rt @5sasha5sasha5: 旧統一教会と政治の関係\u3000塚田穂高氏「国会で検証し国民に明示を」 | 毎日新聞 https://t.co/2zfggmnhdx 「夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新… ',
#  ' rt @kakitama: もう２０年越しの、「男女共同参画の弱体化」「反ジェンダーフリー(平等)・選択的夫婦別姓」「反lgbt・同性婚」は今に続く”見える成果”です。直近でも子ども庁→子ども家庭庁での山谷えり子議員、更に参院選での井上義行議員の「同性愛差別発言・統一教会の選挙… ',
#  ' rt @japanculture113: 国民民主党支持者とは考えの違いはあるけど、議論になっていい感じ。私は自民党保守派支持ではあるけど、経済政策がいいので、国民民主党を評価してる。ただ夫婦別姓や同性婚に反対の立場なのでそこが勿体ない。 ',
#  ' rt @bot73109026: 全国の役場の公務員と物流会社とシステム会社が変更手続きをするための新たな投資を行う必要があり、しかも継続的に業務は増加します。\n\nそしてマンガやアニメに「夫婦別姓じゃない！ガー！」というクレーマーが確実にきます。 ',
#  ' rt @seiryukai: 選択的夫婦別姓 反対twitter演説会のショートムービーです。\n演説会動画は完成しだいyoutubeにアップし皆さんにお知らせいたします。\n皆さんの力を結集して夫婦別姓を阻止しましょう！！\n演説場所を募集しています。ご一緒に、夫婦別姓反対運動をし… ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @nabesan_go: 私は全然左派ではないが、自民党の合理性に欠ける行政・政策のいくつかは統一教会の影響を疑わざる得ないです。\n・統一教会の名称変更認可\n・hpvワクチン反対\n・こども庁の名称問題\n・同性婚反対\n・夫婦別姓反対 https://t.co/o9ubmc3… ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' 自民党には頑固保守爺さんがいて家族はこうあるべきと夫婦別姓も反対してると思ったけどカルト教団の票集めの為だったんですね\n投票率が5割だから\n結局、投票率が低いと国会に出ない暴露系youtuberを生み出したりカルト教団の思い通りになってしまう。正にカルトの思う壷だ ',
#  ' rt @nabesan_go: 私は全然左派ではないが、自民党の合理性に欠ける行政・政策のいくつかは統一教会の影響を疑わざる得ないです。\n・統一教会の名称変更認可\n・hpvワクチン反対\n・こども庁の名称問題\n・同性婚反対\n・夫婦別姓反対 ',
#  ' なんか知らんけど、選択的夫婦別姓に反対している人の書いている内容に突っ込みを入れると、それだけで『レッテル貼り』と言い出す人多い。\n\n反対派の間で流行ってる？\n\nそう言えば、偶然かもしれないけど、旧・統一教会の抗議文書にも『レッテル貼り』の文言あった。\n\nまさか、発信元が同じとか？？？ ',
#  ' rt @starship_glory: ヒューマン・ライツ・ウォッチって、人権団体と言いつつ、実は極左集団なんじゃないの？選択的夫婦別姓やlgbtや外国人参政権問題、移民入管等みんな絡んでんじゃん。金に物を言わせてロビー活動してんのかなぁ〜🙄🤔🙄辻元清美に有田芳生、オマケに伊藤… ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' 普段教育や児童福祉なんて微塵も考えてない癖に、同性婚や選択的夫婦別姓とかの時だけ「子供がかわいそう」とか言うやついるじゃん？アレなに？新手の妖怪？ ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' @cafelattenaruto @sabutibi777 それ、選択的夫婦別姓でも関係ないですよね？\n外国人は日本人と結婚するだけでは戸籍取得は無理。\n日本人となり帰化する必要がある。\nそれは現在でも選択的夫婦別姓でも同じ。\n\n正直、正式な手続きを経て、外国人が戸籍を取得して不満なら、\nそれは選択的夫婦別姓の問題ではないですよね。 ',
#  ' 子供が出来るかなんて分からないし夫婦によりけり。選択的夫婦別姓＝強制的親子別姓ではない https://t.co/yr0h2ldgy8 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @hasegawakenjiro: ポリタスtvのおかげで山口さんの指摘が理解できる。\n\n特に憲法24条の改憲案は、夫婦別姓、同性婚、ジェンダーフリーを阻止する基礎になる。\n\n家父長制度の復活をめざす\n旧統一教会、\n日本政策研究センター、\n日本会議、\nの価値観がほぼ同じ。… ',
#  ' rt @blackswan_tokyo: すごく面白かったyoutube。なぜ夫婦別姓制度やlgbtgに対して、政権が後ろ向きなのか、パズルが埋まるように理解できました！ ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @yuki1988jp: 自民党はもう統一教会に乗っ取られてるも同然。改憲だけでなく同性婚反対や選択的夫婦別姓反対も統一教会の教えの通り。\nいい加減自民党支持者も目を覚ました方がいい。\n\n#ミヤネ屋頑張れ \n\n旧統一教会側と自民党、改憲案が「一致」\u3000緊急事態条項、家族条項… ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @l75bojocreiks0j: 馬鹿じゃねえの。政党はいちいち宗教団体の教義に賛意なんか示さねえよ。ただ、統一教会は「憲法改正、防衛強化に賛成」「夫婦別姓と同性婚に反対」の立場だから、自民党からすりゃ票活しやすいし、統一教会も政活するわな。政党が教義に賛否いずれの立場… ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @hasegawakenjiro: ポリタスtvのおかげで山口さんの指摘が理解できる。\n\n特に憲法24条の改憲案は、夫婦別姓、同性婚、ジェンダーフリーを阻止する基礎になる。\n\n家父長制度の復活をめざす\n旧統一教会、\n日本政策研究センター、\n日本会議、\nの価値観がほぼ同じ。… ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' 嫌韓は重要度が低くて、選択的夫婦別姓や同性婚を阻止する、戦前の家庭とか家父とかへ戻るが大目的だから、そのための味方なので出が韓国だろうと攻めないってことか。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @kakitama: もう２０年越しの、「男女共同参画の弱体化」「反ジェンダーフリー(平等)・選択的夫婦別姓」「反lgbt・同性婚」は今に続く”見える成果”です。直近でも子ども庁→子ども家庭庁での山谷えり子議員、更に参院選での井上義行議員の「同性愛差別発言・統一教会の選挙… ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @kakitama: もう２０年越しの、「男女共同参画の弱体化」「反ジェンダーフリー(平等)・選択的夫婦別姓」「反lgbt・同性婚」は今に続く”見える成果”です。直近でも子ども庁→子ども家庭庁での山谷えり子議員、更に参院選での井上義行議員の「同性愛差別発言・統一教会の選挙… ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @hasegawakenjiro: ポリタスtvのおかげで山口さんの指摘が理解できる。\n\n特に憲法24条の改憲案は、夫婦別姓、同性婚、ジェンダーフリーを阻止する基礎になる。\n\n家父長制度の復活をめざす\n旧統一教会、\n日本政策研究センター、\n日本会議、\nの価値観がほぼ同じ。… ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @5sasha5sasha5: 旧統一教会と政治の関係\u3000塚田穂高氏「国会で検証し国民に明示を」 | 毎日新聞 https://t.co/2zfggmnhdx 「夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新… ',
#  ' rt @kakitama: もう２０年越しの、「男女共同参画の弱体化」「反ジェンダーフリー(平等)・選択的夫婦別姓」「反lgbt・同性婚」は今に続く”見える成果”です。直近でも子ども庁→子ども家庭庁での山谷えり子議員、更に参院選での井上義行議員の「同性愛差別発言・統一教会の選挙… ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' もう２０年越しの、「男女共同参画の弱体化」「反ジェンダーフリー(平等)・選択的夫婦別姓」「反lgbt・同性婚」は今に続く”見える成果”です。直近でも子ども庁→子ども家庭庁での山谷えり子議員、更に参院選での井上義行議員の「同性愛差別発言・統一教会の選挙支援」はあまりに露骨な実例でした。 https://t.co/podhhijq0a https://t.co/ipsmphpxfl ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @5sasha5sasha5: 旧統一教会と政治の関係\u3000塚田穂高氏「国会で検証し国民に明示を」 | 毎日新聞 https://t.co/2zfggmnhdx 「夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新… ',
#  ' rt @id_seiron: 「具体例を出せ！具体例を出せ！」と言ってる選択的夫婦別姓推進派ほど出さない具体例\n\n改姓が原因で\n・キャリアを失った\n・論文の著作権を失った\n・資格を失った\n\n具体的な例は何一つ聞いたことがない（笑） ',
#  ' rt @5sasha5sasha5: 旧統一教会と政治の関係\u3000塚田穂高氏「国会で検証し国民に明示を」 | 毎日新聞 https://t.co/2zfggmnhdx 「夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新… ',
#  ' 立法的救済があるので実質的に選択的夫婦別姓と言えなくないと思うかもしれないが、 夫が帰化していない外国人の場合に、日本法で自由に妻氏を選択して婚姻できるわけでは無い(選択の余地がない)ので、やはり国際結婚は「選択的」夫婦別姓とは言い難い。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' 結婚式の招待状が来た時点で､夫婦別姓の事実婚だと分かるはずだから\n嫌なら欠席するまでだよ\nそもそも夫婦別姓と聞いただけでブチ切れる奴を別姓事実婚の結婚式に招待するかよ https://t.co/oful1wngln ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' 念のため繰り返しますが、選択的夫婦別姓についての批判ではなく、この方個人の宗教蔑視からくる差別発言についての批判です。「別姓を望むなら事実婚でよい」という主張には私も反対です。 ',
#  ' 私は選択的夫婦別姓に賛成していますし、ありもしない伝統を振り翳して差別や不備を煽動・放置する流れにも反対ですが、「低レベルなものは宗教のせい」と定義も曖昧なままに関係のないものをマイナス要素に紐付けし、一纏めに見下す言動は非常に差別的だと感じます。撤回を願います。 https://t.co/bfwo2novqo ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @5sasha5sasha5: 旧統一教会と政治の関係\u3000塚田穂高氏「国会で検証し国民に明示を」 | 毎日新聞 https://t.co/2zfggmnhdx 「夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新… ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @oosakahaoosaka: ジェンダーフリーはダメ\u3000夫婦別姓はダメ\u3000男女共同参画はダメ\u3000憲法改悪は賛成\u3000緊急事態条項は入れろ\u3000核は持て\u3000武器は輸出しろ\n全部、自民党の考えじゃなくて『統一協会』の妄想だとしたら、それを踏襲してええの？日本のみんな。 https://t… ',
#  ' rt @chizurua1: 選択制夫婦別姓や同性婚の成立を反対する理由として、「家庭」「家族」の価値を強調されると、違和感しかない。そこが愛情を育むための居場所としてではなく、封建主義を維持する役割を期待しているから。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' 選択的夫婦別姓で活動する理由は「家に従属する女」という呪いを断ち切るためだそうです。\n\n何ですかこれ？\n\nこんな理由に自民党は協力するのですか？\n\n#選択的夫婦別姓 #自民党 @jimin_koho https://t.co/khjhlan81p ',
#  ' rt @kei_nakazawa: 前々からおかしいと感じてはいたんだ。「ジェンダーフリーは共産主義だ」とか「夫婦別姓は共産主義だ」とか、ことあるごとに共産主義が出てくるから「？」だったんだけど。そうか勝共連合の旧統一教会がいたからなんだ。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @hasegawakenjiro: ポリタスtvのおかげで山口さんの指摘が理解できる。\n\n特に憲法24条の改憲案は、夫婦別姓、同性婚、ジェンダーフリーを阻止する基礎になる。\n\n家父長制度の復活をめざす\n旧統一教会、\n日本政策研究センター、\n日本会議、\nの価値観がほぼ同じ。… ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @id_seiron: 「具体例を出せ！具体例を出せ！」と言ってる選択的夫婦別姓推進派ほど出さない具体例\n\n改姓が原因で\n・キャリアを失った\n・論文の著作権を失った\n・資格を失った\n\n具体的な例は何一つ聞いたことがない（笑） ',
#  ' rt @hasegawakenjiro: ポリタスtvのおかげで山口さんの指摘が理解できる。\n\n特に憲法24条の改憲案は、夫婦別姓、同性婚、ジェンダーフリーを阻止する基礎になる。\n\n家父長制度の復活をめざす\n旧統一教会、\n日本政策研究センター、\n日本会議、\nの価値観がほぼ同じ。… ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' 夫婦別姓とか同性婚とか中絶禁止とか親の仇か？！って思うほど政府が反対してて何でそんな頑ななのか全く理解できなかったんだけど、なるほど宗教ね。宗教自体は反対しないけど、政治家に取り入って国自体を動かそうとする動きは断固反対です。そして政治家は国民を向いて政治してくれ。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' ここまで来たら最早、壺 vs 反壺やんね。\n半壺でまとまれるじゃろ！\nなーんで選択的夫婦別姓みたいなだーれも損せえへんことが進まんかっていうたら、壺に反するからじゃんね。 ',
#  ' rt @moff70357636: カルトの村八分とか引き戻そうとする話を聞いて、最近の日本はカルト化していたんじゃないかと。\n\n自主休校だって、\n選択制夫婦別姓だって、\n\nしたい人がすればいいのに、\n何の不利益もないのに批判や反対が止まないのはやっぱり異常。 ',
#  ' rt @5sasha5sasha5: 旧統一教会と政治の関係\u3000塚田穂高氏「国会で検証し国民に明示を」 | 毎日新聞 https://t.co/2zfggmnhdx 「夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新… ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @nwfle6q9vqtxb4q: こういう陰謀論をtweetするのは辞めた方がいい。最低だと思う。\n選択的夫婦別姓推進派の統一教会関連団体主催イベント出席者もいる。lgbt理解増進法、hpvワクチン然り。\n↓\n手を洗う救急医taka「hpvワクチンに強く反対していた政治… ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' rt @5sasha5sasha5: 旧統一教会と政治の関係\u3000塚田穂高氏「国会で検証し国民に明示を」 | 毎日新聞 https://t.co/2zfggmnhdx 「夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新… ',
#  ' rt @ifpesliwwpob4kt: 仰る通り❗️\n\n差別だの、ジェノサイドだの、在日や左翼メディアがどれだけ騒ごうが、役所に押し掛け圧力掛けようが、日本人以外には適用しない。\n\n戸籍謄本(縦書き)の4代遡って日本人であれば適用。\n\n自動的に在日や帰化人は外せる。\n\nこれが… ',
#  ' カルトの村八分とか引き戻そうとする話を聞いて、最近の日本はカルト化していたんじゃないかと。\n\n自主休校だって、\n選択制夫婦別姓だって、\n\nしたい人がすればいいのに、\n何の不利益もないのに批判や反対が止まないのはやっぱり異常。 ',
#  ' rt @5sasha5sasha5: 旧統一教会と政治の関係\u3000塚田穂高氏「国会で検証し国民に明示を」 | 毎日新聞 https://t.co/2zfggmnhdx 「夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新… ',
#  ' 夫婦別姓、特に思想とかある訳ではなく単にめんどくさいという理由でそのまま運用されてるのまあまあ面白いとは思います。普段その辺政治的主張しか見ないtwitterじゃあんま出てこない話ですね。 ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' rt @ganrim_: 「前々からおかしいと感じてはいたんだ。「ジェンダーフリーは共産主義だ」とか「夫婦別姓は共産主義だ」とか、ことあるごとに共産主義が出てくるから「？」だったんだけど。そうか勝共連合の旧統一教会がいたからなんだ。」\n\nいや、ちゃうやろ。その辺の思想は思想史的… ',
#  ' rt @hasegawakenjiro: ポリタスtvのおかげで山口さんの指摘が理解できる。\n\n特に憲法24条の改憲案は、夫婦別姓、同性婚、ジェンダーフリーを阻止する基礎になる。\n\n家父長制度の復活をめざす\n旧統一教会、\n日本政策研究センター、\n日本会議、\nの価値観がほぼ同じ。… ',
#  ' rt @mrjombxev6xdu9c: あなたが、選択的夫婦別姓に反対する理由は何ですか？ ',
#  ' rt @aiko33151709: ネット上では流布していたカルト統一教会と自民党との密接な関係が今回公衆の前に明らかにされた。夫婦別姓反対、同性婚反対、lgbt反対、家庭中心主義等の自民党の政策は統一教会の教義と同一なのが判明。自民は選挙協力欲しさに彼らの特異な教義を自民の政… ',
#  ' rt @masterds2_3: 「ジェンダーフリーや夫婦別姓は共産主義」も「ジェンダーフリー反対や夫婦別姓反対は統一教会」も実質的には同じ事で、それは「陰謀論」と呼ばれています。 ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' rt @masterds2_3: その前に旧統一教会は韓国の宗教で、韓国人は夫婦別姓だよ ',
#  ' rt @5sasha5sasha5: 旧統一教会と政治の関係\u3000塚田穂高氏「国会で検証し国民に明示を」 | 毎日新聞 https://t.co/2zfggmnhdx 「夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新… ',
#  ' 選択制夫婦別姓に対してヒス起こしてるのもしかしてガチのジジイだけか！？みたいな気付きはありましたね。もう実運用上では夫婦別姓が機能しちゃってる。旧姓使用で通してる人がほとんどだったのはびっくりしましたね……｡ ',
#  ' 夫婦別姓どうのじゃなくて、結婚式で講演始まるのは普通にイヤ。 https://t.co/m6y1akdskz ',
#  ' rt @sabai_aruka: 夫婦別姓を反対している統一教会ですけど、ブンさんとハクさんは\nなぜ別姓なんでしょうか？ ',
#  ' @solo_0505 @takeuchikumiffy おっしゃる通りですね。\n皇室破壊＝日本破壊\u3000ですね。\n朝鮮半島出身労働者の目的は、日本\u3000日本人の奴隷化です。\nそのためには、人権、男女平等、lgbt、夫婦別姓、ポリコレ、参政権、・・・・\u3000何でも利用します。\nいつまでも。\u3000\n私も頑張ります。😊😇 ',
#  ' rt @nabesan_go: 私は全然左派ではないが、自民党の合理性に欠ける行政・政策のいくつかは統一教会の影響を疑わざる得ないです。\n・統一教会の名称変更認可\n・hpvワクチン反対\n・こども庁の名称問題\n・同性婚反対\n・夫婦別姓反対 ',
#  ' rt @hasegawakenjiro: ポリタスtvのおかげで山口さんの指摘が理解できる。\n\n特に憲法24条の改憲案は、夫婦別姓、同性婚、ジェンダーフリーを阻止する基礎になる。\n\n家父長制度の復活をめざす\n旧統一教会、\n日本政策研究センター、\n日本会議、\nの価値観がほぼ同じ。… ',
#  ' rt @5sasha5sasha5: 旧統一教会と政治の関係\u3000塚田穂高氏「国会で検証し国民に明示を」 | 毎日新聞 https://t.co/2zfggmnhdx 「夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新… ',
#  ' rt @hasegawakenjiro: ポリタスtvのおかげで山口さんの指摘が理解できる。\n\n特に憲法24条の改憲案は、夫婦別姓、同性婚、ジェンダーフリーを阻止する基礎になる。\n\n家父長制度の復活をめざす\n旧統一教会、\n日本政策研究センター、\n日本会議、\nの価値観がほぼ同じ。… ',
#  ' rt @hasegawakenjiro: ポリタスtvのおかげで山口さんの指摘が理解できる。\n\n特に憲法24条の改憲案は、夫婦別姓、同性婚、ジェンダーフリーを阻止する基礎になる。\n\n家父長制度の復活をめざす\n旧統一教会、\n日本政策研究センター、\n日本会議、\nの価値観がほぼ同じ。… ',
#  ' 選択的夫婦別姓は“日本人同士の結婚”の話なので心配に及びません。\n壺カルトのデマを信じないでね。生まれてから姓を変えない選択をする事がなぜそんな話になるのか少しは頭を使いましょう^_^ https://t.co/wt5ge3frrj ',
#  ' rt @sabai_aruka: 夫婦別姓を反対している統一教会ですけど、ブンさんとハクさんは\nなぜ別姓なんでしょうか？ ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' rt @hasegawakenjiro: ポリタスtvのおかげで山口さんの指摘が理解できる。\n\n特に憲法24条の改憲案は、夫婦別姓、同性婚、ジェンダーフリーを阻止する基礎になる。\n\n家父長制度の復活をめざす\n旧統一教会、\n日本政策研究センター、\n日本会議、\nの価値観がほぼ同じ。… ',
#  ' @ahonotakao 憲法改正‼️\n選択的夫婦別姓に反対‼️とか言ってたな🤔\n教団の思想と一緒じゃん。 ',
#  ' rt @5sasha5sasha5: 旧統一教会と政治の関係\u3000塚田穂高氏「国会で検証し国民に明示を」 | 毎日新聞 https://t.co/2zfggmnhdx 「夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新… ',
#  ' 夫婦別姓を反対している統一教会ですけど、ブンさんとハクさんは\nなぜ別姓なんでしょうか？ ',
#  ' rt @nwfle6q9vqtxb4q: 【新潮砲】親子と代わる代わる…\u3000内縁妻の娘と不倫『夫婦別姓』推進弁護士の“多様性家族”特集\n#選択的夫婦別姓\u3000#多様な性\u3000#親子丼\n【登場人物】野口敏彦弁護士／加藤美恵子(仮名)主婦／高橋(仮名)野口の内縁の妻・美恵子の実の母／美恵子の… ',
#  ' rt @ppsh41_1945: 自民党の杉田水脈議員は「保育所や学童保育は共産主義による洗脳の場であり、夫婦別姓やlgbt支援とセットで日本の家族を崩壊させようとしている」などと主張していたけど、子供を教団側に置きたがる統一教会の教義と全く同じなんだよね。\n\nもはや統一教会関… ',
#  ' rt @starship_glory: @m3llsquc35qdao0 @cosmicworld000 高市早苗さんのカウンターとして引っ張り出してきたのが、立命館の周平ちゃんですね。\n\n選択的夫婦別姓反対派議員の主張を家族法研究者が論破\nhttps://t.co/ldxim… ',
#  ' rt @hasegawakenjiro: ポリタスtvのおかげで山口さんの指摘が理解できる。\n\n特に憲法24条の改憲案は、夫婦別姓、同性婚、ジェンダーフリーを阻止する基礎になる。\n\n家父長制度の復活をめざす\n旧統一教会、\n日本政策研究センター、\n日本会議、\nの価値観がほぼ同じ。… ',
#  ' @nwfle6q9vqtxb4q 野田さんと言えば選択的夫婦別姓賛成の方ですね。三宅さんと言い、矛盾してますね。 ',
#  ' rt @5sasha5sasha5: 旧統一教会と政治の関係\u3000塚田穂高氏「国会で検証し国民に明示を」 | 毎日新聞 https://t.co/2zfggmnhdx 「夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新… ',
#  ' rt @starship_glory: @m3llsquc35qdao0 @cosmicworld000 高市早苗さんのカウンターとして引っ張り出してきたのが、立命館の周平ちゃんですね。\n\n選択的夫婦別姓反対派議員の主張を家族法研究者が論破\nhttps://t.co/ldxim… ',
#  ' rt @5sasha5sasha5: 旧統一教会と政治の関係\u3000塚田穂高氏「国会で検証し国民に明示を」 | 毎日新聞 https://t.co/2zfggmnhdx 「夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新… ',
#  ' rt @hasegawakenjiro: ポリタスtvのおかげで山口さんの指摘が理解できる。\n\n特に憲法24条の改憲案は、夫婦別姓、同性婚、ジェンダーフリーを阻止する基礎になる。\n\n家父長制度の復活をめざす\n旧統一教会、\n日本政策研究センター、\n日本会議、\nの価値観がほぼ同じ。… ',
#  ' rt @hasegawakenjiro: ポリタスtvのおかげで山口さんの指摘が理解できる。\n\n特に憲法24条の改憲案は、夫婦別姓、同性婚、ジェンダーフリーを阻止する基礎になる。\n\n家父長制度の復活をめざす\n旧統一教会、\n日本政策研究センター、\n日本会議、\nの価値観がほぼ同じ。… ',
#  ' @mydream555 脱原発、アイヌ、夫婦別姓、沖縄の海を綺麗に、辺りも全部胡散臭い ',
#  ' rt @pablichenkosssr: 教祖夫妻が別姓国出身で別姓だったのにそんなわけないじゃないですか。\nむしろ家族の解体を是とし、早い段階から別姓選択を可能にしていた共産主義国や社会主義国と夫婦別姓の方が関係ありますよ。 ',
#  ' @likedreply @stc_bp100 @eo8rmt2mkzu3eo6 @jackey81421082 @skw5tmkoc69kxma @aurxcanjyw3epxs @kurrymurry @yone147258369 侮辱罪と選択的夫婦別姓反対派に因果関係がない\n\nレイプ犯と決めつける行為と名誉毀損罪には因果関係がある\n\nこれの違いが分からないなら、これ以上はもう仕方ないですね（笑） ',
#  ' rt @id_seiron: 「具体例を出せ！具体例を出せ！」と言ってる選択的夫婦別姓推進派ほど出さない具体例\n\n改姓が原因で\n・キャリアを失った\n・論文の著作権を失った\n・資格を失った\n\n具体的な例は何一つ聞いたことがない（笑） ',
#  ' #国際勝共連合（#統一教会）と#自民党 の運動方針は同一です。\n\nジェンダーフリーや性教育の廃止\n(選択的)夫婦別姓の策動を阻止\n子供の人権政策の策動を阻止\n男女共同参画社会基本法の改廃\n憲法改正\n緊急事態条項制定\n日本版nscの設置\n集団的自衛権の行使容認\n非核三原則の改廃\n武器輸出三原則の改廃 https://t.co/dee7yaeoh3 ',
#  ' rt @5sasha5sasha5: 旧統一教会と政治の関係\u3000塚田穂高氏「国会で検証し国民に明示を」 | 毎日新聞 https://t.co/2zfggmnhdx 「夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新… ',
#  ' rt @v0hjjhorjfvm1nl: @seiryukai こんな連中が肩を持つような選択的夫婦別姓とは‥。\n「馬脚を現す」とは、まさにこのことか。 ',
#  ' rt @seiryukai: 選択的夫婦別姓反対街頭演説会を妨害してきた “しばき隊” 。夫婦別姓反対活動はレイシスト（人種差別主義者）で、言論はヘイトスピーチになるようだ。女性が身の危険を感じ警察へ通報。警察官が集結し刑事まで出動した。選択的夫婦別姓活動家と しばき隊 は繋が… ',
#  ' rt @pablichenkosssr: 統一教会と夫婦同姓よりよほど関係あります。社会主義国（旧含む）には早くから「男女平等」という観点から夫婦別姓可能だった国が少なくありません。\n夫婦別姓と共産主義あるいは社会主義は関係あるのか？｜dama s ptichkoy #note… ',
#  ' rt @5sasha5sasha5: 旧統一教会と政治の関係\u3000塚田穂高氏「国会で検証し国民に明示を」 | 毎日新聞 https://t.co/2zfggmnhdx 「夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新… ',
#  ' rt @hasegawakenjiro: ポリタスtvのおかげで山口さんの指摘が理解できる。\n\n特に憲法24条の改憲案は、夫婦別姓、同性婚、ジェンダーフリーを阻止する基礎になる。\n\n家父長制度の復活をめざす\n旧統一教会、\n日本政策研究センター、\n日本会議、\nの価値観がほぼ同じ。… ',
#  ' rt @sollevante2022: 表だって選択的夫婦別姓に反対している団体なんて\n神道政治連盟と幸福の科学、日本会議、\nそして統一教会くらいですね。\n\nほかにはもうないんじゃないかねえ。 ',
#  ' rt @302_3317: @reimu_marisa_y 夫婦別姓 ',
#  ' rt @haguruma0830: 多様な #家族のかたち として夫婦別姓も同性婚も、別姓推進弁護士が内縁妻の娘と不倫しようとも結構なのだけど(週刊誌記事だがグロテスク過ぎて私は嫌悪…)、結局それらを法律婚の範疇に加えることの目的や意味が不明なまま\n\n現行にてどれも国は禁止など… ',
#  ' rt @hasegawakenjiro: ポリタスtvのおかげで山口さんの指摘が理解できる。\n\n特に憲法24条の改憲案は、夫婦別姓、同性婚、ジェンダーフリーを阻止する基礎になる。\n\n家父長制度の復活をめざす\n旧統一教会、\n日本政策研究センター、\n日本会議、\nの価値観がほぼ同じ。… ',
#  ' @h_koyuyu 意味がよくわかりません。\n自分は夫婦別姓に賛成も反対もしてませんよ。 ',
#  ' rt @x2can3joy: 選択的夫婦別姓が一人歩きはしてません。\nむしろ、止めまれまくっています、不当な理由で。\n\n他の法案も含めて、賛否含めて、さっさと議論を進めればいいと考えてます。\n何十年と引きずっても、誰も得しません。(反対派すら時間の損) ',
#  ' 日本独自のカルト法作ればいいだけじゃん。\n他国で禁止の共産党というけど、他国で禁止されていない共産党でもある。意味がわからん。\nそんなに世界が気になるなら、ほぼ世界中で採用されている選択的夫婦別姓制度は大賛成ですよね（笑） https://t.co/cpfx2bfdyi ',
#  ' rt @hasegawakenjiro: ポリタスtvのおかげで山口さんの指摘が理解できる。\n\n特に憲法24条の改憲案は、夫婦別姓、同性婚、ジェンダーフリーを阻止する基礎になる。\n\n家父長制度の復活をめざす\n旧統一教会、\n日本政策研究センター、\n日本会議、\nの価値観がほぼ同じ。… ',
#  ' rt @hasegawakenjiro: ポリタスtvのおかげで山口さんの指摘が理解できる。\n\n特に憲法24条の改憲案は、夫婦別姓、同性婚、ジェンダーフリーを阻止する基礎になる。\n\n家父長制度の復活をめざす\n旧統一教会、\n日本政策研究センター、\n日本会議、\nの価値観がほぼ同じ。… ',
#  ' rt @t_iwagon: それ言ったら野党は夫婦別姓とか外国人参政権とか、他所の国とズブズブだと言ってるようなものでは・・・。 ',
#  ' rt @doremifamico: キモッ\n選択的夫婦別姓の旗振り役の弁護士が内縁の妻の娘(既婚者)と不倫、その他女性とも交際。\n\n結局は選択的夫婦別姓推進派の本当の目的は…\n女性への配慮じゃなくて、下半身のダラシナイ男(女)がパートナーを都合良く扱う為の手段じゃんよ。\n(知っ… ',
#  ' rt @5sasha5sasha5: 旧統一教会と政治の関係\u3000塚田穂高氏「国会で検証し国民に明示を」 | 毎日新聞 https://t.co/2zfggmnhdx 「夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新… ',
#  ' rt @wanpakuten: #サンモニ\n松原耕二氏\n「ただ共通するのは、家父長制的なある種伝統的な家族観。例えば自民党の一人は集会に出て同性婚には反対続けますと、ものの言い方も統一教会の考えを代弁しますと。つまりこれまで選択的夫婦別姓や同性婚の問題がなかなか進まなかったのは… ',
#  ' rt @hasegawakenjiro: ポリタスtvのおかげで山口さんの指摘が理解できる。\n\n特に憲法24条の改憲案は、夫婦別姓、同性婚、ジェンダーフリーを阻止する基礎になる。\n\n家父長制度の復活をめざす\n旧統一教会、\n日本政策研究センター、\n日本会議、\nの価値観がほぼ同じ。… ',
#  ' ポケットの有無で発狂してる奴、ほぼ夫婦別姓の連中でしょ、どーせ ',
#  ' rt @hasegawakenjiro: ポリタスtvのおかげで山口さんの指摘が理解できる。\n\n特に憲法24条の改憲案は、夫婦別姓、同性婚、ジェンダーフリーを阻止する基礎になる。\n\n家父長制度の復活をめざす\n旧統一教会、\n日本政策研究センター、\n日本会議、\nの価値観がほぼ同じ。… ',
#  ' rt @hasegawakenjiro: ポリタスtvのおかげで山口さんの指摘が理解できる。\n\n特に憲法24条の改憲案は、夫婦別姓、同性婚、ジェンダーフリーを阻止する基礎になる。\n\n家父長制度の復活をめざす\n旧統一教会、\n日本政策研究センター、\n日本会議、\nの価値観がほぼ同じ。… ',
#  ' rt @pablichenkosssr: 教祖夫妻が別姓国出身で別姓だったのにそんなわけないじゃないですか。\nむしろ家族の解体を是とし、早い段階から別姓選択を可能にしていた共産主義国や社会主義国と夫婦別姓の方が関係ありますよ。 ',
#  ' rt @hasegawakenjiro: ポリタスtvのおかげで山口さんの指摘が理解できる。\n\n特に憲法24条の改憲案は、夫婦別姓、同性婚、ジェンダーフリーを阻止する基礎になる。\n\n家父長制度の復活をめざす\n旧統一教会、\n日本政策研究センター、\n日本会議、\nの価値観がほぼ同じ。… ',
#  ' rt @hasegawakenjiro: ポリタスtvのおかげで山口さんの指摘が理解できる。\n\n特に憲法24条の改憲案は、夫婦別姓、同性婚、ジェンダーフリーを阻止する基礎になる。\n\n家父長制度の復活をめざす\n旧統一教会、\n日本政策研究センター、\n日本会議、\nの価値観がほぼ同じ。… ',
#  ' rt @5sasha5sasha5: 旧統一教会と政治の関係\u3000塚田穂高氏「国会で検証し国民に明示を」 | 毎日新聞 https://t.co/2zfggmnhdx 「夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新… ',
#  ' それはそうと夫婦別姓とか同性婚とかが進まないとか、その他の政治に関することが宗教の教義のせいだとしたら、がっかりというか、やるせないというか、憤りを感じますよね。 ',
#  ' rt @5sasha5sasha5: 旧統一教会と政治の関係\u3000塚田穂高氏「国会で検証し国民に明示を」 | 毎日新聞 https://t.co/2zfggmnhdx 「夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新… ',
#  ' @nabesan_go ・同性婚反対\n・夫婦別姓反対\nこんなのフェミとジェンダーの活動家しか興味無いわ。アンケートとったら、経済が関心のトップ。\nほとんどの国民にとってはどーでもいいから、やらないだけ。 ',
#  ' 夫婦別姓を認めないって保守というより統一教会だべ。保守の名のもと洗脳されんように🙏 ',
#  ' rt @seiryukai: 皆さん、ご協力をお願いします。\n選択的夫婦別姓反対街頭演説会を妨害したのも しばき隊 黒川氏 達です。\n#金井米穀店 への嫌がらせ証拠保全をして反日活動に対抗準備をしましょう。 ',
#  ' @kikumaco 同感です。\n韓国では絶対的夫婦別姓なのに\n韓国の教団が選択制すら反対するのも\n変ですよね。\nむしろ自民の考えに教団が寄せたと\n考えるほうが自然です。 ',
#  ' rt @5sasha5sasha5: 旧統一教会と政治の関係\u3000塚田穂高氏「国会で検証し国民に明示を」 | 毎日新聞 https://t.co/2zfggmnhdx 「夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新… ',
#  ' rt @pablichenkosssr: 教祖夫妻が別姓国出身で別姓だったのにそんなわけないじゃないですか。\nむしろ家族の解体を是とし、早い段階から別姓選択を可能にしていた共産主義国や社会主義国と夫婦別姓の方が関係ありますよ。 https://t.co/wtn9uidwpq ',
#  ' rt @5sasha5sasha5: 旧統一教会と政治の関係\u3000塚田穂高氏「国会で検証し国民に明示を」 | 毎日新聞 https://t.co/2zfggmnhdx 「夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新… ',
#  ' rt @gun81288955: じゃぁ⬇️招待状に選択的夫婦別姓講演有りと告知しなよ😜👎 祝いの席に反対の人からすれば地獄に決まってんだろ…自分が招待された式で選択的夫婦別姓反対講演あったらキレるだろww\n#選択的夫婦別姓反対\n#夫婦親子家族バラバラ別姓反対 ',
#  ' 「夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな「共産主義」的価値観として敵視」 https://t.co/7x62fypvbv ',
#  ' rt @kenkenrokujapan: 一部の人たちが騒いでいる選択的夫婦別姓ですが、岡山県議会で反対の意見書が可決されましたね。\n\nこうした良識ある地方議会には頑張って欲しいものです。\n\n#選択的夫婦別姓\n\n選択的夫婦別姓制度の反対意見書を可決\u3000岡山県議会 \nhttps:/… ',
#  ' rt @japanculture113: 国民民主党支持者とは考えの違いはあるけど、議論になっていい感じ。私は自民党保守派支持ではあるけど、経済政策がいいので、国民民主党を評価してる。ただ夫婦別姓や同性婚に反対の立場なのでそこが勿体ない。 ',
#  ' 国葬なんて、国民は関心ない。\nモリカケなんて、国民は関心ない。\n選択的夫婦別姓なんて、国民は関心ない。\n\u3000\n何を言うのも自由な国です。 https://t.co/adihmyqv5z ',
#  ' rt @5sasha5sasha5: 旧統一教会と政治の関係\u3000塚田穂高氏「国会で検証し国民に明示を」 | 毎日新聞 https://t.co/2zfggmnhdx 「夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新… ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' @daboso 選択的夫婦別姓制度は、改姓の不利益をなくす制度。\n「夫婦のどちらも改姓しないですむ」ことがメリットとして求められているので、\n新しい氏を作るのでは、デメリットが二倍になってしまいます。\n\nそれでも創姓がいいという方は、それは独自に運動すればいいのでは。 ',
#  ' 国民民主党支持者とは考えの違いはあるけど、議論になっていい感じ。私は自民党保守派支持ではあるけど、経済政策がいいので、国民民主党を評価してる。ただ夫婦別姓や同性婚に反対の立場なのでそこが勿体ない。 ',
#  ' rt @7znv478zu8tnswj: 特アの為に働く人々の仕事ぶりをがこれ\n\n👉日本人のみ罰する川崎市ヘイトスピーチ条例\n👉上海電力のステルス参入\n👉戸籍廃止論\n👉都構想住民投票で帰化を促す\n👉女系天皇推進\n👉夫婦別姓推進\n👉イージスアショア廃止\n👉外国人犯罪者を入管施設か… ',
#  ' rt @cn10013: @k736bfmbtcdgisz 夫婦別姓による差別の証です？\nhttps://t.co/vbkl76teao ',
#  ' rt @kenkenrokujapan: 一部の人たちが騒いでいる選択的夫婦別姓ですが、岡山県議会で反対の意見書が可決されましたね。\n\nこうした良識ある地方議会には頑張って欲しいものです。\n\n#選択的夫婦別姓\n\n選択的夫婦別姓制度の反対意見書を可決\u3000岡山県議会 \nhttps:/… ',
#  ' 「世界に合わせろ」と「選択的夫婦別姓」を推してる方々は、「外国人参政権」という、世界に類を見ない事をやろうとしてる方々には、何か言わねぇんだべが？\n\nまぁ、別な動機なら言わなくてもいいけども…「世界に合わせろ」なんて引っ込めてくれんかね。 ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' 夫婦別姓、別に賛成でも反対でもないんだけど、変更する方だけ面倒くさいのは不公平感ある。 ',
# ...
#  ' rt @nana77rey1: いわゆるリーダー層を排出する中高一貫男子校の社会科で、「関心のある社会課題を自分で見つけてインタビューしよう」という宿題。\n毎年必ず数名「選択的夫婦別姓について聞かせてください」という取材申し込みがあります。\n絶対に時間は作ります。だから同じテー… ',
#  ' rt @nauciccafe: @yukioiokibe @xxcalmo 嘘をつく事に本当に長けている自民党「統一教会」所属の山谷、下村、茂木。山谷の選択的夫婦別姓反対は、統一教会の「意」を組んでる。下村は統一教会の「名称変更」に権力濫用。茂木は自民党とは関係ないと「大嘘」。… ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' rt @nana77rey1: いわゆるリーダー層を排出する中高一貫男子校の社会科で、「関心のある社会課題を自分で見つけてインタビューしよう」という宿題。\n毎年必ず数名「選択的夫婦別姓について聞かせてください」という取材申し込みがあります。\n絶対に時間は作ります。だから同じテー… ',
#  ' rt @chizurua1: 選択制夫婦別姓や同性婚の成立を反対する理由として、「家庭」「家族」の価値を強調されると、違和感しかない。そこが愛情を育むための居場所としてではなく、封建主義を維持する役割を期待しているから。 ',
#  ' rt @nana77rey1: いわゆるリーダー層を排出する中高一貫男子校の社会科で、「関心のある社会課題を自分で見つけてインタビューしよう」という宿題。\n毎年必ず数名「選択的夫婦別姓について聞かせてください」という取材申し込みがあります。\n絶対に時間は作ります。だから同じテー… ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' rt @floria_mint: 「自民党とはズブズブ」旧統一教会との関係が明るみに\u3000政治家には魅力的な「選挙支援」 https://t.co/qzhi0obz1r ←「旧統一教会は同性婚や夫婦別姓などについて『家庭の秩序を乱す』と反対している。考えが近い議員を支援して、その政… ',
#  ' rt @mi89s1: 私もそう思います。山谷えり子議員の父、山谷親平氏はラジオの電話相談で、何度も相談者の置かれた実態を無視して古い家庭の在り方を説いていましたが、娘も同じで、日本会議懇談会役員で、古い家庭観の押し付け、自民内の夫婦別姓の動きを抑えました。なぜ、統一教会とつな… ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' 山谷、諸悪の根源。選択的夫婦別姓や同性婚に賛成してみろ。\n#安倍晋三氏の国葬に反対します https://t.co/mdergcpay1 ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' rt @foryourinforma: 干されていたって、安倍氏と尾辻氏の考え方の違いから採用されていなかったってことじゃん。\n\n尾辻氏は選択的夫婦別姓に賛成だったし、tppへの参加も反対だったし、核についての考えも違っていた。\n民間だって社長の方針と違う人は登用されないでしょ… ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' 安倍元首相銃撃事件が炙り出した選択的夫婦別姓、同性婚が「論外」とされる理由 https://t.co/s5jh3tjkpa ',
#  ' rt @higuras2018: 戸籍は明治5年から始まった\n世界最高の身分登録制度で\n\n除籍簿は明治１９年頃から\n保存されています\n\nこの制度は大多数の日本人に\n支持されており\n\n改悪は絶対にダメです\n\n夫婦別姓の主張はこの制度を\n破壊するための… ',
#  ' rt @nana77rey1: いわゆるリーダー層を排出する中高一貫男子校の社会科で、「関心のある社会課題を自分で見つけてインタビューしよう」という宿題。\n毎年必ず数名「選択的夫婦別姓について聞かせてください」という取材申し込みがあります。\n絶対に時間は作ります。だから同じテー… ',
#  ' rt @ssimtok: 旧統一教会は「家族や性的『純潔』を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティーへの理解といった動向を新たな『共産主義』的価値観として敵視するように」→\nhttps://t.co/4aaif6… ',
#  ' rt @nana77rey1: いわゆるリーダー層を排出する中高一貫男子校の社会科で、「関心のある社会課題を自分で見つけてインタビューしよう」という宿題。\n毎年必ず数名「選択的夫婦別姓について聞かせてください」という取材申し込みがあります。\n絶対に時間は作ります。だから同じテー… ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' rt @mi89s1: 私もそう思います。山谷えり子議員の父、山谷親平氏はラジオの電話相談で、何度も相談者の置かれた実態を無視して古い家庭の在り方を説いていましたが、娘も同じで、日本会議懇談会役員で、古い家庭観の押し付け、自民内の夫婦別姓の動きを抑えました。なぜ、統一教会とつな… ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' rt @nana77rey1: いわゆるリーダー層を排出する中高一貫男子校の社会科で、「関心のある社会課題を自分で見つけてインタビューしよう」という宿題。\n毎年必ず数名「選択的夫婦別姓について聞かせてください」という取材申し込みがあります。\n絶対に時間は作ります。だから同じテー… ',
#  ' rt @ppsh41_1945: 自民党の杉田水脈議員は「保育所や学童保育は共産主義による洗脳の場であり、夫婦別姓やlgbt支援とセットで日本の家族を崩壊させようとしている」などと主張していたけど、子供を教団側に置きたがる統一教会の教義と全く同じなんだよね。\n\nもはや統一教会関… ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' rt @yaqywfry8w03ayt: @nipponichi8 @sankei_news 文春によると、これを主導した田村琢実氏は稲田朋美氏と繋がっており、国政を狙っているらしい。\nオマケに「しんぶん赤旗」では選択的夫婦別姓について田村氏の発言が取り上げられております⚠️… ',
#  ' 中国や朝鮮は夫婦別姓であり、子供は否応なく夫である父親の姓に入る。つまり妻である母親は「家系には入れない」「（父方の姓を名乗ることになる）子供を生むだけ」という女性へのトンでもない差別的な制度が（中国・朝鮮方式の）夫婦別姓なのである。 ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' rt @nwfle6q9vqtxb4q: 井田ppiの偏見がここまでとは、、、。\n選択的夫婦別姓に反対してる人って、そもそも結婚してる人にも多いよね。結婚して子供を育てた経験から、高齢の方ほど反対が多くなっていたりは、前からなのよ。\n選択的夫婦別姓推進派は自分のことしか考えてな… ',
#  ' 安倍元首相銃撃事件が炙り出した選択的夫婦別姓、同性婚が「論外」とされる理由 https://t.co/ahgrkjf7to ',
#  ' みんなからの匿名質問を募集中！\n\nこんな質問に答えてるよ\n● 以前バトってから密かにファンで…\n● アイコンの画像はご本人ですか？\n● 夫婦別姓バトル・・・長いです…\n● ご本人はフサフサですか？\n#質問箱 #匿名質問募集中\n\nhttps://t.co/8nwcewzspa ',
#  ' 安倍元首相銃撃事件が炙り出した選択的夫婦別姓、同性婚が「論外」とされる理由 https://t.co/wp2kyyzbpc | ハフポスト日本版 #ハフポスト日本版 ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' rt @mi89s1: 私もそう思います。山谷えり子議員の父、山谷親平氏はラジオの電話相談で、何度も相談者の置かれた実態を無視して古い家庭の在り方を説いていましたが、娘も同じで、日本会議懇談会役員で、古い家庭観の押し付け、自民内の夫婦別姓の動きを抑えました。なぜ、統一教会とつな… ',
#  ' 安倍元首相銃撃事件が炙り出した選択的夫婦別姓、同性婚が「論外」とされる理由 https://t.co/0v9s0tqqgk ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' rt @chizurua1: 選択制夫婦別姓や同性婚の成立を反対する理由として、「家庭」「家族」の価値を強調されると、違和感しかない。そこが愛情を育むための居場所としてではなく、封建主義を維持する役割を期待しているから。 ',
#  ' rt @aokitonko: んで、この女が、夫婦別姓、同性愛婚姻を潰してきた中心人物。 ',
#  ' rt @mi89s1: 私もそう思います。山谷えり子議員の父、山谷親平氏はラジオの電話相談で、何度も相談者の置かれた実態を無視して古い家庭の在り方を説いていましたが、娘も同じで、日本会議懇談会役員で、古い家庭観の押し付け、自民内の夫婦別姓の動きを抑えました。なぜ、統一教会とつな… ',
#  ' rt @gun81288955: まぁ…😂ww ⬇️青木理に理解示すのがよーく分かるw #選択的夫婦別姓 派はパヨクだしなw\n⬇️コレは何の宗教🤢⁇w 選択的夫婦別姓の旗振りなんだが⁇\n#選択的夫婦別姓反対\n#選択的夫婦別姓派の多様性 https://t.co/8wffx3jj… ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' rt @timeformachine_: 選択式夫婦別姓や同性婚反対の旗振り役ですね、山谷えり子さん\n何度も自民党内の議論を潰してる人 https://t.co/l1mmcmrwzz ',
#  ' rt @mi89s1: 私もそう思います。山谷えり子議員の父、山谷親平氏はラジオの電話相談で、何度も相談者の置かれた実態を無視して古い家庭の在り方を説いていましたが、娘も同じで、日本会議懇談会役員で、古い家庭観の押し付け、自民内の夫婦別姓の動きを抑えました。なぜ、統一教会とつな… ',
#  ' rt @hosakanobuto: 旧統一教会と政治の関係\u3000塚田穂高氏「国会で検証し国民に明示を」  毎日https://t.co/umk5tebl2a 家族や性的「純潔」を重視する教えから、夫婦別姓や性教育、ジェンダーフリー、男女共同参画、同性婚、lgbtなど性的マイノリティ… ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' rt @yasu_yasuno_sa: 「夫婦別姓は福音か」統一教会-世界日報 ２００１年１１月\n山谷えり子 西川京子 橋本聖子 中本太衛 田尾憲男 http://t.co/15jddmpfgj ',
#  ' これが許されて選択制夫婦別姓が許されないのがよくわからない…… https://t.co/sq4vqe7gx0 ',
#  ' rt @kenkenrokujapan: 選択的夫婦別姓で活動する理由は「家に従属する女」という呪いを断ち切るためだそうです。\n\n何ですかこれ？\n\nこんな理由に自民党は協力するのですか？\n\n#選択的夫婦別姓 #自民党 @jimin_koho https://t.co/ywuuj… ',
#  ' rt @nana77rey1: いわゆるリーダー層を排出する中高一貫男子校の社会科で、「関心のある社会課題を自分で見つけてインタビューしよう」という宿題。\n毎年必ず数名「選択的夫婦別姓について聞かせてください」という取材申し込みがあります。\n絶対に時間は作ります。だから同じテー… ',
#  ' rt @seiryukai: 夫婦別姓反対街頭演説会を妨害し、米店へ営業妨害的行為をした しばき隊の黒川氏から繋がった日本基督教団。その関連として日本キリスト教協議会があった。団体の総幹事は在日大韓基督教会である。系図では、社民党．立憲民主党の辻本清美氏．北朝鮮政府へと繋がる。… ',
#  ' 安倍元首相銃撃事件が炙り出した選択的夫婦別姓、同性婚が「論外」とされる理由 https://t.co/dxsrlkr26j ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' rt @pucho611: この署名活動の発起人は\n斉藤恵\u3000と言うbba。\n宇都宮を支持してるが、\n\n宇都宮隆とは…\n都庁前に慰安婦像設置を公言\n選択制夫婦別姓制度を支持\n東京五輪開催中止の署名発起人\n\n新韓じゃん🤮\n\n#安倍元首相銃撃 https://t.co/loj0iaa… ',
#  ' 国民に分かりやすいように、今すぐ選択的夫婦別姓と同性婚の実現をしていただきたいと思います。\nそれならとりあえず国民もそれなりに納得できる、ということで。 https://t.co/kl0herp9mr ',
#  ' #私は聞きたい沖縄県知事選\n\n①同性婚の法制化に賛成しますか？賛成しない場合はその理由をお聞かせ下さい。\n②選択的夫婦別姓制度の導入に賛成しますか？賛成しない場合はその理由を教えて下さい。\n\n壺候補者はこの質問に回答できないだろう。宗教的理由以外に合理的な反対理由が存在しないから。 ',
#  ' rt @mi89s1: 私もそう思います。山谷えり子議員の父、山谷親平氏はラジオの電話相談で、何度も相談者の置かれた実態を無視して古い家庭の在り方を説いていましたが、娘も同じで、日本会議懇談会役員で、古い家庭観の押し付け、自民内の夫婦別姓の動きを抑えました。なぜ、統一教会とつな… ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' rt @chizurua1: 選択制夫婦別姓や同性婚の成立を反対する理由として、「家庭」「家族」の価値を強調されると、違和感しかない。そこが愛情を育むための居場所としてではなく、封建主義を維持する役割を期待しているから。 ',
#  ' rt @seiryukai: 選択的夫婦別姓反対街頭演説会を妨害してきた “しばき隊” 。夫婦別姓反対活動はレイシスト（人種差別主義者）で、言論はヘイトスピーチになるようだ。女性が身の危険を感じ警察へ通報。警察官が集結し刑事まで出動した。選択的夫婦別姓活動家と しばき隊 は繋が… ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' rt @55hawaiicondo: @yukioiokibe 選択的夫婦別姓さえも拒む女性議員。誰のためか？ ',
#  ' rt @foryourinforma: 干されていたって、安倍氏と尾辻氏の考え方の違いから採用されていなかったってことじゃん。\n\n尾辻氏は選択的夫婦別姓に賛成だったし、tppへの参加も反対だったし、核についての考えも違っていた。\n民間だって社長の方針と違う人は登用されないでしょ… ',
#  ' rt @higuras2018: 戸籍は明治5年から始まった\n世界最高の身分登録制度で\n\n除籍簿は明治１９年頃から\n保存されています\n\nこの制度は大多数の日本人に\n支持されており\n\n改悪は絶対にダメです\n\n夫婦別姓の主張はこの制度を\n破壊するための… ',
#  ' rt @yaponluq: ウイグルを応援する全国地方議員の会の参加議員のうち三人がウイグル系候補不支持を表明。夫婦別姓や気候変動にふれたことが理由。在日ウイグル人の多くが候補に期待しているのにだ。地方議員がね、市議なんかがね、国政に出ようとするウイグル系候補不支持をわざわざ表… ',
#  ' rt @mi89s1: 私もそう思います。山谷えり子議員の父、山谷親平氏はラジオの電話相談で、何度も相談者の置かれた実態を無視して古い家庭の在り方を説いていましたが、娘も同じで、日本会議懇談会役員で、古い家庭観の押し付け、自民内の夫婦別姓の動きを抑えました。なぜ、統一教会とつな… ',
#  ' rt @mi89s1: 私もそう思います。山谷えり子議員の父、山谷親平氏はラジオの電話相談で、何度も相談者の置かれた実態を無視して古い家庭の在り方を説いていましたが、娘も同じで、日本会議懇談会役員で、古い家庭観の押し付け、自民内の夫婦別姓の動きを抑えました。なぜ、統一教会とつな… ',
#  ' ウイグルを応援する全国地方議員の会の参加議員のうち三人がウイグル系候補不支持を表明。夫婦別姓や気候変動にふれたことが理由。在日ウイグル人の多くが候補に期待しているのにだ。地方議員がね、市議なんかがね、国政に出ようとするウイグル系候補不支持をわざわざ表明するのはなぜだろうねぇ。 ',
#  ' 民主党時代は夫婦別姓選択制度を推進してたのに、自民党に入ると一変\nこんないい加減な議員の言う事なんか信じられるかい😡 https://t.co/aerltojwbb https://t.co/0tb0agkgpm ',
#  ' rt @chizurua1: 選択制夫婦別姓や同性婚の成立を反対する理由として、「家庭」「家族」の価値を強調されると、違和感しかない。そこが愛情を育むための居場所としてではなく、封建主義を維持する役割を期待しているから。 ',
#  ' rt @foryourinforma: 干されていたって、安倍氏と尾辻氏の考え方の違いから採用されていなかったってことじゃん。\n\n尾辻氏は選択的夫婦別姓に賛成だったし、tppへの参加も反対だったし、核についての考えも違っていた。\n民間だって社長の方針と違う人は登用されないでしょ… ',
#  ' 『「家族のあり方」という問題で捉えれば、別問題ということは有り得ないんだが？』\n\nまずは自分がこれについて論理的に説明したら？\n選択的夫婦別姓と創姓と家族のあり方について論じなさい(文字数制限なし) https://t.co/o7xr7r8n94 ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' rt @higuras2018: 戸籍は明治5年から始まった\n世界最高の身分登録制度で\n\n除籍簿は明治１９年頃から\n保存されています\n\nこの制度は大多数の日本人に\n支持されており\n\n改悪は絶対にダメです\n\n夫婦別姓の主張はこの制度を\n破壊するための… ',
#  ' rt @mi89s1: 私もそう思います。山谷えり子議員の父、山谷親平氏はラジオの電話相談で、何度も相談者の置かれた実態を無視して古い家庭の在り方を説いていましたが、娘も同じで、日本会議懇談会役員で、古い家庭観の押し付け、自民内の夫婦別姓の動きを抑えました。なぜ、統一教会とつな… ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' rt @mi89s1: 私もそう思います。山谷えり子議員の父、山谷親平氏はラジオの電話相談で、何度も相談者の置かれた実態を無視して古い家庭の在り方を説いていましたが、娘も同じで、日本会議懇談会役員で、古い家庭観の押し付け、自民内の夫婦別姓の動きを抑えました。なぜ、統一教会とつな… ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' rt @nana77rey1: いわゆるリーダー層を排出する中高一貫男子校の社会科で、「関心のある社会課題を自分で見つけてインタビューしよう」という宿題。\n毎年必ず数名「選択的夫婦別姓について聞かせてください」という取材申し込みがあります。\n絶対に時間は作ります。だから同じテー… ',
#  ' rt @mi89s1: 私もそう思います。山谷えり子議員の父、山谷親平氏はラジオの電話相談で、何度も相談者の置かれた実態を無視して古い家庭の在り方を説いていましたが、娘も同じで、日本会議懇談会役員で、古い家庭観の押し付け、自民内の夫婦別姓の動きを抑えました。なぜ、統一教会とつな… ',
#  ' rt @chizurua1: 選択制夫婦別姓や同性婚の成立を反対する理由として、「家庭」「家族」の価値を強調されると、違和感しかない。そこが愛情を育むための居場所としてではなく、封建主義を維持する役割を期待しているから。 ',
#  ' https://t.co/mwexi4egac\n去年八月、当時の自民党政調会長に「ウイグル人らへの帰化・査証手続きの弾力対応」を要望した小坪慎也先生。\nその先生だが、参院選に出馬したウイグル系候補が夫婦別姓に賛成の姿勢を示すと「我が国の国家制度に、帰化一世に言及される謂れはない」と露骨な差別発言。 ',
#  ' rt @mi89s1: 私もそう思います。山谷えり子議員の父、山谷親平氏はラジオの電話相談で、何度も相談者の置かれた実態を無視して古い家庭の在り方を説いていましたが、娘も同じで、日本会議懇談会役員で、古い家庭観の押し付け、自民内の夫婦別姓の動きを抑えました。なぜ、統一教会とつな… ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' rt @aokitonko: んで、この女が、夫婦別姓、同性愛婚姻を潰してきた中心人物。 ',
#  ' 安倍政権以降、嘘つき放題・ご飯論法で誤魔化し答弁・何でもかんでも閣議決定・知らなかった等、ヤバいなと思ってたら、憲法改正・選択的夫婦別姓反対・同性婚反対等、世界と逆行する自民党になった。\n今考えると、旧統一教会と繋がっていたからだと納得した。\n\n#自民党って統一教会だったんだな ',
#  ' rt @code_dia: @epj8ifbqej8ei6h @oriak9 選択肢は既に在りますよね？\n\n選択的夫婦別姓運動は、\n殆どニーズの無い事への更なる権利要求運動です。\n\n特殊な選択なりの権利が見合っているから、\nこれ以上の引き上げは要らないって言うのが、\n国民の選択… ',
#  ' rt @higuras2018: 戸籍は明治5年から始まった\n世界最高の身分登録制度で\n\n除籍簿は明治１９年頃から\n保存されています\n\nこの制度は大多数の日本人に\n支持されており\n\n改悪は絶対にダメです\n\n夫婦別姓の主張はこの制度を\n破壊するための… ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' 干されていたって、安倍氏と尾辻氏の考え方の違いから採用されていなかったってことじゃん。\n\n尾辻氏は選択的夫婦別姓に賛成だったし、tppへの参加も反対だったし、核についての考えも違っていた。\n民間だって社長の方針と違う人は登用されないでしょ。\nhttps://t.co/shyqkhzlsi ',
#  ' rt @mi89s1: 私もそう思います。山谷えり子議員の父、山谷親平氏はラジオの電話相談で、何度も相談者の置かれた実態を無視して古い家庭の在り方を説いていましたが、娘も同じで、日本会議懇談会役員で、古い家庭観の押し付け、自民内の夫婦別姓の動きを抑えました。なぜ、統一教会とつな… ',
#  ' rt @mi89s1: 私もそう思います。山谷えり子議員の父、山谷親平氏はラジオの電話相談で、何度も相談者の置かれた実態を無視して古い家庭の在り方を説いていましたが、娘も同じで、日本会議懇談会役員で、古い家庭観の押し付け、自民内の夫婦別姓の動きを抑えました。なぜ、統一教会とつな… ',
#  ' @yukioiokibe @xxcalmo 嘘をつく事に本当に長けている自民党「統一教会」所属の山谷、下村、茂木。山谷の選択的夫婦別姓反対は、統一教会の「意」を組んでる。下村は統一教会の「名称変更」に権力濫用。茂木は自民党とは関係ないと「大嘘」。総裁のアベが総理在任中含めて広告塔やってたのに、関係ないだとよ。この嘘つきども ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' rt @hanamiz01467525: おや、これはすごいバトルが。\n今まで選択的夫婦別姓を目の敵にしていた海乱鬼氏も、統一教会擁護ということで。\n実にわかりやすいですね。 ',
#  ' rt @chizurua1: 選択制夫婦別姓や同性婚の成立を反対する理由として、「家庭」「家族」の価値を強調されると、違和感しかない。そこが愛情を育むための居場所としてではなく、封建主義を維持する役割を期待しているから。 ',
#  ' rt @aokitonko: んで、この女が、夫婦別姓、同性愛婚姻を潰してきた中心人物。 ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' rt @mi89s1: 私もそう思います。山谷えり子議員の父、山谷親平氏はラジオの電話相談で、何度も相談者の置かれた実態を無視して古い家庭の在り方を説いていましたが、娘も同じで、日本会議懇談会役員で、古い家庭観の押し付け、自民内の夫婦別姓の動きを抑えました。なぜ、統一教会とつな… ',
#  ' rt @chizurua1: 選択制夫婦別姓や同性婚の成立を反対する理由として、「家庭」「家族」の価値を強調されると、違和感しかない。そこが愛情を育むための居場所としてではなく、封建主義を維持する役割を期待しているから。 ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ' rt @yamtom: 話題の井上義行議員、この動画でも家庭教育を推し、別姓に反対しているな。\n安倍総理の元首席秘書官・井上よしゆき（義行）、家庭教育と夫婦別姓を語る https://t.co/s49nwrboei @youtubeより ',
#  ' rt @seiryukai: 選択的夫婦別姓反対街頭演説会を妨害してきた “しばき隊” 。夫婦別姓反対活動はレイシスト（人種差別主義者）で、言論はヘイトスピーチになるようだ。女性が身の危険を感じ警察へ通報。警察官が集結し刑事まで出動した。選択的夫婦別姓活動家と しばき隊 は繋が… ',
#  ' rt @x2can3joy: 「選択的夫婦別姓」弁護士による解説本が登場\u3000反対論につながる誤解を解くｑ＆ａも：東京新聞 tokyo web https://t.co/psbczzwzcf \n\n届いたので読んでます♪\nまだ途中までしか読めていませんが、中々読みやすいです😊 ',
#  ' rt @aokitonko: んで、この女が、夫婦別姓、同性愛婚姻を潰してきた中心人物。 ',
#  ' rt @oriak9: 選択的夫婦別姓の話に現れる「夫婦同姓がいい人はどうするんですか！？」、ハイヒール強制やめようの話に現れる「ハイヒール履きたい人はどうすればいいんですか！？」、女性服のポケットの話に現れる「ドレスが着たい人は…」自分で選択しよっか ',
#  ...]

# %%
final = []

tweets = [t.split('@') for t in tweets] #splits each tweet along @s
for n,chunk in enumerate(tweets):
    ment_users = [t[:re.search('[^A-Za-z0-9_]',t).start()].lower().strip() for t in chunk if re.search('[^A-Za-z0-9_]',t) is not None]
    final.extend([[authors[n],name] for name in ment_users if len(name.strip()) > 0])

# %%
final
# Out:
# [['atm09rs', '5sasha5sasha5'],
#  ['ipppen', 'ssimtok'],
#  ['hiro_npwr', 'ssimtok'],
#  ['subaru1000', 'sabutibi777'],
#  ['mumumu_fz', 'seiryukai'],
#  ['nakani_kazuto', 'hosakanobuto'],
#  ['kamechan501030', 'aiko33151709'],
#  ['aohanekosuki2', '2kuow'],
#  ['takapee100', 'sollevante2022'],
#  ['cleardrop_1202', 'sollevante2022'],
#  ['kazukazu881', 'ssimtok'],
#  ['bamunomama', 'ssimtok'],
#  ['ogntom', 'kakitama'],
#  ['etsukokamimura', 'aiko33151709'],
#  ['kamayan1192', 'ssimtok'],
#  ['l41wx4sgtg530fx', 'kenkenrokujapan'],
#  ['highflyflo', 'gun81288955'],
#  ['endymiongtx', 'seiryukai'],
#  ['nntfjoxmaglzc72', 'edokaiki'],
#  ['peekaboo_929', 'nemuribi'],
#  ['ank_only', 'sollevante2022'],
#  ['tsubaki_tsubomi', 'ssimtok'],
#  ['highflyflo', '2kuow'],
#  ['ra100re', 'kenkenrokujapan'],
#  ['kisekioko', 'chiakitokai'],
#  ['kisekioko', 'matsukawa_rui'],
#  ['askayama', 'ssimtok'],
#  ['shobonnu_jp', 'seiryukai'],
#  ['iigeru', 'ssimtok'],
#  ['spearsden', 'ssimtok'],
#  ['masatsugu531', 'seiryukai'],
#  ['f9zs0thnfhkemxa', 'aiko33151709'],
#  ['suzumiya_na_gi', 'cafelattenaruto'],
#  ['suzumiya_na_gi', 'ts80115785'],
#  ['suzumiya_na_gi', 'sabutibi777'],
#  ['rqnf6s6nodtpweo', 'aiko33151709'],
#  ['5wzek4eh774kede', 'hasegawakenjiro'],
#  ['washwasabi', 'ssimtok'],
#  ['temmusu_n', 'nana77rey1'],
#  ['iqfruspyxbql0mr', 'seiryukai'],
#  ['ayaka_catlove', 'sen_yuui'],
#  ['falafalaalafa', 'tayosei_hosetsu'],
#  ['izk76950809', 'seiryukai'],
#  ['mitsuru80s', 'kenkenrokujapan'],
#  ['numa7tsmbrut3g9', 'akikuri'],
#  ['numa7tsmbrut3g9', 'onoderamasaru'],
#  ['numa7tsmbrut3g9', 'sankei_news'],
#  ['numa7tsmbrut3g9', 'bululunwagtail'],
#  ['sen_yuui', 'ayaka_catlove'],
#  ['do4i95atabukeyw', 'kenkenrokujapan'],
#  ['falafalaalafa', 'tayosei_hosetsu'],
#  ['x2can3joy', 'rockhearts737'],
#  ['honmasunmahen', 'hakofugu_net'],
#  ['mikizo360', 'edokaiki'],
#  ['nobukun1919', 'seiryukai'],
#  ['yucchi0i0', 'vnrespectfn'],
#  ['wrestling_luv', 'ssimtok'],
#  ['nuqa52', 'kenkenrokujapan'],
#  ['uai2vrhthtboauo', 'seiryukai'],
#  ['keezai849', 'kenkenrokujapan'],
#  ['exxruy0gjyq8dq8', '5sasha5sasha5'],
#  ['atkrsfszzrtqdcc', 'ssimtok'],
#  ['ijtyp98computer', 'kenkenrokujapan'],
#  ['starship_glory', 'kenkenrokujapan'],
#  ['mfrsw', 'kakitama'],
#  ['kenkenrokujapan', 'jimin_koho'],
#  ['ckfzq6dx7lmil9m', '7q3dsgoqopixflu'],
#  ['puinyuu1', 'ssimtok'],
#  ['qymrcqeswujksyv', 'seiryukai'],
#  ['bellmomo0', 'seiryukai'],
#  ['ftgu1ed5a03lpzh', 'kakitama'],
#  ['juliejulie2070', 'ssimtok'],
#  ['72_sabian', 'seiryukai'],
#  ['toshizoh01', 'seiryukai'],
#  ['ametalk2', 'edokaiki'],
#  ['nya_56_', 'gun81288955'],
#  ['jifbmdifz8foayo', 'edokaiki'],
#  ['450163', 'ssimtok'],
#  ['takeda6tomomk', 'seiryukai'],
#  ['si4syo40', 'ssimtok'],
#  ['teorema2019', 'ssimtok'],
#  ['akinire1', 'hasegawakenjiro'],
#  ['myca65212702_33', 'fukubonzzz'],
#  ['kogakawaiioya', 'ssimtok'],
#  ['japanculture113', 'gurugurugrass'],
#  ['kazunakei', 'ssimtok'],
#  ['yukimaru2200', 'ssimtok'],
#  ['onchan819', 'ssimtok'],
#  ['buhikun', 'kakitama'],
#  ['utakata73', 'ssimtok'],
#  ['taka_eha', 'seiryukai'],
#  ['melt_puraben', 'ssimtok'],
#  ['m7m5ea', 'ssimtok'],
#  ['jora_joraemon', 'ssimtok'],
#  ['t_malico', 'kenkenrokujapan'],
#  ['nglzufuhttvulr0', 'ssimtok'],
#  ['kousakukotani', 'ssimtok'],
#  ['haruka_1031', 'ssimtok'],
#  ['sharimeshi', 'ssimtok'],
#  ['ubotosor', 'seiryukai'],
#  ['takkyyfc', 'ssimtok'],
#  ['satz52170395', 'ssimtok'],
#  ['zensyorendeath', 'ssimtok'],
#  ['hopesai6', 'pablichenkosssr'],
#  ['jaqqo_carol', 'ssimtok'],
#  ['anfang0913', 'seiryukai'],
#  ['manaoflegend', 'ssimtok'],
#  ['kakitama', 'ssimtok'],
#  ['nichinichibijou', 'ssimtok'],
#  ['das_ituki', 'ssimtok'],
#  ['mygogoheaven', 'ssimtok'],
#  ['wgfzqrk2v6m90cl', 'seiryukai'],
#  ['pmsanvv', 'sollevante2022'],
#  ['syohani', 'seiryukai'],
#  ['888moko', 'nipponichi8'],
#  ['motobuch1228', 'sollevante2022'],
#  ['kumaani_hosi', 'seiryukai'],
#  ['mtmt29547371', 'id_seiron'],
#  ['yu_kotyan', '5sasha5sasha5'],
#  ['yb7vz', 'seiryukai'],
#  ['sibasibatales', 'seiryukai'],
#  ['w1tbjaxhqquxcwt', 'seiryukai'],
#  ['hakutsuru_ef81', 'kakitama'],
#  ['yataga33ss', 'jn_lyio'],
#  ['yucchi0i0', 'suzumiya_na_gi'],
#  ['saya_fairyland', 'x2can3joy'],
#  ['lesfw7surawxotb', 'uyoel2103'],
#  ['lesfw7surawxotb', 'sankei_news'],
#  ['daisukeasano4', 'yuki_3_3837'],
#  ['coco51700859', 'seiryukai'],
#  ['makeakala', 'oriak9'],
#  ['lematin', 'kakitama'],
#  ['shizuku_acc', 'seiryukai'],
#  ['buhikun', 'kakitama'],
#  ['higuras2018', 'kenkenrokujapan'],
#  ['chocolatebisco', 'seiryukai'],
#  ['bigiland1000', 'seiryukai'],
#  ['2021puraim', '5sasha5sasha5'],
#  ['tenmachou', 'nabesan_go'],
#  ['2021puraim', 'besseibot'],
#  ['cafelattenaruto', 'na7719961212'],
#  ['cafelattenaruto', 'sabutibi777'],
#  ['hamastar_yb', 'seiryukai'],
#  ['myca65212702_33', 'kenkenrokujapan'],
#  ['myca65212702_33', 'jimin_koho'],
#  ['taresan696', 'seiryukai'],
#  ['c0109k0706', 'seiryukai'],
#  ['6aqeqvfeycptwp5', 'seiryukai'],
#  ['paco962', 'powertopeople5'],
#  ['akasaka7777', 'seiryukai'],
#  ['paco962', 'powertopeople5'],
#  ['momotan_san', 'seiryukai'],
#  ['mkhqrwqzq3nrwik', 'seiryukai'],
#  ['paco962', 'emma78004812'],
#  ['youkanman_t', 'hnr5utvhipxqs2v'],
#  ['youkanman_t', 'ozawa_jimusho'],
#  ['paco962', 'powertopeople5'],
#  ['araya_koraya', 'forthman'],
#  ['cotoco_to', 't_moonnight'],
#  ['paco962', '7q3dsgoqopixflu'],
#  ['paco962', 'chizurua1'],
#  ['gaimane', '5sasha5sasha5'],
#  ['sayamati', 'kakitama'],
#  ['rokotaro', 'japanculture113'],
#  ['kamodakyogoro04', 'bot73109026'],
#  ['sheryl_frontier', 'seiryukai'],
#  ['ozgao5pdi5c8nkt', 'seiryukai'],
#  ['aushi_34d', 'nabesan_go'],
#  ['yuuu129_', 'seiryukai'],
#  ['gnaphalium7', 'seiryukai'],
#  ['miyamaohmu', 'nabesan_go'],
#  ['livingstonjona5', 'starship_glory'],
#  ['erf26119', 'seiryukai'],
#  ['qap3515ii9bcvlg', 'seiryukai'],
#  ['yomibitoshirazu', 'seiryukai'],
#  ['na7719961212', 'cafelattenaruto'],
#  ['na7719961212', 'sabutibi777'],
#  ['letsgroovebyewf', 'seiryukai'],
#  ['miyudesuyo', 'seiryukai'],
#  ['mooniebuster', 'hasegawakenjiro'],
#  ['fair_gail', 'blackswan_tokyo'],
#  ['gnqnw92r1gtrqok', 'seiryukai'],
#  ['bdigxmatyjxctxm', 'yuki1988jp'],
#  ['hirorumi613115', 'seiryukai'],
#  ['kurumi5533', 'seiryukai'],
#  ['xnh51f03', 'seiryukai'],
#  ['dq4kiacbbpyetbk', 'l75bojocreiks0j'],
#  ['melon_11m', 'seiryukai'],
#  ['g_jaguar55', 'seiryukai'],
#  ['ohana64269649', 'seiryukai'],
#  ['happy3sapoko', 'hasegawakenjiro'],
#  ['moe_pippi0306', 'seiryukai'],
#  ['kemymma', 'seiryukai'],
#  ['omicco_', 'kakitama'],
#  ['nor_forest', 'seiryukai'],
#  ['m7m5ea', 'kakitama'],
#  ['mofu2022_1', 'seiryukai'],
#  ['3txrxqj1cka85mg', 'seiryukai'],
#  ['kali_izumi', 'hasegawakenjiro'],
#  ['kasuga_1006', 'seiryukai'],
#  ['biigata51', 'seiryukai'],
#  ['ccottepla', 'seiryukai'],
#  ['sunny5matsumoto', '5sasha5sasha5'],
#  ['zensyorendeath', 'kakitama'],
#  ['nihonnomanga', 'seiryukai'],
#  ['tsuyoshi7328266', 'seiryukai'],
#  ['mizog88', '5sasha5sasha5'],
#  ['abengers2', 'id_seiron'],
#  ['4ph4byvkdgtxprk', '5sasha5sasha5'],
#  ['1myvufflujbci2y', 'seiryukai'],
#  ['helter_skelterz', 'seiryukai'],
#  ['shibakabu4432', 'seiryukai'],
#  ['ikaryu', 'seiryukai'],
#  ['lahagiha', 'seiryukai'],
#  ['mk32nvz', 'seiryukai'],
#  ['l5qpwg1k3nngywj', '5sasha5sasha5'],
#  ['hankakusai5', 'seiryukai'],
#  ['nyanpippiiiii', 'seiryukai'],
#  ['guccikara373', 'seiryukai'],
#  ['t80005', 'seiryukai'],
#  ['norixono', 'seiryukai'],
#  ['ywa5cgccnzy3kv1', 'seiryukai'],
#  ['lemylove2', 'seiryukai'],
#  ['asujon2003', 'oosakahaoosaka'],
#  ['takosuke6351', 'chizurua1'],
#  ['kylieinjapan', 'seiryukai'],
#  ['3catkk', 'seiryukai'],
#  ['kenkenrokujapan', 'jimin_koho'],
#  ['greatest_1990', 'kei_nakazawa'],
#  ['lowlife4775', 'seiryukai'],
#  ['otgpwkhrggehwlp', 'seiryukai'],
#  ['kmhs_608', 'seiryukai'],
#  ['akasatagsje', 'seiryukai'],
#  ['nyoso10', 'seiryukai'],
#  ['r_miura2', 'hasegawakenjiro'],
#  ['poohkoc', 'seiryukai'],
#  ['choroi_silica', 'id_seiron'],
#  ['4prescote', 'hasegawakenjiro'],
#  ['gf9faqe8gunzlzl', 'seiryukai'],
#  ['dcauauryhen3iiv', 'seiryukai'],
#  ['aghessorel_21', 'seiryukai'],
#  ['nirvanayl', 'seiryukai'],
#  ['abkoumuin', 'seiryukai'],
#  ['hiro155562', 'seiryukai'],
#  ['dsince1969', 'moff70357636'],
#  ['atcfelgball', '5sasha5sasha5'],
#  ['_jagatendon', 'seiryukai'],
#  ['681n01sw', 'seiryukai'],
#  ['arigato_almeria', 'nwfle6q9vqtxb4q'],
#  ['fujikawa_no1', 'seiryukai'],
#  ['ayttepvkcrhyxwp', 'seiryukai'],
#  ['nipponkairagi', 'seiryukai'],
#  ['hiruandon89', '5sasha5sasha5'],
#  ['sxuw7h5koowsq6w', 'ifpesliwwpob4kt'],
#  ['jikkenfish', '5sasha5sasha5'],
#  ['1234ssaw', 'oriak9'],
#  ['amarjapon', 'ganrim_'],
#  ['wtks_com', 'hasegawakenjiro'],
#  ['yuru2biost', 'mrjombxev6xdu9c'],
#  ['bdxi4p6hdqxjuhk', 'aiko33151709'],
#  ['amarjapon', 'masterds2_3'],
#  ['matpice', 'oriak9'],
#  ['amarjapon', 'masterds2_3'],
#  ['xtsafrflyi6alkn', '5sasha5sasha5'],
#  ['jfnl_jfp', 'sabai_aruka'],
#  ['tarouzaemon1', 'solo_0505'],
#  ['tarouzaemon1', 'takeuchikumiffy'],
#  ['b87mb2z8fot9gmw', 'nabesan_go'],
#  ['hitokara_bushi', 'hasegawakenjiro'],
#  ['beefboofbuuf', '5sasha5sasha5'],
#  ['kero_genki', 'hasegawakenjiro'],
#  ['nonukono', 'hasegawakenjiro'],
#  ['ropurose', 'sabai_aruka'],
#  ['usyokasa', 'oriak9'],
#  ['f00tb0aller', 'hasegawakenjiro'],
#  ['cocochan000700', 'ahonotakao'],
#  ['hrky38665108', '5sasha5sasha5'],
#  ['l1pldmli4oigwmm', 'nwfle6q9vqtxb4q'],
#  ['blueblaubleue', 'ppsh41_1945'],
#  ['shiroan029', 'starship_glory'],
#  ['shiroan029', 'm3llsquc35qdao0'],
#  ['shiroan029', 'cosmicworld000'],
#  ['u___san', 'hasegawakenjiro'],
#  ['2kuow', 'nwfle6q9vqtxb4q'],
#  ['yog_s29', '5sasha5sasha5'],
#  ['starship_glory', 'starship_glory'],
#  ['starship_glory', 'm3llsquc35qdao0'],
#  ['starship_glory', 'cosmicworld000'],
#  ['shibanagame', '5sasha5sasha5'],
#  ['penewax', 'hasegawakenjiro'],
#  ['mypacek74', 'hasegawakenjiro'],
#  ['timtomtamtemtum', 'mydream555'],
#  ['nyantasista2019', 'pablichenkosssr'],
#  ['id_seiron', 'likedreply'],
#  ['id_seiron', 'stc_bp100'],
#  ['id_seiron', 'eo8rmt2mkzu3eo6'],
#  ['id_seiron', 'jackey81421082'],
#  ['id_seiron', 'skw5tmkoc69kxma'],
#  ['id_seiron', 'aurxcanjyw3epxs'],
#  ['id_seiron', 'kurrymurry'],
#  ['id_seiron', 'yone147258369'],
#  ['dread19782015', 'id_seiron'],
#  ['mk5qtl2lxxtyufm', '5sasha5sasha5'],
#  ['aidjr', 'v0hjjhorjfvm1nl'],
#  ['aidjr', 'seiryukai'],
#  ['aidjr', 'seiryukai'],
#  ['max6_6facter', 'pablichenkosssr'],
#  ['momofumi8', '5sasha5sasha5'],
#  ['mirumiruminai', 'hasegawakenjiro'],
#  ['litten_nyabby', 'sollevante2022'],
#  ['ts2dgvs4erctv6', '302_3317'],
#  ['ts2dgvs4erctv6', 'reimu_marisa_y'],
#  ['hatchfutch', 'haguruma0830'],
#  ['gnm_f', 'hasegawakenjiro'],
#  ['angelpie2010', 'h_koyuyu'],
#  ['rr22txanod', 'x2can3joy'],
#  ['4wjokurumi', 'hasegawakenjiro'],
#  ['michi4507', 'hasegawakenjiro'],
#  ['bibouroku25', 't_iwagon'],
#  ['kina87716696', 'doremifamico'],
#  ['x0maekpao9ogrsw', '5sasha5sasha5'],
#  ['2i4mjpeaxlqdkbv', 'wanpakuten'],
#  ['la_neige_fleur', 'hasegawakenjiro'],
#  ['dillo_dillo', 'hasegawakenjiro'],
#  ['banana_akakoura', 'hasegawakenjiro'],
#  ['yu_ku_yu_ku', 'pablichenkosssr'],
#  ['figgyduff2007', 'hasegawakenjiro'],
#  ['6dhsayf4pqzous7', 'hasegawakenjiro'],
#  ['biblicalko', '5sasha5sasha5'],
#  ['k9tzlpx2fd6imp7', '5sasha5sasha5'],
#  ['alsnova', 'nabesan_go'],
#  ['kallinnka', 'seiryukai'],
#  ['yjsg8', 'kikumaco'],
#  ['caka3636', '5sasha5sasha5'],
#  ['max6_6facter', 'pablichenkosssr'],
#  ['miri_1131', '5sasha5sasha5'],
#  ['hachikogumo', 'gun81288955'],
#  ['nakedshortsell', 'kenkenrokujapan'],
#  ['junzymalcobicch', 'japanculture113'],
#  ['hotaka_tsukada', '5sasha5sasha5'],
#  ['selfbehind', 'oriak9'],
#  ['sollevante2022', 'daboso'],
#  ['windskysumm', '7znv478zu8tnswj'],
#  ['harikyuinari', 'cn10013'],
#  ['harikyuinari', 'k736bfmbtcdgisz'],
#  ['ghyn6grxeequcpx', 'kenkenrokujapan'],
#  ['ssicbm', 'oriak9'],
#  ['xiezi_cocomo', '5sasha5sasha5'],
#  ['rm21329', 'gun81288955'],
#  ['kawataka_alter', 'oriak9'],
#  ['kita_mukai', 'oriak9'],
#  ['kantaroudenden', 'ten1998'],
#  ['kantaroudenden', 'moeruasia01'],
#  ['wgfzqrk2v6m90cl', 'gun81288955'],
#  ['amipunch', 'oriak9'],
#  ['yamatotakerui', 'doremifamico'],
#  ['h_koyuyu', 'kenkenrokujapan'],
#  ['ppxhezyhromxqoj', 'oosakahaoosaka'],
#  ['wgfzqrk2v6m90cl', 'gun81288955'],
#  ['id_seiron', 't_iwagon'],
#  ['rm21329', 'gun81288955'],
#  ['k5xtpqype9kaqa2', 'shop_kakiko'],
#  ['torotaratoro', 'oriak9'],
#  ['nanaroku5', '9ohh0s8x6yv5zlr'],
#  ['nanaroku5', 'nana77rey1'],
#  ['kagayaki51', 'petiemic'],
#  ['jabarahakka', 'oosakahaoosaka'],
#  ['ryuzinmabuya999', '302_3317'],
#  ['ryuzinmabuya999', 'reimu_marisa_y'],
#  ['angelpie2010', 'kikumaco'],
#  ['nanaroku5', 'gun81288955'],
#  ['ja8yum', 'a_ssann'],
#  ['w4f75x7mj9i2gdb', 'tora8enl'],
#  ['w4f75x7mj9i2gdb', 'sat98635697'],
#  ['w4f75x7mj9i2gdb', 'umemura_gifu'],
#  ['vollfarbe', 'nana77rey1'],
#  ['yukimsr99', 'ldk1b_t'],
#  ['917104an', 'gun81288955'],
#  ['917104an', 'haguruma0830'],
#  ['nanaroku5', 'gun81288955'],
#  ['9w8hftyjllcvc7q', 'yampisun40'],
#  ['misamasaharuma1', 'nana77rey1'],
#  ['bokuranohata', 'mariri025'],
#  ['c1xujspne6tc9xp', 'aiko33151709'],
#  ['wgfzqrk2v6m90cl', 'nwfle6q9vqtxb4q'],
#  ['wgfzqrk2v6m90cl', 'cosmicworld000'],
#  ['taijinkohen', '5sasha5sasha5'],
#  ['wgfzqrk2v6m90cl', 'tlexycfd6obza1g'],
#  ['wgfzqrk2v6m90cl', 'aono'],
#  ['kintaryuta', 'oriak9'],
#  ['fl7whltvlgpskv4', 'shop_kakiko'],
#  ['hamagu71', '7znv478zu8tnswj'],
#  ['gun81288955', 'id_seiron'],
#  ['turbo0421', 'is7h5y6ok4ca3j8'],
#  ['nanak01112', 'shop_kakiko'],
#  ['temmei', 'pablichenkosssr'],
#  ['puia3wlingpibcv', 'oriak9'],
#  ['aoyamayasu', 'shop_kakiko'],
#  ['americanbeer3', 'tokyominpo'],
#  ['japanculture113', 'gurugurugrass'],
#  ['tdcqvu', 'marunyatajohn'],
#  ['jyoutyaku', 'oosakahaoosaka'],
#  ['japanculture113', 'gurugurugrass'],
#  ['ujuzic', 'appsddlg'],
#  ['hondatom1', 'hosakanobuto'],
#  ['yutakama', 'miliou8'],
#  ['mqz4yapfzbyit8h', 'bululunwagtail'],
#  ['book_bugs', 'appsddlg'],
#  ['tigar_satou_666', 'aiko33151709'],
#  ['sanjidq', 'seiryukai'],
#  ['tigar_satou_666', 'chizurua1'],
#  ['hvjs2vz4jpxkpbp', '5sasha5sasha5'],
#  ['sachiko_obaa', 'aiko33151709'],
#  ['rockhearts737', 'wren31680301'],
#  ['iroduku_genei', '5sasha5sasha5'],
#  ['ezqyaf6c4spkshk', 'ikarioyajl'],
#  ['ezqyaf6c4spkshk', 'seiryukai'],
#  ['ezqyaf6c4spkshk', 'torakichi019852'],
#  ['ezqyaf6c4spkshk', 'seiryukai'],
#  ['ezqyaf6c4spkshk', 'mizuki_earth'],
#  ['302_3317', 'reimu_marisa_y'],
#  ['kawakawa2254', 'id_seiron'],
#  ['ezqyaf6c4spkshk', 'v0hjjhorjfvm1nl'],
#  ['ezqyaf6c4spkshk', 'seiryukai'],
#  ['ezqyaf6c4spkshk', 'seiryukai'],
#  ['ezqyaf6c4spkshk', 'starship_glory'],
#  ['miubeekogeroji', '5sasha5sasha5'],
#  ['homura_u', 'haguruma0830'],
#  ['max6_6facter', 'tetsulovebird'],
#  ['uedasihgenobu', 'haguruma0830'],
#  ['necobaka69', 'starship_glory'],
#  ['necobaka69', 'seiryukai'],
#  ['battlepodx', 'marunyatajohn'],
#  ['necobaka69', 'seiryukai'],
#  ['z0j38c8tylvsdn4', 'sitosiyoko8'],
#  ['z0j38c8tylvsdn4', 'sitosiyoko8'],
#  ['a777murabito', 'bululunwagtail'],
#  ['precoci21', 'oosakahaoosaka'],
#  ['diccogiale21', 'nana77rey1'],
#  ['_y_u_m_i', 'oriak9'],
#  ['usaka_yamato', 'haguruma0830'],
#  ['nwfle6q9vqtxb4q', 'haguruma0830'],
#  ['241871648', 'machanazo'],
#  ['241871648', 'subjectbotch'],
#  ['241871648', 'aiainstein'],
#  ['lovepeace8910', 'sollevante2022'],
#  ['su_san_futbol', 'kkrd20iv6kruem7'],
#  ['su_san_futbol', 'seiryukai'],
#  ['missingparts3', '5sasha5sasha5'],
#  ['su_san_futbol', 'seiryukai'],
#  ['daizu_n', '5sasha5sasha5'],
#  ['tocochin73', 'mizuha_t'],
#  ['tocochin73', 'akasayiigaremus'],
#  ['antico0931226', 'tezheya'],
#  ['mizuha_t', 'akasayiigaremus'],
#  ['shirokuma_night', '5sasha5sasha5'],
#  ['_yamaneko__', '5sasha5sasha5'],
#  ['pasa09', '5sasha5sasha5'],
#  ['uedasihgenobu', 'nwfle6q9vqtxb4q'],
#  ['a7r2ljtm', 'hotaka_tsukada'],
#  ['iamnot_abe1', 'chizurua1'],
#  ['hiro6456_h', 'aiko33151709'],
#  ['from1970', 'jn_lyio'],
#  ['sunnyoceangogo', 'aiko33151709'],
#  ['don74172917', 'aiko33151709'],
#  ['ksmgndx', 'ursulanamunamu'],
#  ['ksmgndx', '_home_ground'],
#  ['ksmgndx', 'booskachan_ver2'],
#  ['kawahid601', 'aiko33151709'],
#  ['charlie_arai', 'ppsh41_1945'],
#  ['gehinerfuellung', 'nana77rey1'],
#  ['penate3', 'ppsh41_1945'],
#  ['dpc_1217', 'aiko33151709'],
#  ['peanutpersimmon', 'yampisun40'],
#  ['ksmgndx', 'ursulanamunamu'],
#  ['ksmgndx', 'hayakawa2600'],
#  ['1ntdzqlvfvy2vcl', 'naoyafujiwara'],
#  ['ksmgndx', 'hayakawa2600'],
#  ['beshi25_ex', 'nana77rey1'],
#  ['somethinelse_68', 'aiko33151709'],
#  ['paxhterra', 'ppsh41_1945'],
#  ['lazyagatha', 'chizurua1'],
#  ['tankobe', 'shop_kakiko'],
#  ['hsoejima2', 'aiko33151709'],
#  ['dliqbgtql06yqv4', 'wanpakuten'],
#  ['aortgytw3nc1chw', 'aiko33151709'],
#  ['koro1chie1uri1', 'aiko33151709'],
#  ['yuuka_eve', 'aiko33151709'],
#  ['g_democra', 'nana77rey1'],
#  ['oku8686', 'shop_kakiko'],
#  ['nrazcwhpi1vdtvw', 'aiko33151709'],
#  ['kazu07061923', 'yampisun40'],
#  ['mactfsotw', 'nana77rey1'],
#  ['y7s6k', 'hotaka_tsukada'],
#  ['1975_bowie', 'aiko33151709'],
#  ['kfmc10', 'nana77rey1'],
#  ['gingerale500ml', 'hotaka_tsukada'],
#  ['okaeusuki', 'nana77rey1'],
#  ['simaneko17', 'aiko33151709'],
#  ['mizuki_tbss', 'aiko33151709'],
#  ['yamasaki_hana', 'ursulanamunamu'],
#  ['blueshadow010', 'ppsh41_1945'],
#  ['tilia56865436', 'aiko33151709'],
#  ['0113_kikuchan', 'shop_kakiko'],
#  ['anram01', 'aiko33151709'],
#  ['dai7707', 'hotaka_tsukada'],
#  ['me262b', 'aiko33151709'],
#  ['vollfarbe', '_neko_aruku'],
#  ['vollfarbe', 'rockhearts737'],
#  ['vollfarbe', 'likedreply'],
#  ['vollfarbe', 'nana77rey1'],
#  ['awozora7', 'jn_lyio'],
#  ['new52324320', 'ppsh41_1945'],
#  ['kanemonaishi', 'aiko33151709'],
#  ['wav4xrgxqveycxd', 'hotaka_tsukada'],
#  ['tabibito_c_', 'aiko33151709'],
#  ['tettchi2', 'aiko33151709'],
#  ['kei50411225', 'shop_kakiko'],
#  ['miles_taka', 'aiko33151709'],
#  ['porkpiepres', 'kei_nakazawa'],
#  ['munei44327368', 'hotaka_tsukada'],
#  ['__saeco__', 'hotaka_tsukada'],
#  ['lovemeters', 'aiko33151709'],
#  ['nana77rey1', 'jikangahayai'],
#  ['nana77rey1', 'saya_fairyland'],
#  ['imari1217', 'aiko33151709'],
#  ['alc_v', 'hotaka_tsukada'],
#  ['kogakawaiioya', 'ursulanamunamu'],
#  ['eo8rmt2mkzu3eo6', '_neko_aruku'],
#  ['eo8rmt2mkzu3eo6', 'rockhearts737'],
#  ['eo8rmt2mkzu3eo6', 'likedreply'],
#  ['eo8rmt2mkzu3eo6', 'nana77rey1'],
#  ['ytse74pvozenbam', 'masahirono'],
#  ['nannanya5928', 'aiko33151709'],
#  ['japanfulness', 'aiko33151709'],
#  ['suzukisgr', 'kei_nakazawa'],
#  ['eumeda1944', 'aiko33151709'],
#  ['z36ixgxm11qfjp2', 'aiko33151709'],
#  ['reigi_daiji_ya', 'shop_kakiko'],
#  ['zztyv6vdcnkulnm', 'nana77rey1'],
#  ['katepanda2', 'hotaka_tsukada'],
#  ['flatlineweb', 'ursulanamunamu'],
#  ['f3tes1s4zxo54th', 'shop_kakiko'],
#  ['angelus_0923', 'seiryukai'],
#  ['angelus_0923', 'nikone_25'],
#  ['bngcachugi8qrlr', 'aiko33151709'],
#  ['angelus_0923', 'starship_glory'],
#  ['8c8g', 'wanpakuten'],
#  ['zk2zocqmudq9kdl', 'ppsh41_1945'],
#  ['crdftvl6rjqv8l6', 'aiko33151709'],
#  ['pmigraine1', 'nana77rey1'],
#  ['lovemymyoji', 'nana77rey1'],
#  ['lovemymyoji', 'ja1hss'],
#  ['pilgrim45037704', 'h_koyuyu'],
#  ['yuiyui0343', 't_okada'],
#  ['fn83058746', 'chizurua1'],
#  ['fn83058746', 'mi89s1'],
#  ['fn83058746', 'jinn11'],
#  ['daichain1', 'mi89s1'],
#  ['unysanothername', 'oriak9'],
#  ['saya_fairyland', 'nana77rey1'],
#  ['hugring_nowhere', 'kazuhirosoda'],
#  ['zmnmezu81kmpcvw', 'mihoiida_tw'],
#  ['n3siuwp', 'nauciccafe'],
#  ['n3siuwp', 'yukioiokibe'],
#  ['n3siuwp', 'xxcalmo'],
#  ['blu42rosso', 'kazuhirosoda'],
#  ['bluegardenlover', 'chizurua1'],
#  ['x2can3joy', 'nana77rey1'],
#  ['gmailrei', 'yamtom'],
#  ['gmailrei', 'youtube'],
#  ['pomtama25', 'oriak9'],
#  ['matchi_enjooy', 'oriak9'],
#  ['goto74', 'kazuhirosoda'],
#  ['snoopy4018', 'jinn11'],
#  ['kurobiya', 'jinn11'],
#  ['nanak01112', 'edokaiki'],
#  ['minagawajammi', 'jinn11'],
#  ['qanne7', 'oriak9'],
#  ['1qk4s7xnn2uprfe', '55hawaiicondo'],
#  ['1qk4s7xnn2uprfe', 'yukioiokibe'],
#  ['1qk4s7xnn2uprfe', 'nauciccafe'],
#  ['1qk4s7xnn2uprfe', 'yukioiokibe'],
#  ['1qk4s7xnn2uprfe', 'xxcalmo'],
#  ['kamoinu', 'nana77rey1'],
#  ['j_adrift', '7znv478zu8tnswj'],
#  ['shinkengongon', 'chizurua1'],
#  ['shinkengongon', 'mi89s1'],
#  ['draming_panda', 'oriak9'],
#  ['n_hope_n', 'mihoiida_tw'],
#  ['sureame896', 'oriak9'],
#  ['alomave', 'jinn11'],
#  ['lolo_daryl', 't_o94si9o'],
#  ['cftq4km6nvqihsk', 'kawakami_takuya'],
#  ['ponchoronyanko', 'nana77rey1'],
#  ['p_lassi5', 'oriak9'],
#  ['julikolove', 'oriak9'],
#  ['yossense', 'nana77rey1'],
#  ['rudy_hul', 'nana77rey1'],
#  ['nega_ikiro_bot', 'nana77rey1'],
#  ['finalfunboy', 'chizurua1'],
#  ['kaodkptqduqefkj', 'mi89s1'],
#  ['kiharu_bara', 'kazuhirosoda'],
#  ['turbom28215389', 'seiryukai'],
#  ['yuri4sakura', 'ssimtok'],
#  ['ayokota', 'mihoiida_tw'],
#  ['opulencemement', 'oriak9'],
#  ['08130293s', 'seiryukai'],
#  ['boosann_', 'oriak9'],
#  ['h3bo3', 'kazuhirosoda'],
#  ['aizomeyumeko', 'franzkenk'],
#  ['zztyv6vdcnkulnm', 'code_dia'],
#  ['cross0830', 'yampisun40'],
#  ['cross0830', 'cross0830'],
#  ['cross0830', 'aono'],
#  ['serena53033222', 'oriak9'],
#  ['awayukinosuke', 'oriak9'],
#  ['wajiuqgskjtpptd', 'jinn11'],
#  ['sswindy', 'mi89s1'],
#  ['hitotsu_company', 'kazu10233147'],
#  ['imagawa_u', 'oriak9'],
#  ['mrnzna7n4zzn8es', 'yamtom'],
#  ['mrnzna7n4zzn8es', 'youtube'],
#  ['masamzp', 'yamtom'],
#  ['masamzp', 'youtube'],
#  ['zassou2828', 'oriak9'],
#  ['ddts1terbrbatgu', 'kazuhirosoda'],
#  ['takobekoneko', 'oriak9'],
#  ['motomoko_m', 'oriak9'],
#  ['kujhar84tfde', 'yamtom'],
#  ['kujhar84tfde', 'youtube'],
#  ['abc98793953002', 'yamtom'],
#  ['abc98793953002', 'youtube'],
#  ['kaku12559701', 'oriak9'],
#  ['sato859', 'don_lemme_down'],
#  ['natsuhikoaloha', 'mi89s1'],
#  ['ayashimashi', 'oriak9'],
#  ['kojiro323', 'seiryukai'],
#  ['buhikun', 'yamtom'],
#  ['buhikun', 'youtube'],
#  ['rokoemon2', 'franzkenk'],
#  ['kojika0131', '2f0umod7aqpheom'],
#  ['msmsaito', 'yamtom'],
#  ['msmsaito', 'youtube'],
#  ['tonton_0007', 'yampisun40'],
#  ['tonton_0007', 'cross0830'],
#  ['tonton_0007', 'aono'],
#  ['saitamacity', 'yamtom'],
#  ['saitamacity', 'youtube'],
#  ['notzurabut', 'oriak9'],
#  ['moonlight_1958', 'kazuhirosoda'],
#  ['etude6635', 'cocochan000700'],
#  ['tbonne10', 'hotaka_tsukada'],
#  ['tobaneko', 'oriak9'],
#  ['lurjenncr3ifupg', 'kazuhirosoda'],
#  ['yasei_shikou', 'jinn11'],
#  ['ikehara65579036', 'kazuhirosoda'],
#  ['takigawaosamu', 'aokitonko'],
#  ['sibag2vny02wxya', 'aokitonko'],
#  ['k5xtpqype9kaqa2', 'gamechangefreak'],
#  ['live_in_toulon', 'mainichi'],
#  ['takigawaosamu', 'oriak9'],
#  ['harutagu1', 'jinn11'],
#  ['hitosizuku18', 'jinn11'],
#  ['ire_scot', 'cocochan000700'],
#  ['tubupoko', 'jinn11'],
#  ['cjxgh26q7k5oewn', 'jinn11'],
#  ['lemonade10181', 'oriak9'],
#  ['tareuyaya', 'jinn11'],
#  ['kali_izumi', 'yamtom'],
#  ['kali_izumi', 'youtube'],
#  ['higashiajianews', 'jomaruyan'],
#  ['oscar_ymx55', 'alma0707'],
#  ['walkinglint', 'yamtom'],
#  ['walkinglint', 'youtube'],
#  ['tonarinojugasan', 'kazuhirosoda'],
#  ['sazamaru', 'yamtom'],
#  ['sazamaru', 'youtube'],
#  ['1618kplr', 'kei_nakazawa'],
#  ['neko_de_ne', 'kenkenrokujapan'],
#  ['hrskksrh', 'kazuhirosoda'],
#  ['yampisun40', 'cross0830'],
#  ['yampisun40', 'aono'],
#  ['q7l5bff1vpl92st', 'kazu10233147'],
#  ['denchan35', 'voguejp'],
#  ['ludwig3000', 'mi89s1'],
#  ['mogura22765', 'kenkenrokujapan'],
#  ['sinagire_sold', 'oriak9'],
#  ['91muswellhill', 'oriak9'],
#  ['uchida_kawasaki', 'yamtom'],
#  ['uchida_kawasaki', 'youtube'],
#  ['noirseuil', 'kazuhirosoda'],
#  ['otomomichel', 'oriak9'],
#  ['obisato', 'kazuhirosoda'],
#  ['argg7omcjykks6e', 'mi89s1'],
#  ['thiebun993', 'mi89s1'],
#  ['maikichikun', 'oriak9'],
#  ['higurashit5', 'kazuhirosoda'],
#  ['homareapple', 'aokitonko'],
#  ['sallykalin', 'alice_777'],
#  ['sallykalin', 'hoyaminabe'],
#  ['flovejazz', 'abel03ok'],
#  ['benedictine555', 'kazuhirosoda'],
#  ['ikitekenai', 'oriak9'],
#  ['hopesai6', 'nwfle6q9vqtxb4q'],
#  ['tsucchan_t', 'aokitonko'],
#  ['stigrbej20', 'kenkenrokujapan'],
#  ['yahndf', 'tf44029245'],
#  ['mamino194', 'racoon1120'],
#  ['boukennkyusha', 'oriak9'],
#  ['pqqbr7o81n7zzfm', 'kenkenrokujapan'],
#  ['km1514brook', 'oriak9'],
#  ['teru2bouz', 'mi89s1'],
#  ['doctor_aititeyu', 'oriak9'],
#  ['taz_schmidt', 'jinn11'],
#  ['mt_ksk', 'key14932405'],
#  ['akira_5884', 'yamtom'],
#  ['akira_5884', 'youtube'],
#  ['28_momechabo', 'jinn11'],
#  ['tomotomorarara', 'oriak9'],
#  ['kamayan1192', 'yamtom'],
#  ['kamayan1192', 'youtube'],
#  ['hitomirisun', 'oriak9'],
#  ['blueskycoffeen1', 'h_koyuyu'],
#  ['alice_777', 'alice_777'],
#  ['alice_777', 'hoyaminabe'],
#  ['polarbear_2017', 'yamtom'],
#  ['polarbear_2017', 'youtube'],
#  ['f21tsx6teup441u', 'chizurua1'],
#  ['fnfbzhixetycv7g', 'chizurua1'],
#  ['lovemymyoji', 'jinn11'],
#  ['fnfbzhixetycv7g', 'mi89s1'],
#  ['mocoinmoco', 'hotaka_tsukada'],
#  ['elefl69', 'chizurua1'],
#  ['keiminkei', 'mi89s1'],
#  ['st_ryoi', 'mi89s1'],
#  ['chihihirokota', 'mi89s1'],
#  ['keiminkei', 'chizurua1'],
#  ['mocoinmoco', 'ssimtok'],
#  ['r_yoshi332', 'jinn11'],
#  ['p_birdo', 'kazuhirosoda'],
#  ['key14932405', 'kazuhirosoda'],
#  ['st_ryoi', 'chizurua1'],
#  ['amy_lo_o', 'oriak9'],
#  ['odenchan_kaito', 'kazuhirosoda'],
#  ['daisukikimakima', 'mi89s1'],
#  ['tmukeymt', 'jinn11'],
#  ['daisukikimakima', 'chizurua1'],
#  ['cross0830', 'aono'],
#  ['no_ha', 'kazuhirosoda'],
#  ['04_mizuki', 'chizurua1'],
#  ['04_mizuki', 'mi89s1'],
#  ['muajika', 'chizurua1'],
#  ['shizuku_acc', 'seiryukai'],
#  ['evhbcks65nc32wg', 'jinn11'],
#  ['akiringo1217', 'chizurua1'],
#  ['ai4801ki', 'jinn11'],
#  ['yukino0201', 'mi89s1'],
#  ['dokugen', 'mi89s1'],
#  ['yukino0201', 'chizurua1'],
#  ['minako71809606', 'oriak9'],
#  ['toporosky', 'oriak9'],
#  ['itsukiharano', 'kei_nakazawa'],
#  ['lurjenncr3ifupg', 'mi89s1'],
#  ['123456moto', 'kazuhirosoda'],
#  ['izumikuroi', 'oriak9'],
#  ['4kcjz0ldstr2tz1', 'hosakanobuto'],
#  ['wpj57011218', 'chizurua1'],
#  ['kamui_arisawa', 'seiryukai'],
#  ['n3reba', 'oriak9'],
#  ['wan8tsune', 'kazuhirosoda'],
#  ['wpj57011218', 'mi89s1'],
#  ['aoitomato0112', 'amano_treefrog'],
#  ['aoitomato0112', 'wanpakuten'],
#  ['ponkoro_pon', 'oriak9'],
#  ['p4blparwhxxnsyy', 'ssimtok'],
#  ['itotakashi1121', 'kazuhirosoda'],
#  ['lovehatecelery', 'h_112358'],
#  ['arcsinh_aurcus', 'oriak9'],
#  ['andybelle2', 'mi89s1'],
#  ['burra63', 'kazuhirosoda'],
#  ['andybelle2', 'chizurua1'],
#  ['lanka26080156', 'oriak9'],
#  ['rokunai', 'oriak9'],
#  ['kyoko42062664', 'jinn11'],
#  ['maris_hy', 't_okada'],
#  ['awamorikazy1957', 'kazuhirosoda'],
#  ['yuuhi2', 'kazuhirosoda'],
#  ['tlho24lf4qlmaw2', 'kazuhirosoda'],
#  ['tapino31', 'h_112358'],
#  ['kandemo', 'kazuhirosoda'],
#  ['maou_ouou', 'chizurua1'],
#  ['akimareko', 'chizurua1'],
#  ['juemonh', 'kenkenrokujapan'],
#  ['rrrradddd', 'youtube'],
#  ['ganekoganegane', 'chizurua1'],
#  ['ganekoganegane', 'mi89s1'],
#  ['godwindmill', 'kenkenrokujapan'],
#  ['hitoshin0614', 'oriak9'],
#  ['odenchan_kaito', 'akahata_pr'],
#  ['shirokumakum3', 'mihoiida_tw'],
#  ['odenchan_kaito', 'mi89s1'],
#  ['__sy_iura', 'chizurua1'],
#  ['inunekodturn', 'amano_treefrog'],
#  ['inunekodturn', 'wanpakuten'],
#  ['nnkitarohcoca', 'mi89s1'],
#  ['a3kflkuvi658ehu', 'jinn11'],
#  ['nnatoznn', 'hotaka_tsukada'],
#  ['nnkitarohcoca', 'chizurua1'],
#  ['vtdnflgiqk3zxkg', 'oriak9'],
#  ['noche_y_calima', 'oriak9'],
#  ['come40529', 'mihoiida_tw'],
#  ['oyi5qkkdaxga6ut', 'to_mock'],
#  ['okinawaolzf5blg', '2f0umod7aqpheom'],
#  ['tittikiti617', 'nana77rey1'],
#  ['faichan_kangri', 'nana77rey1'],
#  ['mushitake', 'oriak9'],
#  ['ifv7xavyvl7nfoz', 'amano_treefrog'],
#  ['ifv7xavyvl7nfoz', 'wanpakuten'],
#  ['ultrastarplayer', 'mi89s1'],
#  ['abel03ok', 'yanbarugurashi'],
#  ['kanon1200', 'oriak9'],
#  ['tapino31', 'nana77rey1'],
#  ['apricot0309', 'ikehara65579036'],
#  ['tohotte', 'oriak9'],
#  ['avgtom', 'yaponluq'],
#  ['pasear_al_zoo', 'nana77rey1'],
#  ['hanntouwodeyo', 'mi89s1'],
#  ['e3ettragpk2otz4', 'kitakyu8888'],
#  ['e3ettragpk2otz4', 'hon5437'],
#  ['talkiyanhonin', 'kawai_kanyu'],
#  ['gw71065277', 'rf_1967'],
#  ['gw71065277', 'fallofbears'],
#  ['te01828697', 'aokitonko'],
#  ['neko_de_ne', 'higuras2018'],
#  ['ckfzq6dx7lmil9m', 'mi89s1'],
#  ['yukineko_28n28n', 'oriak9'],
#  ['kenkenrokujapan', 'jimin_koho'],
#  ['mical_s', 'oriak9'],
#  ['museaimi', 'seikenkoutai46'],
#  ['noshikun', 'chizurua1'],
#  ['ishi_no_sita_', 'mi89s1'],
#  ['alxdeyykny5wguc', 'nana77rey1'],
#  ['mmm_hiyo', 'oriak9'],
#  ['8amoroma8', 'aokitonko'],
#  ['hunter529', 'aokitonko'],
#  ['lx0e4uhl', 'mi89s1'],
#  ['lgq2aglmxnsawkg', 'nana77rey1'],
#  ['nauciccafe', 'nauciccafe'],
#  ['nauciccafe', 'yukioiokibe'],
#  ['nauciccafe', 'xxcalmo'],
#  ['akir09216578gt0', 'oriak9'],
#  ['fabius_spqr', 'nana77rey1'],
#  ['trad15917269', 'chizurua1'],
#  ['bamunomama', 'nana77rey1'],
#  ['milkat_c', 'oriak9'],
#  ['ultorahiro', 'oriak9'],
#  ['bamunomama', 'floria_mint'],
#  ['trad15917269', 'mi89s1'],
#  ['milukusleep', 'oriak9'],
#  ['minmimama1', 'oriak9'],
#  ['uraku88', 'foryourinforma'],
#  ['anmalanicora4', 'oriak9'],
#  ['sweet_zerry', 'higuras2018'],
#  ['esse_tendr', 'nana77rey1'],
#  ['yuku89457342', 'ssimtok'],
#  ['shofuken', 'nana77rey1'],
#  ['erzengel1014', 'oriak9'],
#  ['moegi_oofc', 'oriak9'],
#  ['yossie89180000', 'mi89s1'],
#  ['2ndbeahkk5bkcc8', 'oriak9'],
#  ['nekonoaitsu', 'nana77rey1'],
#  ['_daisylily', 'ppsh41_1945'],
#  ['milmiru', 'oriak9'],
#  ['kazzoone', 'oriak9'],
#  ['2uvddx5gwl0rgob', 'yaqywfry8w03ayt'],
#  ['2uvddx5gwl0rgob', 'nipponichi8'],
#  ['2uvddx5gwl0rgob', 'sankei_news'],
#  ['choseki_', 'oriak9'],
#  ['emmanuel_chanel', 'nwfle6q9vqtxb4q'],
#  ['yojiro10haruki', 'oriak9'],
#  ['a31vww0sswmth6q', 'mi89s1'],
#  ['tkmkszk02', 'oriak9'],
#  ['beesick49', 'chizurua1'],
#  ['20220710a', 'aokitonko'],
#  ['ffnyl27djkgebnm', 'mi89s1'],
#  ['8qt1xlvf15gyeki', 'gun81288955'],
#  ['clover1x2x2x', 'oriak9'],
#  ['saya_fairyland', 'timeformachine_'],
#  ['ritchie99999', 'mi89s1'],
#  ['bonobono_6001', 'hosakanobuto'],
#  ['takamizu_0', 'oriak9'],
#  ['96chibikaka', 'yasu_yasuno_sa'],
#  ['godwindmill', 'kenkenrokujapan'],
#  ['godwindmill', 'jimin_koho'],
#  ['okonomiyaki2099', 'nana77rey1'],
#  ['lassta008', 'seiryukai'],
#  ['new_kt73', 'oriak9'],
#  ['iggiedog', 'oriak9'],
#  ['masashi57152567', 'pucho611'],
#  ['56so53tf9qvon96', 'mi89s1'],
#  ['kagosend22', 'oriak9'],
#  ['vcmizu01', 'oriak9'],
#  ['megusurinokiko', 'chizurua1'],
#  ['van1601', 'seiryukai'],
#  ['ricol3rd', 'oriak9'],
#  ['tomato06615289', 'oriak9'],
#  ['minomino263', '55hawaiicondo'],
#  ['minomino263', 'yukioiokibe'],
#  ['aekmkq', 'foryourinforma'],
#  ['oov0210', 'higuras2018'],
#  ['yuki_in_pj', 'yaponluq'],
#  ['bwp7ahkc7yggaqd', 'mi89s1'],
#  ['monogatarizm', 'mi89s1'],
#  ['filiara_pleyel', 'chizurua1'],
#  ['moe_pippi0306', 'foryourinforma'],
#  ['thesun_thestars', 'oriak9'],
#  ['hohoemi1219', 'higuras2018'],
#  ['mhcko', 'mi89s1'],
#  ['hachteik', 'oriak9'],
#  ['nananishi4', 'oriak9'],
#  ['piqowngy16ww1ei', 'mi89s1'],
#  ['qrr8956tgb', 'oriak9'],
#  ['alxdeyykny5wguc', 'oriak9'],
#  ['alma0707', 'oriak9'],
#  ['2gh3unozo3cipbd', 'nana77rey1'],
#  ['cainsystem_jp', 'mi89s1'],
#  ['bfjgroup', 'chizurua1'],
#  ['1iw806rtchqh5a1', 'mi89s1'],
#  ['kenroafrocuban', 'oriak9'],
#  ['biblio839', 'oriak9'],
#  ['fuku_black', 'oriak9'],
#  ['reiwanore', 'oriak9'],
#  ['abc98793953002', 'oriak9'],
#  ['sally_for_life', 'oriak9'],
#  ['fearless_taisho', 'aokitonko'],
#  ['choroi_silica', 'code_dia'],
#  ['choroi_silica', 'epj8ifbqej8ei6h'],
#  ['choroi_silica', 'oriak9'],
#  ['mxuubiv3vxdlzd6', 'higuras2018'],
#  ['lock_on_sweet', 'oriak9'],
#  ['gnti3xifvfckzwm', 'mi89s1'],
#  ['luna37se', 'mi89s1'],
#  ['nauciccafe', 'yukioiokibe'],
#  ['nauciccafe', 'xxcalmo'],
#  ['aoikiefu', 'oriak9'],
#  ['daihatsup5', 'oriak9'],
#  ['monkspirits', 'oriak9'],
#  ['ugo75vsd7qme0zr', 'hanamiz01467525'],
#  ['svhfzdktg0o4j8v', 'chizurua1'],
#  ['sally_for_life', 'aokitonko'],
#  ['shirokumanow1', 'oriak9'],
#  ['kei_mj1130', 'mi89s1'],
#  ['kei_mj1130', 'chizurua1'],
#  ['noi39r', 'oriak9'],
#  ['wttudf8uxfhmmde', 'yamtom'],
#  ['wttudf8uxfhmmde', 'youtube'],
#  ['netconservatism', 'seiryukai'],
#  ['okonomiyaki2099', 'x2can3joy'],
#  ['hukumusi', 'aokitonko'],
#  ['jirotaromomo', 'oriak9'],
#  ['kumago_qoo', 'oriak9'],
#  ['moguipee7', 'booksmany'],
#  ['moguipee7', 'mainichi'],
#  ['h83664', 't_okada'],
#  ['masarutoyoshiko', 'mi89s1'],
#  ['ninbentutituti', 'oriak9'],
#  ['yakinikutarou3', 'hosakanobuto'],
#  ['akirahitoshi', 't_okada'],
#  ['luv_yxr', 'aokitonko'],
#  ['53pvlngstpopdua', 'chizurua1'],
#  ['53pvlngstpopdua', 'mi89s1'],
#  ['karenaihana_', 'higuras2018'],
#  ['sosorasora3', 'aokitonko'],
#  ['nanatsunomedama', 'tf44029245'],
#  ['hiro4sa', 'higuras2018'],
#  ['kaokou11', 'oriak9'],
#  ['8octp', 'aokitonko'],
#  ['jikoisinhairan', 'mi89s1'],
#  ['arienaikamo_s', 'rocky20011001'],
#  ['awasemaru7', 'oriak9'],
#  ['sin_tek_bi_hun', 'kawai_kanyu'],
#  ['a_s_i_m1', 'oriak9'],
#  ['kp35g', 'oriak9'],
#  ['nc0xynnvdmpakes', 'higuras2018'],
#  ['moca_shiki', 'oriak9'],
#  ['ikedaakiko1', 'chizurua1'],
#  ['ryo210uchuuujin', 'nana77rey1'],
#  ['veryfarfromhere', 'nana77rey1'],
#  ['kank_683128', 'oriak9'],
#  ['muroitouko', 'nana77rey1'],
#  ['mamasan_h', 'yamtom'],
#  ['mamasan_h', 'youtube'],
#  ['kenkenrokujapan', 'higuras2018'],
#  ['_perhonen_', 'ssimtok'],
#  ['sskmk', 'nana77rey1'],
#  ['kid71375156', 'kenkenrokujapan'],
#  ['kid71375156', 'jimin_koho'],
#  ['55hawaiicondo', 'yukioiokibe'],
#  ['bibliotecalia', 'nana77rey1'],
#  ...]

# %%
def save_csv(filename,data,use_quotes=False,double_to_single=True,file_mode='w',enc='utf-8',verbose=True): #this assumes a list of lists wherein the second-level list items contain no commas
    with open(filename,file_mode,encoding = enc) as out:
        for line in data:
            if type(line) is not list and type(line) is not tuple:
                line = [line] #forces all items in 'data' to be lists
            if use_quotes == True:
                if double_to_single == True:
                    row = '"' + '","'.join([str(i).replace('"',"'") for i in line]) + '"' + "\n"
                else:
                    row = '"' + '","'.join([str(i) for i in line]) + '"' + "\n"
            else:
                row = ','.join([str(i) for i in line]) + "\n"
            out.write(row)
    if verbose == True:
        print('Data saved to file "' + filename + '".')

# %%
def load_data(data,enc='utf-8',translate_unicode=False):
    if type(data) is str:
        csv_data = []
        with open(data,'r',encoding = enc,errors = 'replace') as f:
            if translate_unicode == True:
                reader = csv.reader((line.encode().decode('unicode_escape').replace('\0','') for line in f)) #remove NULL bytes
            else:
                reader = csv.reader((line.replace('\0','') for line in f)) #remove NULL bytes
            for row in reader:
                if row != []:
                    csv_data.append(row)
        print('Data loaded from file "' + data + '".')
        return csv_data
    else:
        print('Data loaded.')
        return copy.deepcopy(data)

# %%
outfile = '_edgelist.csv'
save_csv(outfile,final)
# Out:
# Data saved to file "_edgelist.csv".

# %%
top_communities = tsm.get_top_communities(final)
# Out:
# Data loaded.
# Non-directed network created.
# Community partition complete.
# Total n of communities: 359
# Modularity: 0.77
# Community analysis complete. The top 10 communities in this network account for 68.87 % of all nodes.
# And 66.78 % of all edges.

# %%
nodes_data = top_communities.node_list
nodes_data
# Out:
# [['oriak9', '1', '1512'],
#  ['hotaka_tsukada', '6', '1393'],
#  ['nipponkairagi', '11', '1344'],
#  ['seiryukai', '21', '1218'],
#  ['aiko33151709', '14', '1189'],
#  ['quitamarco', '0', '585'],
#  ['nana77rey1', '4', '322'],
#  ['ssimtok', '16', '298'],
#  ['yampisun40', '17', '197'],
#  ['chizurua1', '25', '178'],
#  ['shop_kakiko', '11', '124'],
#  ['kenkenrokujapan', '17', '106'],
#  ['mi89s1', '25', '104'],
#  ['hosakanobuto', '16', '95'],
#  ['5sasha5sasha5', '6', '92'],
#  ['nwfle6q9vqtxb4q', '17', '71'],
#  ['quotationmark95', '25', '64'],
#  ['yoboudr_op', '4', '59'],
#  ['id_seiron', '17', '55'],
#  ['grayengineer', '17', '53'],
#  ['sollevante2022', '4', '50'],
#  ['w4f75x7mj9i2gdb', '17', '45'],
#  ['oosakahaoosaka', '25', '44'],
#  ['h_koyuyu', '17', '43'],
#  ['yuki1988jp', '25', '41'],
#  ['kakitama', '16', '41'],
#  ['haguruma0830', '17', '38'],
#  ['starship_glory', '21', '35'],
#  ['powertopeople5', '25', '34'],
#  ['run_and_walk_', '4', '32'],
#  ['nikone_25', '21', '32'],
#  ['jinn11', '25', '31'],
#  ['pokhara1995', '4', '28'],
#  ['eo8rmt2mkzu3eo6', '4', '28'],
#  ['hasegawakenjiro', '6', '27'],
#  ['marine_blueo', '4', '26'],
#  ['kenkyukenkyu2', '21', '26'],
#  ['bessei_family', '4', '26'],
#  ['uirousakura', '6', '25'],
#  ['besseibot', '4', '25'],
#  ['cosmicworld000', '17', '24'],
#  ['p2ie9tqrwnz3qq0', '11', '21'],
#  ['pablichenkosssr', '17', '20'],
#  ['naagita', '6', '19'],
#  ['hachikogumo', '17', '19'],
#  ['code_dia', '17', '19'],
#  ['aono', '17', '19'],
#  ['suzumiya_na_gi', '4', '18'],
#  ['stc_bp100', '4', '18'],
#  ['_neko_aruku', '4', '18'],
#  ['ohaginokao3181', '4', '17'],
#  ['gun81288955', '17', '17'],
#  ['chilira_la29', '4', '17'],
#  ['umemura_gifu', '17', '16'],
#  ['yshdykhr', '6', '15'],
#  ['yamami_open', '17', '15'],
#  ['sugiyama766', '17', '15'],
#  ['shige_death', '6', '15'],
#  ['na7719961212', '4', '15'],
#  ['hug_hug519', '17', '15'],
#  ['yucchi0i0', '4', '14'],
#  ['x2can3joy', '4', '14'],
#  ['moeruasia01', '17', '14'],
#  ['katalernejo', '4', '14'],
#  ['higuras2018', '17', '14'],
#  ['alloemloveu', '4', '14'],
#  ['sspmi', '6', '13'],
#  ['rockhearts737', '4', '13'],
#  ['mrjombxev6xdu9c', '4', '13'],
#  ['grapefruitsjui2', '4', '13'],
#  ['edokaiki', '11', '13'],
#  ['turbo0421', '17', '12'],
#  ['milmilk6', '4', '12'],
#  ['choroi_silica', '17', '12'],
#  ['bokuranoijyu', '0', '12'],
#  ['aurxcanjyw3epxs', '4', '12'],
#  ['yumemigachi24', '25', '11'],
#  ['saya_fairyland', '4', '11'],
#  ['ryantan315', '4', '11'],
#  ['nasitaro', '6', '11'],
#  ['likedreply', '17', '11'],
#  ['7q3dsgoqopixflu', '25', '11'],
#  ['ts80115785', '4', '10'],
#  ['skyyard_sora', '17', '10'],
#  ['sabutibi777', '4', '10'],
#  ['puyodora', '17', '10'],
#  ['orenama', '4', '10'],
#  ['k__e_i', '21', '10'],
#  ['jimin_koho', '17', '10'],
#  ['4hnnwuz3lmecs9d', '4', '10'],
#  ['taka_paris', '16', '9'],
#  ['subaru1000', '4', '9'],
#  ['racoon1120', '4', '9'],
#  ['okonomiyaki2099', '4', '9'],
#  ['okihara_taichi', '4', '9'],
#  ['mihoiida_tw', '4', '9'],
#  ['kawai_kanyu', '1', '9'],
#  ['japanese0456', '17', '9'],
#  ['dr_mashiritosan', '17', '9'],
#  ['aoigogatu', '17', '9'],
#  ['aircraftcarrer', '17', '9'],
#  ['nakanishib', '6', '8'],
#  ['maribctchan', '11', '8'],
#  ['koikeyoshitaka', '17', '8'],
#  ['kamifuusen7161', '4', '8'],
#  ['jomaruyan', '25', '8'],
#  ['axzfptbughjctvf', '11', '8'],
#  ['yossense', '4', '7'],
#  ['ryoma09012', '17', '7'],
#  ['resipatriot', '17', '7'],
#  ['ndelnyzgpdtvgzz', '4', '7'],
#  ['kowya444', '17', '7'],
#  ['a_gochiu3power', '17', '7'],
#  ['xoqbs1krynzlqov', '17', '6'],
#  ['torepan_sensei', '4', '6'],
#  ['thequxq', '17', '6'],
#  ['speed540', '4', '6'],
#  ['risapeori', '17', '6'],
#  ['product1954', '25', '6'],
#  ['mu9pmtylvahabi9', '4', '6'],
#  ['lautream', '6', '6'],
#  ['kusikurage', '4', '6'],
#  ['kayuumaatsui', '4', '6'],
#  ['karajin228', '4', '6'],
#  ['bluezlee_', '25', '6'],
#  ['awayukinosuke', '17', '6'],
#  ['aiainstein', '4', '6'],
#  ['ae24vi7efq387k1', '21', '6'],
#  ['2kuow', '21', '6'],
#  ['yone147258369', '4', '5'],
#  ['wata_nabekyo_ko', '17', '5'],
#  ['vnrespectfn', '4', '5'],
#  ['ticktack08241', '17', '5'],
#  ['reimu_marisa_y', '17', '5'],
#  ['neko_de_ne', '17', '5'],
#  ['manna2010able', '16', '5'],
#  ['la_neige_fleur', '4', '5'],
#  ['kurrymurry', '4', '5'],
#  ['kiris_kirimura', '4', '5'],
#  ['kikumaco', '17', '5'],
#  ['ito_mikiko', '4', '5'],
#  ['hammern666', '17', '5'],
#  ['ftth', '1', '5'],
#  ['cross0830', '17', '5'],
#  ['celebrateones15', '17', '5'],
#  ['anohitosaccount', '4', '5'],
#  ['zztyv6vdcnkulnm', '17', '4'],
#  ['yossik091', '25', '4'],
#  ['yamatoji', '4', '4'],
#  ['vwatv6', '4', '4'],
#  ['v3xwhhofecqxy7p', '17', '4'],
#  ['uncle_dagon', '0', '4'],
#  ['tomatotacotoma', '17', '4'],
#  ['tm2501', '11', '4'],
#  ['tetsulovebird', '17', '4'],
#  ['ssa90751853', '4', '4'],
#  ['sd_t2w', '21', '4'],
#  ['pp_giraud', '4', '4'],
#  ['opaku_trainkit', '17', '4'],
#  ['noguchi1706', '17', '4'],
#  ['mydream555', '17', '4'],
#  ['mukaituru', '17', '4'],
#  ['masumit17', '17', '4'],
#  ['macback1986', '25', '4'],
#  ['kenjitsukagoshi', '0', '4'],
#  ['k2bo5rrsaajadk5', '17', '4'],
#  ['jikangahayai', '4', '4'],
#  ['irukachan2009', '4', '4'],
#  ['h503158', '25', '4'],
#  ['gungnir_info', '14', '4'],
#  ['funacyun1', '14', '4'],
#  ['femimatsu', '17', '4'],
#  ['el7777777', '17', '4'],
#  ['cometkobe', '16', '4'],
#  ['cafelattenaruto', '4', '4'],
#  ['blueskycoffeen1', '17', '4'],
#  ['ayuaayuuuun', '4', '4'],
#  ['ayapeace9love', '25', '4'],
#  ['a_bird_swimming', '17', '4'],
#  ['302_3317', '17', '4'],
#  ['0psskpj4a2qu0u7', '4', '4'],
#  ['zukky092', '17', '3'],
#  ['yurara0601', '14', '3'],
#  ['yuki_3_3837', '21', '3'],
#  ['yukarip', '16', '3'],
#  ['wren31680301', '17', '3'],
#  ['v0hjjhorjfvm1nl', '21', '3'],
#  ['umemiyabi', '4', '3'],
#  ['tv65377118', '17', '3'],
#  ['torakichi019852', '21', '3'],
#  ['timeformachine_', '4', '3'],
#  ['tebasakitoriri', '21', '3'],
#  ['skw5tmkoc69kxma', '17', '3'],
#  ['sholake2017', '17', '3'],
#  ['s38obajin', '1', '3'],
#  ['ryuwwda4adp5ib0', '21', '3'],
#  ['rocky20011001', '11', '3'],
#  ['qzmrtm3zlgvqvh7', '4', '3'],
#  ['pqyra5cqvx22ars', '11', '3'],
#  ['penguins_thief', '4', '3'],
#  ['p4iptlge7zcssyi', '14', '3'],
#  ['okei_suu', '25', '3'],
#  ['nyannyanryu1', '4', '3'],
#  ['nohiguchi', '4', '3'],
#  ['nh3aibrs1cwuaks', '25', '3'],
#  ['nakanotamagawa', '25', '3'],
#  ['muratamuramura', '0', '3'],
#  ['mizuki_earth', '21', '3'],
#  ['minamon_san', '17', '3'],
#  ['minaduki__jin', '4', '3'],
#  ['migikomigiko', '17', '3'],
#  ['mdriiiii33333', '21', '3'],
#  ['masa_mynews', '16', '3'],
#  ['livingstonjona5', '17', '3'],
#  ['litera_web', '25', '3'],
#  ['kouzou1982', '0', '3'],
#  ['kou20220312', '11', '3'],
#  ['kokkaisheep', '1', '3'],
#  ['kevin099455', '17', '3'],
#  ['kesuikenakamura', '4', '3'],
#  ['kaibutsu_k', '17', '3'],
#  ['irodada', '21', '3'],
#  ['iiyamaakari', '17', '3'],
#  ['hrs5758d', '4', '3'],
#  ['hiroshiok531', '16', '3'],
#  ['hetare_keieisha', '17', '3'],
#  ['henohen62544972', '4', '3'],
#  ['hayakawaz', '4', '3'],
#  ['halhal103', '16', '3'],
#  ['fuxxthxxshxx', '25', '3'],
#  ['fuji_kikyo', '17', '3'],
#  ['foryourinforma', '21', '3'],
#  ['floria_mint', '16', '3'],
#  ['eiyu_bot', '1', '3'],
#  ['cocochan000700', '0', '3'],
#  ['chchuru', '1', '3'],
#  ['catsfreaknokyo', '4', '3'],
#  ['c4ouuu45o5uq0zm', '17', '3'],
#  ['boeing78717', '1', '3'],
#  ['arimoto_kaori', '17', '3'],
#  ['anno_un', '17', '3'],
#  ['akahata_pr', '25', '3'],
#  ['32ohoqkrtpnupae', '4', '3'],
#  ['yoosi7777', '4', '2'],
#  ['yaponluq', '6', '2'],
#  ['y1j4ijwe2bxjzon', '17', '2'],
#  ['xmysyal6ngwevpa', '4', '2'],
#  ['w01453537', '21', '2'],
#  ['votune', '25', '2'],
#  ['va4inucsotdiqao', '17', '2'],
#  ['umebau', '17', '2'],
#  ['ugg26072', '25', '2'],
#  ['ugesama', '21', '2'],
#  ['tobatozankoudes', '25', '2'],
#  ['ten1998', '17', '2'],
#  ['tbnskugk2z3hcxe', '25', '2'],
#  ['taramo', '17', '2'],
#  ['t_iwagon', '17', '2'],
#  ['t2prw6harjwqr5s', '11', '2'],
#  ['syobo_n20xx', '4', '2'],
#  ['superwriterx', '4', '2'],
#  ['smartpapax', '17', '2'],
#  ['sin2nissi', '4', '2'],
#  ['shion23589524', '17', '2'],
#  ['shihrun', '6', '2'],
#  ['seresu1seresu', '17', '2'],
#  ['sawara201408', '17', '2'],
#  ['sat98635697', '17', '2'],
#  ['sao_nifu', '17', '2'],
#  ['runrunpon', '17', '2'],
#  ['roccavbnm', '21', '2'],
#  ['rimirinarisa', '25', '2'],
#  ['qjsvxt3g8atyprs', '17', '2'],
#  ['pastel_caree', '4', '2'],
#  ['otohu_oishii', '4', '2'],
#  ['nsumashi', '6', '2'],
#  ['nobuyoyagi', '1', '2'],
#  ['nnkitarohcoca', '25', '2'],
#  ['nekoshiroiro', '17', '2'],
#  ['nanasi1172', '6', '2'],
#  ['nakashima11', '17', '2'],
#  ['mtjnuami', '4', '2'],
#  ['momo_ni', '6', '2'],
#  ['mlkcoopers', '17', '2'],
#  ['mediabreaker21', '17', '2'],
#  ['matsuhis1', '17', '2'],
#  ['marimo34815947', '4', '2'],
#  ['m3llsquc35qdao0', '21', '2'],
#  ['lovehatecelery', '4', '2'],
#  ['lawer_ni_', '4', '2'],
#  ['kumax035', '17', '2'],
#  ['kokiakise', '11', '2'],
#  ['kimpiyo2', '11', '2'],
#  ['kidkaido', '21', '2'],
#  ['kenkichisandesu', '4', '2'],
#  ['kazenochisoku', '11', '2'],
#  ['katsu_m', '6', '2'],
#  ['k_soai', '4', '2'],
#  ['k2gtr', '25', '2'],
#  ['june990724', '17', '2'],
#  ['jeremy_l_mercy3', '17', '2'],
#  ['ja1hss', '4', '2'],
#  ['iqjb4p7gtchno5v', '4', '2'],
#  ['io_nanari', '25', '2'],
#  ['ieyezkobrcqsujz', '11', '2'],
#  ['huffpostjapan', '6', '2'],
#  ['hopesai6', '17', '2'],
#  ['hirox246', '4', '2'],
#  ['hakutaku2019', '17', '2'],
#  ['hachimachu', '17', '2'],
#  ['h_112358', '4', '2'],
#  ['gr_tst', '14', '2'],
#  ['gorori_go', '4', '2'],
#  ['gh2rfr7bqrmwnpg', '17', '2'],
#  ['ggxkmoi7vbswt6k', '17', '2'],
#  ['f_yamato', '25', '2'],
#  ['epj8ifbqej8ei6h', '17', '2'],
#  ['dreamer_k007', '4', '2'],
#  ['daikonmoti_moti', '17', '2'],
#  ['csyuvmhpcpyule1', '17', '2'],
#  ['crisis_japan', '17', '2'],
#  ['compnvhmaster', '17', '2'],
#  ['cocomaccow', '17', '2'],
#  ['chiyogami55', '17', '2'],
#  ['carp0422', '25', '2'],
#  ['cafe_meguriya', '16', '2'],
#  ['caddiensw', '17', '2'],
#  ['c80utp721xiicne', '25', '2'],
#  ['buuccibuco', '17', '2'],
#  ['bstbs1930', '17', '2'],
#  ['arienaikamo_s', '11', '2'],
#  ['appsddlg', '0', '2'],
#  ['akira_mori0120', '11', '2'],
#  ['akihiko_kadowak', '17', '2'],
#  ['airi_deshi_555', '17', '2'],
#  ['agenasu_odashi', '4', '2'],
#  ['_sebasho', '21', '2'],
#  ['92_taga', '11', '2'],
#  ['8edojx0gvorbqxk', '16', '2'],
#  ['5rkpft7w47tcdr9', '11', '2'],
#  ['1970khkh', '11', '2'],
#  ['121384tonikaku', '17', '2'],
#  ['zusx0g', '17', '1'],
#  ['zikokoteikan_', '17', '1'],
#  ['zicocouteican', '17', '1'],
#  ['yusuke3346', '17', '1'],
#  ['yurun_oyag', '17', '1'],
#  ['yumi_suginami', '17', '1'],
#  ['yukiysiva', '4', '1'],
#  ['yukiyoshi_gotoh', '17', '1'],
#  ['yukaspy007', '6', '1'],
#  ['ysv36gxuk', '4', '1'],
#  ['yoyamy3722301', '14', '1'],
#  ['yoshikyoshi', '4', '1'],
#  ['yoshi78511819', '25', '1'],
#  ['yopparaijpn666', '21', '1'],
#  ['yononakaheno', '4', '1'],
#  ['yonamineshogo', '17', '1'],
#  ['yomogimochi1', '11', '1'],
#  ['yomeguchixxx', '17', '1'],
#  ['yjsg8', '17', '1'],
#  ['yitabashi', '17', '1'],
#  ['yamazakimusashi', '21', '1'],
#  ['yamaimo1414', '21', '1'],
#  ['yamabe', '4', '1'],
#  ['yahata9692', '14', '1'],
#  ['xyzkh', '4', '1'],
#  ['wasabi15749807', '17', '1'],
#  ['vanillasiosio', '17', '1'],
#  ['unisuke178', '17', '1'],
#  ['um__homem', '16', '1'],
#  ['u1knbytu5uvmwl0', '17', '1'],
#  ['twr_kou', '4', '1'],
#  ['tsuruga60k', '17', '1'],
#  ['tsubaki_tsubomi', '16', '1'],
#  ['tosiho', '4', '1'],
#  ['tora8enl', '17', '1'],
#  ['tomo66388825', '17', '1'],
#  ['tomo50178072', '21', '1'],
#  ['tojibuta_san', '17', '1'],
#  ['to_i_toi_toi', '25', '1'],
#  ['tlexycfd6obza1g', '17', '1'],
#  ['timtomtamtemtum', '17', '1'],
#  ['thor_ntyr', '0', '1'],
#  ['tendou1977t', '17', '1'],
#  ['tayutaubear', '17', '1'],
#  ['taku8717893011', '4', '1'],
#  ['takeuchikumiffy', '11', '1'],
#  ['takahiro392002', '17', '1'],
#  ['taka_eha', '21', '1'],
#  ['ta_howait', '17', '1'],
#  ['ta1210', '4', '1'],
#  ['swu82963813', '4', '1'],
#  ['suzu056', '17', '1'],
#  ['sunetarouu', '4', '1'],
#  ['suka_t', '0', '1'],
#  ['studiobishop', '17', '1'],
#  ['strt30', '4', '1'],
#  ['sthuuall', '21', '1'],
#  ['spearsden', '17', '1'],
#  ['sowwwww1001', '17', '1'],
#  ['solo_0505', '11', '1'],
#  ['skynex4', '21', '1'],
#  ['skboyj2', '4', '1'],
#  ['simonumabe', '17', '1'],
#  ['simachekera', '17', '1'],
#  ['sigurekimi2023', '11', '1'],
#  ['shinpuu7', '21', '1'],
#  ['shikana22625318', '4', '1'],
#  ['shibagoroko', '17', '1'],
#  ['seifutonare', '17', '1'],
#  ['sciolismwriter', '17', '1'],
#  ['sasuke1614', '6', '1'],
#  ['salediroccia', '17', '1'],
#  ['sachikoohira', '14', '1'],
#  ['s8t8r9n0', '17', '1'],
#  ['rztfufkkm2fpu1l', '17', '1'],
#  ['ryuta06444330', '17', '1'],
#  ['ryuhin_aktry', '4', '1'],
#  ['runayama1', '17', '1'],
#  ['reon_trunks_ami', '17', '1'],
#  ['renkon33211147', '4', '1'],
#  ['rendez_voust', '25', '1'],
#  ['ra_mem_seiji', '4', '1'],
#  ['qt6gom6ywzi2lfj', '4', '1'],
#  ['q_951', '25', '1'],
#  ['pxokvnsdbeoxe9r', '4', '1'],
#  ['puuuma318', '1', '1'],
#  ['ponchoronyanko', '4', '1'],
#  ['politasjp', '16', '1'],
#  ['pepekun1388', '16', '1'],
#  ['pbiegjbol8tpzdz', '11', '1'],
#  ['parsleymerrymen', '4', '1'],
#  ['p5azxiwvlc6qutf', '4', '1'],
#  ['owloaompad2baxi', '17', '1'],
#  ['ouinon77097774', '25', '1'],
#  ['oryzias999', '6', '1'],
#  ['online_checker', '4', '1'],
#  ['omaegayouna', '17', '1'],
#  ['oi2dbzduog72kvp', '17', '1'],
#  ['nyantasista2019', '17', '1'],
#  ['nsja6vbffwiajj9', '11', '1'],
#  ['nqsbc', '17', '1'],
#  ['nozomi_ski', '4', '1'],
#  ['nosuke0607', '0', '1'],
#  ['norisuke78', '14', '1'],
#  ['nomoreofthatja1', '17', '1'],
#  ['nmnm_nmsn', '14', '1'],
#  ['niyari_honpo', '16', '1'],
#  ['nishiy2006', '25', '1'],
#  ['nied_inok', '14', '1'],
#  ['nemuribi', '16', '1'],
#  ['neco_1968', '11', '1'],
#  ['nasunasunaasu', '17', '1'],
#  ['nako2013', '4', '1'],
#  ['nakano0316', '6', '1'],
#  ['myosaisen', '4', '1'],
#  ['myers206', '25', '1'],
#  ['mvop4pcgdqmj2gf', '17', '1'],
#  ['murakenta', '6', '1'],
#  ['momog986_4', '17', '1'],
#  ['moko92397655', '25', '1'],
#  ['mofukamoshika', '16', '1'],
#  ['minotonefinland', '4', '1'],
#  ['miitan35367455', '17', '1'],
#  ['miduwo', '1', '1'],
#  ['michioha', '17', '1'],
#  ['mayumaro19', '17', '1'],
#  ['maxirem', '17', '1'],
#  ['masato76077469', '17', '1'],
#  ['masa_honto', '17', '1'],
#  ['marriott1968', '14', '1'],
#  ['mariri025', '17', '1'],
#  ['mari64takahashi', '4', '1'],
#  ['makrabin7', '17', '1'],
#  ['madamedebamboo', '4', '1'],
#  ['lovemymyoji', '4', '1'],
#  ['lily_lemon90', '17', '1'],
#  ['leechul7', '4', '1'],
#  ['kyokohou', '21', '1'],
#  ['kurineko235', '25', '1'],
#  ['kurikommm8j', '16', '1'],
#  ['kuma36026725', '14', '1'],
#  ['ksm_mam', '17', '1'],
#  ['kouzai2007', '14', '1'],
#  ['kotsubo48', '21', '1'],
#  ['kotani2013', '14', '1'],
#  ['kotamama318', '21', '1'],
#  ['kokoron8282', '6', '1'],
#  ['kojiyamada1966', '4', '1'],
#  ['kkrd20iv6kruem7', '17', '1'],
#  ['kintai2768', '11', '1'],
#  ['kinoko_survivor', '4', '1'],
#  ['kimonomike2', '17', '1'],
#  ['kikko_no_blog', '25', '1'],
#  ['keizokuramoto', '4', '1'],
#  ['kbusz10z7km57he', '4', '1'],
#  ['kaworutokotaro', '17', '1'],
#  ['kawataka_alter', '4', '1'],
#  ['kashiwa_actor', '4', '1'],
#  ['karakan_seizi', '17', '1'],
#  ['kaiwale703', '4', '1'],
#  ['kaburaya2013', '17', '1'],
#  ['junsk99', '21', '1'],
#  ['jpbakahakkenki', '17', '1'],
#  ['joshispa', '4', '1'],
#  ['joe007sn', '1', '1'],
#  ['jkx2etq1yl9i8x3', '17', '1'],
#  ['jico_goda', '21', '1'],
#  ['ji', '17', '1'],
#  ['jane_m3', '21', '1'],
#  ['jackey81421082', '17', '1'],
#  ['jack88912057', '17', '1'],
#  ['j_sakkin', '25', '1'],
#  ['iwaataaa', '17', '1'],
#  ['ital_inouye', '4', '1'],
#  ['is7h5y6ok4ca3j8', '17', '1'],
#  ['infocenter2021', '4', '1'],
#  ['imari1217', '14', '1'],
#  ['ikaryakuchan', '17', '1'],
#  ['ikarioyajl', '21', '1'],
#  ['ifmari', '4', '1'],
#  ['ibrxdbxmiwsabns', '16', '1'],
#  ['i_like_lambmeat', '21', '1'],
#  ['hzqxvcekkn5qmow', '17', '1'],
#  ['hosyu_jk3', '17', '1'],
#  ['hoshimogmog', '4', '1'],
#  ['hikasu', '6', '1'],
#  ['hichachu', '6', '1'],
#  ['hayate689', '11', '1'],
#  ['hara_shimpei', '4', '1'],
#  ['hakofugu_net', '21', '1'],
#  ['hagiwara_ryo', '16', '1'],
#  ['h8radrlokg2w2kr', '4', '1'],
#  ['gsdhu0dl3sp9z1z', '17', '1'],
#  ['goruzo13nippon', '21', '1'],
#  ['googlecloud_jp', '4', '1'],
#  ['gomasaba_duke', '21', '1'],
#  ['glc_japan', '17', '1'],
#  ['gin_camp', '17', '1'],
#  ['gianfranco_zora', '4', '1'],
#  ['ghettoorgan', '16', '1'],
#  ['genki2010', '25', '1'],
#  ['gay_yagi', '16', '1'],
#  ['garix9', '17', '1'],
#  ['gantaro1945', '4', '1'],
#  ['ganonk114', '17', '1'],
#  ['games_plarium', '4', '1'],
#  ['gamechangefreak', '11', '1'],
#  ['gaitifuji', '25', '1'],
#  ['funkymegane', '4', '1'],
#  ['fukubonzzz', '17', '1'],
#  ['fukjyai', '17', '1'],
#  ['forthman', '16', '1'],
#  ['fooh32', '4', '1'],
#  ['flying__father', '4', '1'],
#  ['felicishatch', '4', '1'],
#  ['f_youdo', '17', '1'],
#  ['f1skywlkr_jdi', '17', '1'],
#  ['esmdcre', '14', '1'],
#  ['eri_arfiya', '21', '1'],
#  ['englishtempwor1', '14', '1'],
#  ['engeki_shimizu', '25', '1'],
#  ['ebisu_mom', '17', '1'],
#  ['e5ibob5ny736qul', '21', '1'],
#  ['dositavikke1126', '17', '1'],
#  ['daboso', '17', '1'],
#  ['cyxuaxfglffzzct', '11', '1'],
#  ['cy4ykf1l', '6', '1'],
#  ['crybabyto', '25', '1'],
#  ['cristoforou', '1', '1'],
#  ['cozytahara', '21', '1'],
#  ['color_snow1101', '11', '1'],
#  ['christweekly', '1', '1'],
#  ['chosi812', '17', '1'],
#  ['chocohamu__', '17', '1'],
#  ['chisato_kamui', '11', '1'],
#  ['chinjo_hokkaido', '4', '1'],
#  ['chichimama73', '11', '1'],
#  ['chamiq', '17', '1'],
#  ['bubu_de_la_ma', '16', '1'],
#  ['bluerosemoon1', '21', '1'],
#  ['blochbenjamin', '16', '1'],
#  ['black_joke_chan', '14', '1'],
#  ['bessei2018', '4', '1'],
#  ['belzedaro', '17', '1'],
#  ['baribarivary3', '16', '1'],
#  ['ayame_tomokaji', '4', '1'],
#  ['atsukofuji', '4', '1'],
#  ['ashipro7830', '4', '1'],
#  ['asahicom', '4', '1'],
#  ['arielcookieliu', '16', '1'],
#  ['aria6663', '17', '1'],
#  ['apprtranslator', '17', '1'],
#  ['anjuro_anjuro', '17', '1'],
#  ['angelpie2010', '17', '1'],
#  ['amiba', '17', '1'],
#  ['ami_snowleopard', '21', '1'],
#  ['alpha369omega', '11', '1'],
#  ['alma0707', '1', '1'],
#  ['akishmz', '4', '1'],
#  ['akiofan9191', '25', '1'],
#  ['akihikokondosk', '4', '1'],
#  ['akaisuisei_sab', '6', '1'],
#  ['ajqadjqvsdiqinp', '21', '1'],
#  ['ahonotakao', '0', '1'],
#  ['aelwoyo403sc09l', '4', '1'],
#  ['a_ssann', '25', '1'],
#  ['a_mememe_a', '4', '1'],
#  ['9ohh0s8x6yv5zlr', '4', '1'],
#  ['8z3zps', '21', '1'],
#  ['770125t', '25', '1'],
#  ['5kldy4a9atlrz1g', '17', '1'],
#  ['5283kazumaru', '17', '1'],
#  ['42tlapping09', '25', '1'],
#  ['3nico3', '21', '1'],
#  ['1ovelynews', '6', '1'],
#  ['1125monaca', '14', '1'],
#  ['100yenri_to', '17', '1'],
#  ['0917chiaki917', '11', '1'],
#  ['zzzoomy_56', '25', '0'],
#  ['zyjkun7kzroakuo', '14', '0'],
#  ['zxcvbn7531', '14', '0'],
#  ['zx600e_1994', '11', '0'],
#  ['zx2j0pmnewwuyak', '11', '0'],
#  ['zwzk3egxmcotkhd', '14', '0'],
#  ['zwvyobei8gxqyfa', '25', '0'],
#  ['zwingli39', '6', '0'],
#  ['zuzfd24mu9m8gva', '14', '0'],
#  ['zurapayo', '17', '0'],
#  ['zuk8f4yo3astrp0', '11', '0'],
#  ['zuizuimi', '14', '0'],
#  ['zuhan_ekaki', '1', '0'],
#  ['zube76hfjidpn2z', '14', '0'],
#  ['zubat3jyou', '1', '0'],
#  ['ztdw0120', '21', '0'],
#  ['zs3vjphjthcclku', '16', '0'],
#  ['zrzsgqib3fcvwuo', '14', '0'],
#  ['zqsaidpssfibd7a', '14', '0'],
#  ['zpp_10', '1', '0'],
#  ['zozo_mushi', '1', '0'],
#  ['zovajpypsiiqfcm', '14', '0'],
#  ['zoushima3', '11', '0'],
#  ['zotiqkok02mhvyr', '25', '0'],
#  ['zooon1151016', '21', '0'],
#  ['zonnchang', '21', '0'],
#  ['zonexkaoru', '6', '0'],
#  ['zokbt2timwzcwr6', '25', '0'],
#  ['zoetropezooey', '1', '0'],
#  ['zodiacaldust', '16', '0'],
#  ['znskhr', '6', '0'],
#  ['znpajrnctaiupdv', '14', '0'],
#  ['zmnmezu81kmpcvw', '4', '0'],
#  ['zmaririnz', '1', '0'],
#  ['zlufbcdbgq0ssxg', '11', '0'],
#  ['zkwuwxscfnfos4x', '1', '0'],
#  ['zjxjzf3xkhlifjx', '11', '0'],
#  ['zizi97401232', '21', '0'],
#  ['zivacray', '21', '0'],
#  ['ziplock', '16', '0'],
#  ['zinofrancescatt', '6', '0'],
#  ['zin_bnar', '1', '0'],
#  ['zimt6j9gawsdnhv', '14', '0'],
#  ['zimmyisfakestar', '6', '0'],
#  ['ziguzagu0721', '6', '0'],
#  ['zig66experience', '21', '0'],
#  ['zhzyxpenfb9qtcr', '11', '0'],
#  ['zh3qtfy5lhksgdt', '11', '0'],
#  ['zgwxxm0oqsyg11s', '11', '0'],
#  ['zgmf_yx21r', '21', '0'],
#  ['zg6b0tlwrgsempn', '21', '0'],
#  ['zfwxiahva8bcp52', '17', '0'],
#  ['zfphcngojjubdhh', '14', '0'],
#  ['zeroyen0yen_mhw', '14', '0'],
#  ['zerosp2017061', '0', '0'],
#  ['zeroset7', '6', '0'],
#  ['zeroniwasi', '21', '0'],
#  ['zerofightercat', '17', '0'],
#  ['zerobuster_g', '16', '0'],
#  ['zephyr400zc', '21', '0'],
#  ['zenko0813', '1', '0'],
#  ['zen30567645', '21', '0'],
#  ['zeg8ew3vky2v6lm', '14', '0'],
#  ['zeclufc0liutyo0', '11', '0'],
#  ['zebrajunjun', '21', '0'],
#  ['zebra_masa', '6', '0'],
#  ['ze_llo', '1', '0'],
#  ['ze2kso2hvyhzowo', '21', '0'],
#  ['zdkbnt6xprueu3b', '11', '0'],
#  ['zclfzql4ije7wen', '16', '0'],
#  ['zbanchi', '4', '0'],
#  ['zavsxsphk5h1riz', '21', '0'],
#  ['zassou2828', '1', '0'],
#  ['zapp102', '1', '0'],
#  ['zany46325', '11', '0'],
#  ['zanopmjbzgfqw75', '6', '0'],
#  ['zamaaaaaneeeee', '1', '0'],
#  ['zakuzaku_sennin', '11', '0'],
#  ['zakuro_ishi', '1', '0'],
#  ['zaklafkintore', '1', '0'],
#  ['zaklab', '0', '0'],
#  ['zakihacky', '0', '0'],
#  ['zaiyanjp45', '11', '0'],
#  ['z8wvww8wzqo6ds1', '14', '0'],
#  ['z7dee5fafayz7', '14', '0'],
#  ['z73lvpb10boat7i', '11', '0'],
#  ['z5u7y2', '11', '0'],
#  ['z36ixgxm11qfjp2', '14', '0'],
#  ['z354hcx2d5z3hxm', '4', '0'],
#  ['z2fwanuqnomlgqx', '21', '0'],
#  ['z25099843950', '11', '0'],
#  ['z1j6awkkug04xus', '11', '0'],
#  ['z0uccb998fdc8ox', '21', '0'],
#  ['z0ru70yy6int0ol', '25', '0'],
#  ['yzw7hiysda2wjdp', '1', '0'],
#  ['yzvhljrzvoqy0ge', '11', '0'],
#  ['yz_pey', '1', '0'],
#  ['yyuyama', '11', '0'],
#  ['yyrr528088471', '11', '0'],
#  ['yyoshiy1208y', '11', '0'],
#  ['yyoajii275', '0', '0'],
#  ['yyage', '6', '0'],
#  ['yy22647823', '17', '0'],
#  ['yxtxkx10161017', '6', '0'],
#  ['yxjiiuqemjomviv', '14', '0'],
#  ['yxf2ge60m0tkvio', '21', '0'],
#  ['ywa5cgccnzy3kv1', '21', '0'],
#  ['yvespiagetblanc', '25', '0'],
#  ['yuzu29soda', '17', '0'],
#  ['yuzu03141', '21', '0'],
#  ['yuz_uki1', '25', '0'],
#  ['yuyuyuyuyuwatch', '6', '0'],
#  ['yuyuyunoyuyuco', '1', '0'],
#  ['yuyuyo96298305', '17', '0'],
#  ['yuyu_yuyuchan', '21', '0'],
#  ['yuyu68728041', '21', '0'],
#  ['yuwatwit', '11', '0'],
#  ['yuuuuulo1', '21', '0'],
#  ['yuuumitwitta', '1', '0'],
#  ['yuuu129_', '21', '0'],
#  ['yuuryo5', '16', '0'],
#  ['yuuna06102000', '1', '0'],
#  ['yuumomo12321', '11', '0'],
#  ['yuuko2335', '14', '0'],
#  ['yuukanno', '25', '0'],
#  ['yuuka_eve', '14', '0'],
#  ['yuuk_kkrbgduse', '14', '0'],
#  ['yuuhi2', '6', '0'],
#  ['yuu268140', '14', '0'],
#  ['yuto814', '1', '0'],
#  ['yute_tet', '21', '0'],
#  ['yutapon3512', '0', '0'],
#  ['yutam86', '11', '0'],
#  ['yutakunayachan', '4', '0'],
#  ['yutakakitamaru', '14', '0'],
#  ['yut_2022su', '21', '0'],
#  ['yurumelt', '21', '0'],
#  ['yurukyaraojisan', '14', '0'],
#  ['yurucoponco', '0', '0'],
#  ['yuru2biost', '4', '0'],
#  ['yuriwaka0809', '6', '0'],
#  ['yurio904', '1', '0'],
#  ['yurinsaka', '21', '0'],
#  ['yurikonmoz', '16', '0'],
#  ['yurikarin_read', '21', '0'],
#  ['yuriakatase2', '0', '0'],
#  ['yuri4sakura', '16', '0'],
#  ['yuri37905240', '25', '0'],
#  ['yupipi_papiko', '14', '0'],
#  ['yupioniyupi', '21', '0'],
#  ['yupidzi', '11', '0'],
#  ['yuomatak', '4', '0'],
#  ['yuofromipanema', '25', '0'],
#  ['yunogozu', '4', '0'],
#  ['yunishio', '6', '0'],
#  ['yumo37383579', '11', '0'],
#  ['yumipon45', '21', '0'],
#  ['yuming1024', '1', '0'],
#  ['yumikoy', '1', '0'],
#  ['yumikinnn', '1', '0'],
#  ['yumidorian', '21', '0'],
#  ['yumico89z', '17', '0'],
#  ['yumi_yumi_koko', '1', '0'],
#  ['yumi_shinamon', '21', '0'],
#  ['yumi_mts', '1', '0'],
#  ['yumeyume20164', '11', '0'],
#  ['yumekanau39net1', '14', '0'],
#  ['yumehome', '11', '0'],
#  ['yume8izumi', '6', '0'],
#  ['yume10ken', '14', '0'],
#  ['yumato954', '11', '0'],
#  ['yulii_smirnoff', '11', '0'],
#  ['yukuri195', '11', '0'],
#  ['yukukawa3476', '11', '0'],
#  ['yuku89457342', '4', '0'],
#  ['yukohori2', '11', '0'],
#  ['yukoakeve', '21', '0'],
#  ['yuknog', '0', '0'],
#  ['yukky787', '14', '0'],
#  ['yukky747747', '11', '0'],
#  ['yukkopost', '21', '0'],
#  ['yukitarowww', '0', '0'],
#  ['yukisuke18', '21', '0'],
#  ['yukiqlair', '16', '0'],
#  ['yukio987654321', '16', '0'],
#  ['yukinomitsuki', '1', '0'],
#  ['yukinoinoue1', '21', '0'],
#  ['yukino0201', '25', '0'],
#  ['yukineko_28n28n', '1', '0'],
#  ['yukina39', '0', '0'],
#  ['yukimaru2200', '16', '0'],
#  ['yukimar92366746', '14', '0'],
#  ['yukikopool', '21', '0'],
#  ['yukiko45828', '4', '0'],
#  ['yukik10281', '21', '0'],
#  ['yuki_yukiki___', '25', '0'],
#  ['yuki_in_pj', '6', '0'],
#  ['yuki_abe6', '17', '0'],
#  ['yuki777666', '6', '0'],
#  ['yuki14', '1', '0'],
#  ['yuketta77', '14', '0'],
#  ['yukemurimochi', '1', '0'],
#  ['yukarigasane', '4', '0'],
#  ['yukarienne', '1', '0'],
#  ['yukaace_1132', '1', '0'],
#  ['yuka__ko', '0', '0'],
#  ['yuka371658', '6', '0'],
#  ['yuka112814', '16', '0'],
#  ['yuk0117', '1', '0'],
#  ['yujitashi', '6', '0'],
#  ['yujinoaim', '6', '0'],
#  ['yuji_kzk', '6', '0'],
#  ['yuiboo1127', '25', '0'],
#  ['yui2051wing', '21', '0'],
#  ['yuhohtaka', '0', '0'],
#  ['yuha84002885', '6', '0'],
#  ['yugayug01511120', '17', '0'],
#  ['yufuintacos1', '14', '0'],
#  ['yufuin_g', '11', '0'],
#  ['yuchunrd', '6', '0'],
#  ['yuba0803', '1', '0'],
#  ['yuai_church', '0', '0'],
#  ['yu_no_cha', '1', '0'],
#  ['yu_mojarra', '6', '0'],
#  ['yu_metamorphose', '21', '0'],
#  ['yu_ku_yu_ku', '17', '0'],
#  ['yu_kotyan', '6', '0'],
#  ['yu__1962', '6', '0'],
#  ['yu99918230', '4', '0'],
#  ['yu2kama', '14', '0'],
#  ['yu2001_ari2003', '11', '0'],
#  ['yty889', '25', '0'],
#  ['ytsgpjrzvqsobci', '16', '0'],
#  ['ytj6tk9aiyuyo7v', '11', '0'],
#  ['ythdlrdz6fueoxg', '6', '0'],
#  ['yt0124space', '6', '0'],
#  ['ysyk4eva', '6', '0'],
#  ['yswakkedxy2xrwa', '1', '0'],
#  ['ysuzu15', '11', '0'],
#  ['ysmc_tanaka', '11', '0'],
#  ['yshibuyatokyo', '25', '0'],
#  ['yrht4fqbnhglgr9', '25', '0'],
#  ['yrbq2urkqr05cme', '1', '0'],
#  ['yqsft1k4cfxjehu', '11', '0'],
#  ['yqmr7adabv1amhu', '16', '0'],
#  ['yq7mxbqvyz3q1e4', '6', '0'],
#  ['ypzhqyrlyfaxcij', '14', '0'],
#  ['yptbbpcnxyoyggj', '0', '0'],
#  ['yplrnwsrssjwzva', '11', '0'],
#  ['ypdpfcqlapo2sgw', '6', '0'],
#  ['yoyoyo_baha', '21', '0'],
#  ['yoyoyo05555', '11', '0'],
#  ['yowkuro', '17', '0'],
#  ['yowaineko', '11', '0'],
#  ['youturn1980', '0', '0'],
#  ['youtube48628832', '11', '0'],
#  ['youshiyadaisuki', '6', '0'],
#  ['yousato_risei', '21', '0'],
#  ['yourchoicepeace', '6', '0'],
#  ['youma_jukai', '16', '0'],
#  ['youheimetal', '25', '0'],
#  ['yougonara', '16', '0'],
#  ['youcand44474105', '25', '0'],
#  ['you_tarou01', '17', '0'],
#  ['you_psy', '6', '0'],
#  ['you_0358', '11', '0'],
#  ['you26767', '11', '0'],
#  ['yot07814', '16', '0'],
#  ['yossy32gtr', '21', '0'],
#  ['yossiibook', '14', '0'],
#  ['yossie89180000', '25', '0'],
#  ['yosiroumiyuisi', '21', '0'],
#  ['yosidycltgkyrwz', '25', '0'],
#  ['yosi220', '14', '0'],
#  ['yosi0605', '6', '0'],
#  ['yoshnoiz', '6', '0'],
#  ['yoshito2906', '21', '0'],
#  ['yoshiokayuji', '14', '0'],
#  ['yoshioka36', '17', '0'],
#  ['yoshinene', '14', '0'],
#  ['yoshimisa1227', '4', '0'],
#  ['yoshikitakeishi', '17', '0'],
#  ['yoshiki_tourabu', '1', '0'],
#  ['yoshikazum4', '14', '0'],
#  ['yoshikatsu_www', '21', '0'],
#  ['yoshihiromori11', '6', '0'],
#  ['yoshihirohorii', '6', '0'],
#  ['yoshihiro_abe', '6', '0'],
#  ['yoshiharuusui', '6', '0'],
#  ['yoshiehitomi', '25', '0'],
#  ['yoshidaouri', '21', '0'],
#  ['yoshiane', '1', '0'],
#  ['yoshi_ham', '4', '0'],
#  ['yoshi857616758', '14', '0'],
#  ['yoshi67144140', '21', '0'],
#  ['yorunimau', '1', '0'],
#  ['yoru_stern', '1', '0'],
#  ['yorozuya37', '0', '0'],
#  ['yorokobinokabe', '0', '0'],
#  ['yoroimyheart8', '11', '0'],
#  ['yorkwing', '4', '0'],
#  ['yoriyoinekocyan', '21', '0'],
#  ['yoricchi46', '16', '0'],
#  ['yoppie0319', '25', '0'],
#  ['yomoyashi', '17', '0'],
#  ['yomibitoshirazu', '21', '0'],
#  ['yome0930', '17', '0'],
#  ['yokyun68k', '1', '0'],
#  ['yokotunashima', '11', '0'],
#  ['yokomori555', '14', '0'],
#  ['yokoalacarte', '6', '0'],
#  ['yokko51900', '14', '0'],
#  ['yojiro10haruki', '1', '0'],
#  ['yoizo3', '1', '0'],
#  ['yoitenki3', '14', '0'],
#  ['yoikuni_1192', '6', '0'],
#  ['yoici', '25', '0'],
#  ['yohno1963', '14', '0'],
#  ['yohkomaya', '1', '0'],
#  ['yohko_anego', '1', '0'],
#  ['yoh21071430', '6', '0'],
#  ['yogc8tm', '17', '0'],
#  ['yog_s29', '6', '0'],
#  ['yodosakisan', '21', '0'],
#  ['yodobasiend', '6', '0'],
#  ['yocchi009', '11', '0'],
#  ['yoakemaedayo', '16', '0'],
#  ['yo4fwx48wz3sleo', '14', '0'],
#  ['yo4410ra', '1', '0'],
#  ['ynlib07', '14', '0'],
#  ['ynanica', '1', '0'],
#  ['yn0027', '21', '0'],
#  ['ymtb50', '0', '0'],
#  ['ymonku1y', '17', '0'],
#  ['ymmt1970hrs', '4', '0'],
#  ['ymdr4989', '1', '0'],
#  ['ymdarling5', '11', '0'],
#  ['ylx6bwa5t8fhf6b', '11', '0'],
#  ['ykwtsk_z', '16', '0'],
#  ['ykuodubvcs2drar', '1', '0'],
#  ['yksj', '6', '0'],
#  ['ykn524396175', '14', '0'],
#  ['ykn19fky5d0nlvl', '21', '0'],
#  ['ykkic', '1', '0'],
#  ['ykid1olcexq2r0y', '11', '0'],
#  ['yj7wotl7awytpql', '1', '0'],
#  ['yj3lrexo2kdt8r1', '11', '0'],
#  ['yishiaki1', '14', '0'],
#  ['yikura7', '4', '0'],
#  ['yikaynfmk03b', '4', '0'],
#  ['yhashigen', '16', '0'],
#  ['yh04137539', '14', '0'],
#  ['ygsxobfop2qz0vs', '11', '0'],
#  ['ygrgeyzz8vjq377', '14', '0'],
#  ['ygloc4relo1xls4', '11', '0'],
#  ['ygenxchxqfbp0pi', '6', '0'],
#  ['yfyspwysen7opvr', '21', '0'],
#  ['yfa35860', '16', '0'],
#  ['yf47595480', '21', '0'],
#  ['yeybi3l7qhwnwe0', '11', '0'],
#  ['yellowgreeeen58', '21', '0'],
#  ['yellow_x_metal', '11', '0'],
#  ['yekou02', '1', '0'],
#  ['ycwg5hxiezcbgtx', '6', '0'],
#  ['ycorey55', '4', '0'],
#  ['ycie0qgdnjzgvqe', '25', '0'],
#  ['yba7grimanceuhu', '14', '0'],
#  ['yb7vz', '21', '0'],
#  ['yayuzerowqu0504', '16', '0'],
#  ['yayu_uu', '16', '0'],
#  ['yayoikoume0622', '21', '0'],
#  ['yayakoshiya310', '6', '0'],
#  ['yatumimi', '4', '0'],
#  ['yatsugatake1229', '21', '0'],
#  ['yasuyukima', '4', '0'],
#  ['yasuwo_chan', '1', '0'],
#  ['yasukunig', '11', '0'],
#  ['yasukunieirei', '21', '0'],
#  ['yasuko2773', '6', '0'],
#  ['yasuke43', '14', '0'],
#  ...]

# %%
top_communities.n_communities
# Out:
# 359

# %%
top_communities.modularity
# Out:
# 0.77

# %%
nodes_data
# Out:
# [['oriak9', '1', '1512'],
#  ['hotaka_tsukada', '6', '1393'],
#  ['nipponkairagi', '11', '1344'],
#  ['seiryukai', '21', '1218'],
#  ['aiko33151709', '14', '1189'],
#  ['quitamarco', '0', '585'],
#  ['nana77rey1', '4', '322'],
#  ['ssimtok', '16', '298'],
#  ['yampisun40', '17', '197'],
#  ['chizurua1', '25', '178'],
#  ['shop_kakiko', '11', '124'],
#  ['kenkenrokujapan', '17', '106'],
#  ['mi89s1', '25', '104'],
#  ['hosakanobuto', '16', '95'],
#  ['5sasha5sasha5', '6', '92'],
#  ['nwfle6q9vqtxb4q', '17', '71'],
#  ['quotationmark95', '25', '64'],
#  ['yoboudr_op', '4', '59'],
#  ['id_seiron', '17', '55'],
#  ['grayengineer', '17', '53'],
#  ['sollevante2022', '4', '50'],
#  ['w4f75x7mj9i2gdb', '17', '45'],
#  ['oosakahaoosaka', '25', '44'],
#  ['h_koyuyu', '17', '43'],
#  ['yuki1988jp', '25', '41'],
#  ['kakitama', '16', '41'],
#  ['haguruma0830', '17', '38'],
#  ['starship_glory', '21', '35'],
#  ['powertopeople5', '25', '34'],
#  ['run_and_walk_', '4', '32'],
#  ['nikone_25', '21', '32'],
#  ['jinn11', '25', '31'],
#  ['pokhara1995', '4', '28'],
#  ['eo8rmt2mkzu3eo6', '4', '28'],
#  ['hasegawakenjiro', '6', '27'],
#  ['marine_blueo', '4', '26'],
#  ['kenkyukenkyu2', '21', '26'],
#  ['bessei_family', '4', '26'],
#  ['uirousakura', '6', '25'],
#  ['besseibot', '4', '25'],
#  ['cosmicworld000', '17', '24'],
#  ['p2ie9tqrwnz3qq0', '11', '21'],
#  ['pablichenkosssr', '17', '20'],
#  ['naagita', '6', '19'],
#  ['hachikogumo', '17', '19'],
#  ['code_dia', '17', '19'],
#  ['aono', '17', '19'],
#  ['suzumiya_na_gi', '4', '18'],
#  ['stc_bp100', '4', '18'],
#  ['_neko_aruku', '4', '18'],
#  ['ohaginokao3181', '4', '17'],
#  ['gun81288955', '17', '17'],
#  ['chilira_la29', '4', '17'],
#  ['umemura_gifu', '17', '16'],
#  ['yshdykhr', '6', '15'],
#  ['yamami_open', '17', '15'],
#  ['sugiyama766', '17', '15'],
#  ['shige_death', '6', '15'],
#  ['na7719961212', '4', '15'],
#  ['hug_hug519', '17', '15'],
#  ['yucchi0i0', '4', '14'],
#  ['x2can3joy', '4', '14'],
#  ['moeruasia01', '17', '14'],
#  ['katalernejo', '4', '14'],
#  ['higuras2018', '17', '14'],
#  ['alloemloveu', '4', '14'],
#  ['sspmi', '6', '13'],
#  ['rockhearts737', '4', '13'],
#  ['mrjombxev6xdu9c', '4', '13'],
#  ['grapefruitsjui2', '4', '13'],
#  ['edokaiki', '11', '13'],
#  ['turbo0421', '17', '12'],
#  ['milmilk6', '4', '12'],
#  ['choroi_silica', '17', '12'],
#  ['bokuranoijyu', '0', '12'],
#  ['aurxcanjyw3epxs', '4', '12'],
#  ['yumemigachi24', '25', '11'],
#  ['saya_fairyland', '4', '11'],
#  ['ryantan315', '4', '11'],
#  ['nasitaro', '6', '11'],
#  ['likedreply', '17', '11'],
#  ['7q3dsgoqopixflu', '25', '11'],
#  ['ts80115785', '4', '10'],
#  ['skyyard_sora', '17', '10'],
#  ['sabutibi777', '4', '10'],
#  ['puyodora', '17', '10'],
#  ['orenama', '4', '10'],
#  ['k__e_i', '21', '10'],
#  ['jimin_koho', '17', '10'],
#  ['4hnnwuz3lmecs9d', '4', '10'],
#  ['taka_paris', '16', '9'],
#  ['subaru1000', '4', '9'],
#  ['racoon1120', '4', '9'],
#  ['okonomiyaki2099', '4', '9'],
#  ['okihara_taichi', '4', '9'],
#  ['mihoiida_tw', '4', '9'],
#  ['kawai_kanyu', '1', '9'],
#  ['japanese0456', '17', '9'],
#  ['dr_mashiritosan', '17', '9'],
#  ['aoigogatu', '17', '9'],
#  ['aircraftcarrer', '17', '9'],
#  ['nakanishib', '6', '8'],
#  ['maribctchan', '11', '8'],
#  ['koikeyoshitaka', '17', '8'],
#  ['kamifuusen7161', '4', '8'],
#  ['jomaruyan', '25', '8'],
#  ['axzfptbughjctvf', '11', '8'],
#  ['yossense', '4', '7'],
#  ['ryoma09012', '17', '7'],
#  ['resipatriot', '17', '7'],
#  ['ndelnyzgpdtvgzz', '4', '7'],
#  ['kowya444', '17', '7'],
#  ['a_gochiu3power', '17', '7'],
#  ['xoqbs1krynzlqov', '17', '6'],
#  ['torepan_sensei', '4', '6'],
#  ['thequxq', '17', '6'],
#  ['speed540', '4', '6'],
#  ['risapeori', '17', '6'],
#  ['product1954', '25', '6'],
#  ['mu9pmtylvahabi9', '4', '6'],
#  ['lautream', '6', '6'],
#  ['kusikurage', '4', '6'],
#  ['kayuumaatsui', '4', '6'],
#  ['karajin228', '4', '6'],
#  ['bluezlee_', '25', '6'],
#  ['awayukinosuke', '17', '6'],
#  ['aiainstein', '4', '6'],
#  ['ae24vi7efq387k1', '21', '6'],
#  ['2kuow', '21', '6'],
#  ['yone147258369', '4', '5'],
#  ['wata_nabekyo_ko', '17', '5'],
#  ['vnrespectfn', '4', '5'],
#  ['ticktack08241', '17', '5'],
#  ['reimu_marisa_y', '17', '5'],
#  ['neko_de_ne', '17', '5'],
#  ['manna2010able', '16', '5'],
#  ['la_neige_fleur', '4', '5'],
#  ['kurrymurry', '4', '5'],
#  ['kiris_kirimura', '4', '5'],
#  ['kikumaco', '17', '5'],
#  ['ito_mikiko', '4', '5'],
#  ['hammern666', '17', '5'],
#  ['ftth', '1', '5'],
#  ['cross0830', '17', '5'],
#  ['celebrateones15', '17', '5'],
#  ['anohitosaccount', '4', '5'],
#  ['zztyv6vdcnkulnm', '17', '4'],
#  ['yossik091', '25', '4'],
#  ['yamatoji', '4', '4'],
#  ['vwatv6', '4', '4'],
#  ['v3xwhhofecqxy7p', '17', '4'],
#  ['uncle_dagon', '0', '4'],
#  ['tomatotacotoma', '17', '4'],
#  ['tm2501', '11', '4'],
#  ['tetsulovebird', '17', '4'],
#  ['ssa90751853', '4', '4'],
#  ['sd_t2w', '21', '4'],
#  ['pp_giraud', '4', '4'],
#  ['opaku_trainkit', '17', '4'],
#  ['noguchi1706', '17', '4'],
#  ['mydream555', '17', '4'],
#  ['mukaituru', '17', '4'],
#  ['masumit17', '17', '4'],
#  ['macback1986', '25', '4'],
#  ['kenjitsukagoshi', '0', '4'],
#  ['k2bo5rrsaajadk5', '17', '4'],
#  ['jikangahayai', '4', '4'],
#  ['irukachan2009', '4', '4'],
#  ['h503158', '25', '4'],
#  ['gungnir_info', '14', '4'],
#  ['funacyun1', '14', '4'],
#  ['femimatsu', '17', '4'],
#  ['el7777777', '17', '4'],
#  ['cometkobe', '16', '4'],
#  ['cafelattenaruto', '4', '4'],
#  ['blueskycoffeen1', '17', '4'],
#  ['ayuaayuuuun', '4', '4'],
#  ['ayapeace9love', '25', '4'],
#  ['a_bird_swimming', '17', '4'],
#  ['302_3317', '17', '4'],
#  ['0psskpj4a2qu0u7', '4', '4'],
#  ['zukky092', '17', '3'],
#  ['yurara0601', '14', '3'],
#  ['yuki_3_3837', '21', '3'],
#  ['yukarip', '16', '3'],
#  ['wren31680301', '17', '3'],
#  ['v0hjjhorjfvm1nl', '21', '3'],
#  ['umemiyabi', '4', '3'],
#  ['tv65377118', '17', '3'],
#  ['torakichi019852', '21', '3'],
#  ['timeformachine_', '4', '3'],
#  ['tebasakitoriri', '21', '3'],
#  ['skw5tmkoc69kxma', '17', '3'],
#  ['sholake2017', '17', '3'],
#  ['s38obajin', '1', '3'],
#  ['ryuwwda4adp5ib0', '21', '3'],
#  ['rocky20011001', '11', '3'],
#  ['qzmrtm3zlgvqvh7', '4', '3'],
#  ['pqyra5cqvx22ars', '11', '3'],
#  ['penguins_thief', '4', '3'],
#  ['p4iptlge7zcssyi', '14', '3'],
#  ['okei_suu', '25', '3'],
#  ['nyannyanryu1', '4', '3'],
#  ['nohiguchi', '4', '3'],
#  ['nh3aibrs1cwuaks', '25', '3'],
#  ['nakanotamagawa', '25', '3'],
#  ['muratamuramura', '0', '3'],
#  ['mizuki_earth', '21', '3'],
#  ['minamon_san', '17', '3'],
#  ['minaduki__jin', '4', '3'],
#  ['migikomigiko', '17', '3'],
#  ['mdriiiii33333', '21', '3'],
#  ['masa_mynews', '16', '3'],
#  ['livingstonjona5', '17', '3'],
#  ['litera_web', '25', '3'],
#  ['kouzou1982', '0', '3'],
#  ['kou20220312', '11', '3'],
#  ['kokkaisheep', '1', '3'],
#  ['kevin099455', '17', '3'],
#  ['kesuikenakamura', '4', '3'],
#  ['kaibutsu_k', '17', '3'],
#  ['irodada', '21', '3'],
#  ['iiyamaakari', '17', '3'],
#  ['hrs5758d', '4', '3'],
#  ['hiroshiok531', '16', '3'],
#  ['hetare_keieisha', '17', '3'],
#  ['henohen62544972', '4', '3'],
#  ['hayakawaz', '4', '3'],
#  ['halhal103', '16', '3'],
#  ['fuxxthxxshxx', '25', '3'],
#  ['fuji_kikyo', '17', '3'],
#  ['foryourinforma', '21', '3'],
#  ['floria_mint', '16', '3'],
#  ['eiyu_bot', '1', '3'],
#  ['cocochan000700', '0', '3'],
#  ['chchuru', '1', '3'],
#  ['catsfreaknokyo', '4', '3'],
#  ['c4ouuu45o5uq0zm', '17', '3'],
#  ['boeing78717', '1', '3'],
#  ['arimoto_kaori', '17', '3'],
#  ['anno_un', '17', '3'],
#  ['akahata_pr', '25', '3'],
#  ['32ohoqkrtpnupae', '4', '3'],
#  ['yoosi7777', '4', '2'],
#  ['yaponluq', '6', '2'],
#  ['y1j4ijwe2bxjzon', '17', '2'],
#  ['xmysyal6ngwevpa', '4', '2'],
#  ['w01453537', '21', '2'],
#  ['votune', '25', '2'],
#  ['va4inucsotdiqao', '17', '2'],
#  ['umebau', '17', '2'],
#  ['ugg26072', '25', '2'],
#  ['ugesama', '21', '2'],
#  ['tobatozankoudes', '25', '2'],
#  ['ten1998', '17', '2'],
#  ['tbnskugk2z3hcxe', '25', '2'],
#  ['taramo', '17', '2'],
#  ['t_iwagon', '17', '2'],
#  ['t2prw6harjwqr5s', '11', '2'],
#  ['syobo_n20xx', '4', '2'],
#  ['superwriterx', '4', '2'],
#  ['smartpapax', '17', '2'],
#  ['sin2nissi', '4', '2'],
#  ['shion23589524', '17', '2'],
#  ['shihrun', '6', '2'],
#  ['seresu1seresu', '17', '2'],
#  ['sawara201408', '17', '2'],
#  ['sat98635697', '17', '2'],
#  ['sao_nifu', '17', '2'],
#  ['runrunpon', '17', '2'],
#  ['roccavbnm', '21', '2'],
#  ['rimirinarisa', '25', '2'],
#  ['qjsvxt3g8atyprs', '17', '2'],
#  ['pastel_caree', '4', '2'],
#  ['otohu_oishii', '4', '2'],
#  ['nsumashi', '6', '2'],
#  ['nobuyoyagi', '1', '2'],
#  ['nnkitarohcoca', '25', '2'],
#  ['nekoshiroiro', '17', '2'],
#  ['nanasi1172', '6', '2'],
#  ['nakashima11', '17', '2'],
#  ['mtjnuami', '4', '2'],
#  ['momo_ni', '6', '2'],
#  ['mlkcoopers', '17', '2'],
#  ['mediabreaker21', '17', '2'],
#  ['matsuhis1', '17', '2'],
#  ['marimo34815947', '4', '2'],
#  ['m3llsquc35qdao0', '21', '2'],
#  ['lovehatecelery', '4', '2'],
#  ['lawer_ni_', '4', '2'],
#  ['kumax035', '17', '2'],
#  ['kokiakise', '11', '2'],
#  ['kimpiyo2', '11', '2'],
#  ['kidkaido', '21', '2'],
#  ['kenkichisandesu', '4', '2'],
#  ['kazenochisoku', '11', '2'],
#  ['katsu_m', '6', '2'],
#  ['k_soai', '4', '2'],
#  ['k2gtr', '25', '2'],
#  ['june990724', '17', '2'],
#  ['jeremy_l_mercy3', '17', '2'],
#  ['ja1hss', '4', '2'],
#  ['iqjb4p7gtchno5v', '4', '2'],
#  ['io_nanari', '25', '2'],
#  ['ieyezkobrcqsujz', '11', '2'],
#  ['huffpostjapan', '6', '2'],
#  ['hopesai6', '17', '2'],
#  ['hirox246', '4', '2'],
#  ['hakutaku2019', '17', '2'],
#  ['hachimachu', '17', '2'],
#  ['h_112358', '4', '2'],
#  ['gr_tst', '14', '2'],
#  ['gorori_go', '4', '2'],
#  ['gh2rfr7bqrmwnpg', '17', '2'],
#  ['ggxkmoi7vbswt6k', '17', '2'],
#  ['f_yamato', '25', '2'],
#  ['epj8ifbqej8ei6h', '17', '2'],
#  ['dreamer_k007', '4', '2'],
#  ['daikonmoti_moti', '17', '2'],
#  ['csyuvmhpcpyule1', '17', '2'],
#  ['crisis_japan', '17', '2'],
#  ['compnvhmaster', '17', '2'],
#  ['cocomaccow', '17', '2'],
#  ['chiyogami55', '17', '2'],
#  ['carp0422', '25', '2'],
#  ['cafe_meguriya', '16', '2'],
#  ['caddiensw', '17', '2'],
#  ['c80utp721xiicne', '25', '2'],
#  ['buuccibuco', '17', '2'],
#  ['bstbs1930', '17', '2'],
#  ['arienaikamo_s', '11', '2'],
#  ['appsddlg', '0', '2'],
#  ['akira_mori0120', '11', '2'],
#  ['akihiko_kadowak', '17', '2'],
#  ['airi_deshi_555', '17', '2'],
#  ['agenasu_odashi', '4', '2'],
#  ['_sebasho', '21', '2'],
#  ['92_taga', '11', '2'],
#  ['8edojx0gvorbqxk', '16', '2'],
#  ['5rkpft7w47tcdr9', '11', '2'],
#  ['1970khkh', '11', '2'],
#  ['121384tonikaku', '17', '2'],
#  ['zusx0g', '17', '1'],
#  ['zikokoteikan_', '17', '1'],
#  ['zicocouteican', '17', '1'],
#  ['yusuke3346', '17', '1'],
#  ['yurun_oyag', '17', '1'],
#  ['yumi_suginami', '17', '1'],
#  ['yukiysiva', '4', '1'],
#  ['yukiyoshi_gotoh', '17', '1'],
#  ['yukaspy007', '6', '1'],
#  ['ysv36gxuk', '4', '1'],
#  ['yoyamy3722301', '14', '1'],
#  ['yoshikyoshi', '4', '1'],
#  ['yoshi78511819', '25', '1'],
#  ['yopparaijpn666', '21', '1'],
#  ['yononakaheno', '4', '1'],
#  ['yonamineshogo', '17', '1'],
#  ['yomogimochi1', '11', '1'],
#  ['yomeguchixxx', '17', '1'],
#  ['yjsg8', '17', '1'],
#  ['yitabashi', '17', '1'],
#  ['yamazakimusashi', '21', '1'],
#  ['yamaimo1414', '21', '1'],
#  ['yamabe', '4', '1'],
#  ['yahata9692', '14', '1'],
#  ['xyzkh', '4', '1'],
#  ['wasabi15749807', '17', '1'],
#  ['vanillasiosio', '17', '1'],
#  ['unisuke178', '17', '1'],
#  ['um__homem', '16', '1'],
#  ['u1knbytu5uvmwl0', '17', '1'],
#  ['twr_kou', '4', '1'],
#  ['tsuruga60k', '17', '1'],
#  ['tsubaki_tsubomi', '16', '1'],
#  ['tosiho', '4', '1'],
#  ['tora8enl', '17', '1'],
#  ['tomo66388825', '17', '1'],
#  ['tomo50178072', '21', '1'],
#  ['tojibuta_san', '17', '1'],
#  ['to_i_toi_toi', '25', '1'],
#  ['tlexycfd6obza1g', '17', '1'],
#  ['timtomtamtemtum', '17', '1'],
#  ['thor_ntyr', '0', '1'],
#  ['tendou1977t', '17', '1'],
#  ['tayutaubear', '17', '1'],
#  ['taku8717893011', '4', '1'],
#  ['takeuchikumiffy', '11', '1'],
#  ['takahiro392002', '17', '1'],
#  ['taka_eha', '21', '1'],
#  ['ta_howait', '17', '1'],
#  ['ta1210', '4', '1'],
#  ['swu82963813', '4', '1'],
#  ['suzu056', '17', '1'],
#  ['sunetarouu', '4', '1'],
#  ['suka_t', '0', '1'],
#  ['studiobishop', '17', '1'],
#  ['strt30', '4', '1'],
#  ['sthuuall', '21', '1'],
#  ['spearsden', '17', '1'],
#  ['sowwwww1001', '17', '1'],
#  ['solo_0505', '11', '1'],
#  ['skynex4', '21', '1'],
#  ['skboyj2', '4', '1'],
#  ['simonumabe', '17', '1'],
#  ['simachekera', '17', '1'],
#  ['sigurekimi2023', '11', '1'],
#  ['shinpuu7', '21', '1'],
#  ['shikana22625318', '4', '1'],
#  ['shibagoroko', '17', '1'],
#  ['seifutonare', '17', '1'],
#  ['sciolismwriter', '17', '1'],
#  ['sasuke1614', '6', '1'],
#  ['salediroccia', '17', '1'],
#  ['sachikoohira', '14', '1'],
#  ['s8t8r9n0', '17', '1'],
#  ['rztfufkkm2fpu1l', '17', '1'],
#  ['ryuta06444330', '17', '1'],
#  ['ryuhin_aktry', '4', '1'],
#  ['runayama1', '17', '1'],
#  ['reon_trunks_ami', '17', '1'],
#  ['renkon33211147', '4', '1'],
#  ['rendez_voust', '25', '1'],
#  ['ra_mem_seiji', '4', '1'],
#  ['qt6gom6ywzi2lfj', '4', '1'],
#  ['q_951', '25', '1'],
#  ['pxokvnsdbeoxe9r', '4', '1'],
#  ['puuuma318', '1', '1'],
#  ['ponchoronyanko', '4', '1'],
#  ['politasjp', '16', '1'],
#  ['pepekun1388', '16', '1'],
#  ['pbiegjbol8tpzdz', '11', '1'],
#  ['parsleymerrymen', '4', '1'],
#  ['p5azxiwvlc6qutf', '4', '1'],
#  ['owloaompad2baxi', '17', '1'],
#  ['ouinon77097774', '25', '1'],
#  ['oryzias999', '6', '1'],
#  ['online_checker', '4', '1'],
#  ['omaegayouna', '17', '1'],
#  ['oi2dbzduog72kvp', '17', '1'],
#  ['nyantasista2019', '17', '1'],
#  ['nsja6vbffwiajj9', '11', '1'],
#  ['nqsbc', '17', '1'],
#  ['nozomi_ski', '4', '1'],
#  ['nosuke0607', '0', '1'],
#  ['norisuke78', '14', '1'],
#  ['nomoreofthatja1', '17', '1'],
#  ['nmnm_nmsn', '14', '1'],
#  ['niyari_honpo', '16', '1'],
#  ['nishiy2006', '25', '1'],
#  ['nied_inok', '14', '1'],
#  ['nemuribi', '16', '1'],
#  ['neco_1968', '11', '1'],
#  ['nasunasunaasu', '17', '1'],
#  ['nako2013', '4', '1'],
#  ['nakano0316', '6', '1'],
#  ['myosaisen', '4', '1'],
#  ['myers206', '25', '1'],
#  ['mvop4pcgdqmj2gf', '17', '1'],
#  ['murakenta', '6', '1'],
#  ['momog986_4', '17', '1'],
#  ['moko92397655', '25', '1'],
#  ['mofukamoshika', '16', '1'],
#  ['minotonefinland', '4', '1'],
#  ['miitan35367455', '17', '1'],
#  ['miduwo', '1', '1'],
#  ['michioha', '17', '1'],
#  ['mayumaro19', '17', '1'],
#  ['maxirem', '17', '1'],
#  ['masato76077469', '17', '1'],
#  ['masa_honto', '17', '1'],
#  ['marriott1968', '14', '1'],
#  ['mariri025', '17', '1'],
#  ['mari64takahashi', '4', '1'],
#  ['makrabin7', '17', '1'],
#  ['madamedebamboo', '4', '1'],
#  ['lovemymyoji', '4', '1'],
#  ['lily_lemon90', '17', '1'],
#  ['leechul7', '4', '1'],
#  ['kyokohou', '21', '1'],
#  ['kurineko235', '25', '1'],
#  ['kurikommm8j', '16', '1'],
#  ['kuma36026725', '14', '1'],
#  ['ksm_mam', '17', '1'],
#  ['kouzai2007', '14', '1'],
#  ['kotsubo48', '21', '1'],
#  ['kotani2013', '14', '1'],
#  ['kotamama318', '21', '1'],
#  ['kokoron8282', '6', '1'],
#  ['kojiyamada1966', '4', '1'],
#  ['kkrd20iv6kruem7', '17', '1'],
#  ['kintai2768', '11', '1'],
#  ['kinoko_survivor', '4', '1'],
#  ['kimonomike2', '17', '1'],
#  ['kikko_no_blog', '25', '1'],
#  ['keizokuramoto', '4', '1'],
#  ['kbusz10z7km57he', '4', '1'],
#  ['kaworutokotaro', '17', '1'],
#  ['kawataka_alter', '4', '1'],
#  ['kashiwa_actor', '4', '1'],
#  ['karakan_seizi', '17', '1'],
#  ['kaiwale703', '4', '1'],
#  ['kaburaya2013', '17', '1'],
#  ['junsk99', '21', '1'],
#  ['jpbakahakkenki', '17', '1'],
#  ['joshispa', '4', '1'],
#  ['joe007sn', '1', '1'],
#  ['jkx2etq1yl9i8x3', '17', '1'],
#  ['jico_goda', '21', '1'],
#  ['ji', '17', '1'],
#  ['jane_m3', '21', '1'],
#  ['jackey81421082', '17', '1'],
#  ['jack88912057', '17', '1'],
#  ['j_sakkin', '25', '1'],
#  ['iwaataaa', '17', '1'],
#  ['ital_inouye', '4', '1'],
#  ['is7h5y6ok4ca3j8', '17', '1'],
#  ['infocenter2021', '4', '1'],
#  ['imari1217', '14', '1'],
#  ['ikaryakuchan', '17', '1'],
#  ['ikarioyajl', '21', '1'],
#  ['ifmari', '4', '1'],
#  ['ibrxdbxmiwsabns', '16', '1'],
#  ['i_like_lambmeat', '21', '1'],
#  ['hzqxvcekkn5qmow', '17', '1'],
#  ['hosyu_jk3', '17', '1'],
#  ['hoshimogmog', '4', '1'],
#  ['hikasu', '6', '1'],
#  ['hichachu', '6', '1'],
#  ['hayate689', '11', '1'],
#  ['hara_shimpei', '4', '1'],
#  ['hakofugu_net', '21', '1'],
#  ['hagiwara_ryo', '16', '1'],
#  ['h8radrlokg2w2kr', '4', '1'],
#  ['gsdhu0dl3sp9z1z', '17', '1'],
#  ['goruzo13nippon', '21', '1'],
#  ['googlecloud_jp', '4', '1'],
#  ['gomasaba_duke', '21', '1'],
#  ['glc_japan', '17', '1'],
#  ['gin_camp', '17', '1'],
#  ['gianfranco_zora', '4', '1'],
#  ['ghettoorgan', '16', '1'],
#  ['genki2010', '25', '1'],
#  ['gay_yagi', '16', '1'],
#  ['garix9', '17', '1'],
#  ['gantaro1945', '4', '1'],
#  ['ganonk114', '17', '1'],
#  ['games_plarium', '4', '1'],
#  ['gamechangefreak', '11', '1'],
#  ['gaitifuji', '25', '1'],
#  ['funkymegane', '4', '1'],
#  ['fukubonzzz', '17', '1'],
#  ['fukjyai', '17', '1'],
#  ['forthman', '16', '1'],
#  ['fooh32', '4', '1'],
#  ['flying__father', '4', '1'],
#  ['felicishatch', '4', '1'],
#  ['f_youdo', '17', '1'],
#  ['f1skywlkr_jdi', '17', '1'],
#  ['esmdcre', '14', '1'],
#  ['eri_arfiya', '21', '1'],
#  ['englishtempwor1', '14', '1'],
#  ['engeki_shimizu', '25', '1'],
#  ['ebisu_mom', '17', '1'],
#  ['e5ibob5ny736qul', '21', '1'],
#  ['dositavikke1126', '17', '1'],
#  ['daboso', '17', '1'],
#  ['cyxuaxfglffzzct', '11', '1'],
#  ['cy4ykf1l', '6', '1'],
#  ['crybabyto', '25', '1'],
#  ['cristoforou', '1', '1'],
#  ['cozytahara', '21', '1'],
#  ['color_snow1101', '11', '1'],
#  ['christweekly', '1', '1'],
#  ['chosi812', '17', '1'],
#  ['chocohamu__', '17', '1'],
#  ['chisato_kamui', '11', '1'],
#  ['chinjo_hokkaido', '4', '1'],
#  ['chichimama73', '11', '1'],
#  ['chamiq', '17', '1'],
#  ['bubu_de_la_ma', '16', '1'],
#  ['bluerosemoon1', '21', '1'],
#  ['blochbenjamin', '16', '1'],
#  ['black_joke_chan', '14', '1'],
#  ['bessei2018', '4', '1'],
#  ['belzedaro', '17', '1'],
#  ['baribarivary3', '16', '1'],
#  ['ayame_tomokaji', '4', '1'],
#  ['atsukofuji', '4', '1'],
#  ['ashipro7830', '4', '1'],
#  ['asahicom', '4', '1'],
#  ['arielcookieliu', '16', '1'],
#  ['aria6663', '17', '1'],
#  ['apprtranslator', '17', '1'],
#  ['anjuro_anjuro', '17', '1'],
#  ['angelpie2010', '17', '1'],
#  ['amiba', '17', '1'],
#  ['ami_snowleopard', '21', '1'],
#  ['alpha369omega', '11', '1'],
#  ['alma0707', '1', '1'],
#  ['akishmz', '4', '1'],
#  ['akiofan9191', '25', '1'],
#  ['akihikokondosk', '4', '1'],
#  ['akaisuisei_sab', '6', '1'],
#  ['ajqadjqvsdiqinp', '21', '1'],
#  ['ahonotakao', '0', '1'],
#  ['aelwoyo403sc09l', '4', '1'],
#  ['a_ssann', '25', '1'],
#  ['a_mememe_a', '4', '1'],
#  ['9ohh0s8x6yv5zlr', '4', '1'],
#  ['8z3zps', '21', '1'],
#  ['770125t', '25', '1'],
#  ['5kldy4a9atlrz1g', '17', '1'],
#  ['5283kazumaru', '17', '1'],
#  ['42tlapping09', '25', '1'],
#  ['3nico3', '21', '1'],
#  ['1ovelynews', '6', '1'],
#  ['1125monaca', '14', '1'],
#  ['100yenri_to', '17', '1'],
#  ['0917chiaki917', '11', '1'],
#  ['zzzoomy_56', '25', '0'],
#  ['zyjkun7kzroakuo', '14', '0'],
#  ['zxcvbn7531', '14', '0'],
#  ['zx600e_1994', '11', '0'],
#  ['zx2j0pmnewwuyak', '11', '0'],
#  ['zwzk3egxmcotkhd', '14', '0'],
#  ['zwvyobei8gxqyfa', '25', '0'],
#  ['zwingli39', '6', '0'],
#  ['zuzfd24mu9m8gva', '14', '0'],
#  ['zurapayo', '17', '0'],
#  ['zuk8f4yo3astrp0', '11', '0'],
#  ['zuizuimi', '14', '0'],
#  ['zuhan_ekaki', '1', '0'],
#  ['zube76hfjidpn2z', '14', '0'],
#  ['zubat3jyou', '1', '0'],
#  ['ztdw0120', '21', '0'],
#  ['zs3vjphjthcclku', '16', '0'],
#  ['zrzsgqib3fcvwuo', '14', '0'],
#  ['zqsaidpssfibd7a', '14', '0'],
#  ['zpp_10', '1', '0'],
#  ['zozo_mushi', '1', '0'],
#  ['zovajpypsiiqfcm', '14', '0'],
#  ['zoushima3', '11', '0'],
#  ['zotiqkok02mhvyr', '25', '0'],
#  ['zooon1151016', '21', '0'],
#  ['zonnchang', '21', '0'],
#  ['zonexkaoru', '6', '0'],
#  ['zokbt2timwzcwr6', '25', '0'],
#  ['zoetropezooey', '1', '0'],
#  ['zodiacaldust', '16', '0'],
#  ['znskhr', '6', '0'],
#  ['znpajrnctaiupdv', '14', '0'],
#  ['zmnmezu81kmpcvw', '4', '0'],
#  ['zmaririnz', '1', '0'],
#  ['zlufbcdbgq0ssxg', '11', '0'],
#  ['zkwuwxscfnfos4x', '1', '0'],
#  ['zjxjzf3xkhlifjx', '11', '0'],
#  ['zizi97401232', '21', '0'],
#  ['zivacray', '21', '0'],
#  ['ziplock', '16', '0'],
#  ['zinofrancescatt', '6', '0'],
#  ['zin_bnar', '1', '0'],
#  ['zimt6j9gawsdnhv', '14', '0'],
#  ['zimmyisfakestar', '6', '0'],
#  ['ziguzagu0721', '6', '0'],
#  ['zig66experience', '21', '0'],
#  ['zhzyxpenfb9qtcr', '11', '0'],
#  ['zh3qtfy5lhksgdt', '11', '0'],
#  ['zgwxxm0oqsyg11s', '11', '0'],
#  ['zgmf_yx21r', '21', '0'],
#  ['zg6b0tlwrgsempn', '21', '0'],
#  ['zfwxiahva8bcp52', '17', '0'],
#  ['zfphcngojjubdhh', '14', '0'],
#  ['zeroyen0yen_mhw', '14', '0'],
#  ['zerosp2017061', '0', '0'],
#  ['zeroset7', '6', '0'],
#  ['zeroniwasi', '21', '0'],
#  ['zerofightercat', '17', '0'],
#  ['zerobuster_g', '16', '0'],
#  ['zephyr400zc', '21', '0'],
#  ['zenko0813', '1', '0'],
#  ['zen30567645', '21', '0'],
#  ['zeg8ew3vky2v6lm', '14', '0'],
#  ['zeclufc0liutyo0', '11', '0'],
#  ['zebrajunjun', '21', '0'],
#  ['zebra_masa', '6', '0'],
#  ['ze_llo', '1', '0'],
#  ['ze2kso2hvyhzowo', '21', '0'],
#  ['zdkbnt6xprueu3b', '11', '0'],
#  ['zclfzql4ije7wen', '16', '0'],
#  ['zbanchi', '4', '0'],
#  ['zavsxsphk5h1riz', '21', '0'],
#  ['zassou2828', '1', '0'],
#  ['zapp102', '1', '0'],
#  ['zany46325', '11', '0'],
#  ['zanopmjbzgfqw75', '6', '0'],
#  ['zamaaaaaneeeee', '1', '0'],
#  ['zakuzaku_sennin', '11', '0'],
#  ['zakuro_ishi', '1', '0'],
#  ['zaklafkintore', '1', '0'],
#  ['zaklab', '0', '0'],
#  ['zakihacky', '0', '0'],
#  ['zaiyanjp45', '11', '0'],
#  ['z8wvww8wzqo6ds1', '14', '0'],
#  ['z7dee5fafayz7', '14', '0'],
#  ['z73lvpb10boat7i', '11', '0'],
#  ['z5u7y2', '11', '0'],
#  ['z36ixgxm11qfjp2', '14', '0'],
#  ['z354hcx2d5z3hxm', '4', '0'],
#  ['z2fwanuqnomlgqx', '21', '0'],
#  ['z25099843950', '11', '0'],
#  ['z1j6awkkug04xus', '11', '0'],
#  ['z0uccb998fdc8ox', '21', '0'],
#  ['z0ru70yy6int0ol', '25', '0'],
#  ['yzw7hiysda2wjdp', '1', '0'],
#  ['yzvhljrzvoqy0ge', '11', '0'],
#  ['yz_pey', '1', '0'],
#  ['yyuyama', '11', '0'],
#  ['yyrr528088471', '11', '0'],
#  ['yyoshiy1208y', '11', '0'],
#  ['yyoajii275', '0', '0'],
#  ['yyage', '6', '0'],
#  ['yy22647823', '17', '0'],
#  ['yxtxkx10161017', '6', '0'],
#  ['yxjiiuqemjomviv', '14', '0'],
#  ['yxf2ge60m0tkvio', '21', '0'],
#  ['ywa5cgccnzy3kv1', '21', '0'],
#  ['yvespiagetblanc', '25', '0'],
#  ['yuzu29soda', '17', '0'],
#  ['yuzu03141', '21', '0'],
#  ['yuz_uki1', '25', '0'],
#  ['yuyuyuyuyuwatch', '6', '0'],
#  ['yuyuyunoyuyuco', '1', '0'],
#  ['yuyuyo96298305', '17', '0'],
#  ['yuyu_yuyuchan', '21', '0'],
#  ['yuyu68728041', '21', '0'],
#  ['yuwatwit', '11', '0'],
#  ['yuuuuulo1', '21', '0'],
#  ['yuuumitwitta', '1', '0'],
#  ['yuuu129_', '21', '0'],
#  ['yuuryo5', '16', '0'],
#  ['yuuna06102000', '1', '0'],
#  ['yuumomo12321', '11', '0'],
#  ['yuuko2335', '14', '0'],
#  ['yuukanno', '25', '0'],
#  ['yuuka_eve', '14', '0'],
#  ['yuuk_kkrbgduse', '14', '0'],
#  ['yuuhi2', '6', '0'],
#  ['yuu268140', '14', '0'],
#  ['yuto814', '1', '0'],
#  ['yute_tet', '21', '0'],
#  ['yutapon3512', '0', '0'],
#  ['yutam86', '11', '0'],
#  ['yutakunayachan', '4', '0'],
#  ['yutakakitamaru', '14', '0'],
#  ['yut_2022su', '21', '0'],
#  ['yurumelt', '21', '0'],
#  ['yurukyaraojisan', '14', '0'],
#  ['yurucoponco', '0', '0'],
#  ['yuru2biost', '4', '0'],
#  ['yuriwaka0809', '6', '0'],
#  ['yurio904', '1', '0'],
#  ['yurinsaka', '21', '0'],
#  ['yurikonmoz', '16', '0'],
#  ['yurikarin_read', '21', '0'],
#  ['yuriakatase2', '0', '0'],
#  ['yuri4sakura', '16', '0'],
#  ['yuri37905240', '25', '0'],
#  ['yupipi_papiko', '14', '0'],
#  ['yupioniyupi', '21', '0'],
#  ['yupidzi', '11', '0'],
#  ['yuomatak', '4', '0'],
#  ['yuofromipanema', '25', '0'],
#  ['yunogozu', '4', '0'],
#  ['yunishio', '6', '0'],
#  ['yumo37383579', '11', '0'],
#  ['yumipon45', '21', '0'],
#  ['yuming1024', '1', '0'],
#  ['yumikoy', '1', '0'],
#  ['yumikinnn', '1', '0'],
#  ['yumidorian', '21', '0'],
#  ['yumico89z', '17', '0'],
#  ['yumi_yumi_koko', '1', '0'],
#  ['yumi_shinamon', '21', '0'],
#  ['yumi_mts', '1', '0'],
#  ['yumeyume20164', '11', '0'],
#  ['yumekanau39net1', '14', '0'],
#  ['yumehome', '11', '0'],
#  ['yume8izumi', '6', '0'],
#  ['yume10ken', '14', '0'],
#  ['yumato954', '11', '0'],
#  ['yulii_smirnoff', '11', '0'],
#  ['yukuri195', '11', '0'],
#  ['yukukawa3476', '11', '0'],
#  ['yuku89457342', '4', '0'],
#  ['yukohori2', '11', '0'],
#  ['yukoakeve', '21', '0'],
#  ['yuknog', '0', '0'],
#  ['yukky787', '14', '0'],
#  ['yukky747747', '11', '0'],
#  ['yukkopost', '21', '0'],
#  ['yukitarowww', '0', '0'],
#  ['yukisuke18', '21', '0'],
#  ['yukiqlair', '16', '0'],
#  ['yukio987654321', '16', '0'],
#  ['yukinomitsuki', '1', '0'],
#  ['yukinoinoue1', '21', '0'],
#  ['yukino0201', '25', '0'],
#  ['yukineko_28n28n', '1', '0'],
#  ['yukina39', '0', '0'],
#  ['yukimaru2200', '16', '0'],
#  ['yukimar92366746', '14', '0'],
#  ['yukikopool', '21', '0'],
#  ['yukiko45828', '4', '0'],
#  ['yukik10281', '21', '0'],
#  ['yuki_yukiki___', '25', '0'],
#  ['yuki_in_pj', '6', '0'],
#  ['yuki_abe6', '17', '0'],
#  ['yuki777666', '6', '0'],
#  ['yuki14', '1', '0'],
#  ['yuketta77', '14', '0'],
#  ['yukemurimochi', '1', '0'],
#  ['yukarigasane', '4', '0'],
#  ['yukarienne', '1', '0'],
#  ['yukaace_1132', '1', '0'],
#  ['yuka__ko', '0', '0'],
#  ['yuka371658', '6', '0'],
#  ['yuka112814', '16', '0'],
#  ['yuk0117', '1', '0'],
#  ['yujitashi', '6', '0'],
#  ['yujinoaim', '6', '0'],
#  ['yuji_kzk', '6', '0'],
#  ['yuiboo1127', '25', '0'],
#  ['yui2051wing', '21', '0'],
#  ['yuhohtaka', '0', '0'],
#  ['yuha84002885', '6', '0'],
#  ['yugayug01511120', '17', '0'],
#  ['yufuintacos1', '14', '0'],
#  ['yufuin_g', '11', '0'],
#  ['yuchunrd', '6', '0'],
#  ['yuba0803', '1', '0'],
#  ['yuai_church', '0', '0'],
#  ['yu_no_cha', '1', '0'],
#  ['yu_mojarra', '6', '0'],
#  ['yu_metamorphose', '21', '0'],
#  ['yu_ku_yu_ku', '17', '0'],
#  ['yu_kotyan', '6', '0'],
#  ['yu__1962', '6', '0'],
#  ['yu99918230', '4', '0'],
#  ['yu2kama', '14', '0'],
#  ['yu2001_ari2003', '11', '0'],
#  ['yty889', '25', '0'],
#  ['ytsgpjrzvqsobci', '16', '0'],
#  ['ytj6tk9aiyuyo7v', '11', '0'],
#  ['ythdlrdz6fueoxg', '6', '0'],
#  ['yt0124space', '6', '0'],
#  ['ysyk4eva', '6', '0'],
#  ['yswakkedxy2xrwa', '1', '0'],
#  ['ysuzu15', '11', '0'],
#  ['ysmc_tanaka', '11', '0'],
#  ['yshibuyatokyo', '25', '0'],
#  ['yrht4fqbnhglgr9', '25', '0'],
#  ['yrbq2urkqr05cme', '1', '0'],
#  ['yqsft1k4cfxjehu', '11', '0'],
#  ['yqmr7adabv1amhu', '16', '0'],
#  ['yq7mxbqvyz3q1e4', '6', '0'],
#  ['ypzhqyrlyfaxcij', '14', '0'],
#  ['yptbbpcnxyoyggj', '0', '0'],
#  ['yplrnwsrssjwzva', '11', '0'],
#  ['ypdpfcqlapo2sgw', '6', '0'],
#  ['yoyoyo_baha', '21', '0'],
#  ['yoyoyo05555', '11', '0'],
#  ['yowkuro', '17', '0'],
#  ['yowaineko', '11', '0'],
#  ['youturn1980', '0', '0'],
#  ['youtube48628832', '11', '0'],
#  ['youshiyadaisuki', '6', '0'],
#  ['yousato_risei', '21', '0'],
#  ['yourchoicepeace', '6', '0'],
#  ['youma_jukai', '16', '0'],
#  ['youheimetal', '25', '0'],
#  ['yougonara', '16', '0'],
#  ['youcand44474105', '25', '0'],
#  ['you_tarou01', '17', '0'],
#  ['you_psy', '6', '0'],
#  ['you_0358', '11', '0'],
#  ['you26767', '11', '0'],
#  ['yot07814', '16', '0'],
#  ['yossy32gtr', '21', '0'],
#  ['yossiibook', '14', '0'],
#  ['yossie89180000', '25', '0'],
#  ['yosiroumiyuisi', '21', '0'],
#  ['yosidycltgkyrwz', '25', '0'],
#  ['yosi220', '14', '0'],
#  ['yosi0605', '6', '0'],
#  ['yoshnoiz', '6', '0'],
#  ['yoshito2906', '21', '0'],
#  ['yoshiokayuji', '14', '0'],
#  ['yoshioka36', '17', '0'],
#  ['yoshinene', '14', '0'],
#  ['yoshimisa1227', '4', '0'],
#  ['yoshikitakeishi', '17', '0'],
#  ['yoshiki_tourabu', '1', '0'],
#  ['yoshikazum4', '14', '0'],
#  ['yoshikatsu_www', '21', '0'],
#  ['yoshihiromori11', '6', '0'],
#  ['yoshihirohorii', '6', '0'],
#  ['yoshihiro_abe', '6', '0'],
#  ['yoshiharuusui', '6', '0'],
#  ['yoshiehitomi', '25', '0'],
#  ['yoshidaouri', '21', '0'],
#  ['yoshiane', '1', '0'],
#  ['yoshi_ham', '4', '0'],
#  ['yoshi857616758', '14', '0'],
#  ['yoshi67144140', '21', '0'],
#  ['yorunimau', '1', '0'],
#  ['yoru_stern', '1', '0'],
#  ['yorozuya37', '0', '0'],
#  ['yorokobinokabe', '0', '0'],
#  ['yoroimyheart8', '11', '0'],
#  ['yorkwing', '4', '0'],
#  ['yoriyoinekocyan', '21', '0'],
#  ['yoricchi46', '16', '0'],
#  ['yoppie0319', '25', '0'],
#  ['yomoyashi', '17', '0'],
#  ['yomibitoshirazu', '21', '0'],
#  ['yome0930', '17', '0'],
#  ['yokyun68k', '1', '0'],
#  ['yokotunashima', '11', '0'],
#  ['yokomori555', '14', '0'],
#  ['yokoalacarte', '6', '0'],
#  ['yokko51900', '14', '0'],
#  ['yojiro10haruki', '1', '0'],
#  ['yoizo3', '1', '0'],
#  ['yoitenki3', '14', '0'],
#  ['yoikuni_1192', '6', '0'],
#  ['yoici', '25', '0'],
#  ['yohno1963', '14', '0'],
#  ['yohkomaya', '1', '0'],
#  ['yohko_anego', '1', '0'],
#  ['yoh21071430', '6', '0'],
#  ['yogc8tm', '17', '0'],
#  ['yog_s29', '6', '0'],
#  ['yodosakisan', '21', '0'],
#  ['yodobasiend', '6', '0'],
#  ['yocchi009', '11', '0'],
#  ['yoakemaedayo', '16', '0'],
#  ['yo4fwx48wz3sleo', '14', '0'],
#  ['yo4410ra', '1', '0'],
#  ['ynlib07', '14', '0'],
#  ['ynanica', '1', '0'],
#  ['yn0027', '21', '0'],
#  ['ymtb50', '0', '0'],
#  ['ymonku1y', '17', '0'],
#  ['ymmt1970hrs', '4', '0'],
#  ['ymdr4989', '1', '0'],
#  ['ymdarling5', '11', '0'],
#  ['ylx6bwa5t8fhf6b', '11', '0'],
#  ['ykwtsk_z', '16', '0'],
#  ['ykuodubvcs2drar', '1', '0'],
#  ['yksj', '6', '0'],
#  ['ykn524396175', '14', '0'],
#  ['ykn19fky5d0nlvl', '21', '0'],
#  ['ykkic', '1', '0'],
#  ['ykid1olcexq2r0y', '11', '0'],
#  ['yj7wotl7awytpql', '1', '0'],
#  ['yj3lrexo2kdt8r1', '11', '0'],
#  ['yishiaki1', '14', '0'],
#  ['yikura7', '4', '0'],
#  ['yikaynfmk03b', '4', '0'],
#  ['yhashigen', '16', '0'],
#  ['yh04137539', '14', '0'],
#  ['ygsxobfop2qz0vs', '11', '0'],
#  ['ygrgeyzz8vjq377', '14', '0'],
#  ['ygloc4relo1xls4', '11', '0'],
#  ['ygenxchxqfbp0pi', '6', '0'],
#  ['yfyspwysen7opvr', '21', '0'],
#  ['yfa35860', '16', '0'],
#  ['yf47595480', '21', '0'],
#  ['yeybi3l7qhwnwe0', '11', '0'],
#  ['yellowgreeeen58', '21', '0'],
#  ['yellow_x_metal', '11', '0'],
#  ['yekou02', '1', '0'],
#  ['ycwg5hxiezcbgtx', '6', '0'],
#  ['ycorey55', '4', '0'],
#  ['ycie0qgdnjzgvqe', '25', '0'],
#  ['yba7grimanceuhu', '14', '0'],
#  ['yb7vz', '21', '0'],
#  ['yayuzerowqu0504', '16', '0'],
#  ['yayu_uu', '16', '0'],
#  ['yayoikoume0622', '21', '0'],
#  ['yayakoshiya310', '6', '0'],
#  ['yatumimi', '4', '0'],
#  ['yatsugatake1229', '21', '0'],
#  ['yasuyukima', '4', '0'],
#  ['yasuwo_chan', '1', '0'],
#  ['yasukunig', '11', '0'],
#  ['yasukunieirei', '21', '0'],
#  ['yasuko2773', '6', '0'],
#  ['yasuke43', '14', '0'],
#  ...]

# %%
edges_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/6l/9sc4ys752w1_7xp_8yvrq3600000gn/T/ipykernel_72958/123237571.py in <module>
# ----> 1 edges_data
#
# NameError: name 'edges_data' is not defined

# %%
class eiObject:
    '''an object class with attributes for various EI-index-related data and metadata'''
    def __init__(self,n_nodes=None,ei_indices=None,internal_ties=None,external_ties=None,mean_ei=None,total_ties=None,received_ties=None,sent_ties=None,r_s=None,adj_in=None,adj_out=None):
        self.n_nodes = n_nodes
        self.ei_indices = ei_indices
        self.internal_ties = internal_ties
        self.external_ties = external_ties
        self.mean_ei = mean_ei
        self.total_ties = total_ties
        self.received_ties = received_ties
        self.sent_ties = sent_ties
        self.r_s = r_s
        self.adj_out = adj_out
        self.adj_in = adj_in

# %%
def _get_shared_ties(top_community_ids,top_edges,ei_int,ei_ext,n_nodes,verbose):
    adj_out = {} #sent ties point away from the focal community
    adj_in = {} #received ties point toward the focal community

    for i in top_community_ids:
        adj_out[i] = {}
        adj_in[i] = {}
        for j in top_edges:
            if j[2] == i and j[3] != i:
                if j[3] in adj_out[i]:
                    adj_out[i][j[3]] += 1
                else:
                    adj_out[i][j[3]] = 1
            if j[2] != i and j[3] == i:
                if j[2] in adj_in[i]:
                    adj_in[i][j[2]] += 1
                else:
                    adj_in[i][j[2]] = 1

    total_dict = {}
    received_dict = {}
    sent_dict = {}
    r_s_dict = {}

    for i in top_community_ids:
        total = ei_int[i]+ei_ext[i]
        total_dict[i] = total
        incoming = sum(adj_in[i].values())
        received_dict[i] = incoming
        outgoing = sum(adj_out[i].values())
        sent_dict[i] = outgoing
        r_s = round(incoming - outgoing,3)
        r_s_dict[i] = r_s

        if verbose == True:
            print("\nCommunity\tSize\tInternal\tReceived\tSent\tReceived - Sent")
            print(str(i)+"\t"+str(n_nodes[i])+"\t"+str(round(ei_int[i]/total,3))+"\t"+str(round(incoming/total,3))+"\t"+str(round(outgoing/total,3))+"\t"+str(round(r_s/total,3))+"\n")
            for j in top_community_ids:
                if i != j:
                    if j in adj_out[i]:
                        print(str(j)+"-s\t"+str(round(adj_out[i][j]/total,3)))
                    if j in adj_in[i]:
                        print(str(j)+"-r\t"+str(round(adj_in[i][j]/total,3)))

    prox_out = eiObject()
    prox_out.adj_in = collections.OrderedDict(sorted(adj_in.items()))
    prox_out.adj_out = collections.OrderedDict(sorted(adj_out.items()))
    prox_out.total_ties = collections.OrderedDict(sorted(total_dict.items()))
    prox_out.received_ties = collections.OrderedDict(sorted(received_dict.items()))
    prox_out.sent_ties = collections.OrderedDict(sorted(sent_dict.items()))
    prox_out.r_s = collections.OrderedDict(sorted(r_s_dict.items()))

    return prox_out

# %%
def calc_ei(nodes_data,edges_data,all_output=True,pause=False,weight_edges=True,verbose=True,save_prefix=''):
    if weight_edges == False:
        print("Calculating EI indices using *UNweighted* edges.\n")
    else:
        print("Calculating EI indices using *weighted* edges.\n")

    nodes = load_data(nodes_data)
    if nodes[0][0] == 'name':
        del nodes[0] #remove headers from CSV

    edges = load_data(edges_data)
    modclass = [i[1] for i in nodes]
    moduniq = {}

    for i in modclass: #get and count unique community IDs
        if i in moduniq:
            moduniq[i] += 1
        else:
            moduniq[i] = 1

    mu_top = sorted(moduniq,key=moduniq.get,reverse=True) #get all communities from node file
    top_nodes_list = [i for i in nodes if i[1] in mu_top]
    top_nodes = {node[0]:node[1] for node in top_nodes_list} #create dict of screen names and community IDs

    if weight_edges == False:
        edges = list(set([i[0] + "," + i[1] for i in edges])) #unweight the edgelist--multiple links to B from A count as one edge
        edges = [i.split(",") for i in edges]

    for edge in edges:
        if edge[0] in top_nodes:
            edge.append(top_nodes[edge[0]])

    for edge in edges:
        if edge[1] in top_nodes:
            edge.append(top_nodes[edge[1]])

    top_edges = [i for i in edges if len(i) == 4]

    ei_int = {}
    ei_ext = {}

    for i in mu_top:
        ei_int[i] = 0
        ei_ext[i] = 0
        for j in top_edges:
            if j[2] == i and j[3] == i:
                ei_int[i] += 1
            elif j[2] == i or j[3] == i:
                ei_ext[i] += 1

    ei_indices = {}

    for i in ei_int:
        ei_indices[i] = round((ei_ext[i]-ei_int[i])/(ei_ext[i]+ei_int[i]),3)

    ei_ord = collections.OrderedDict(sorted(ei_indices.items()))
    ei_int = collections.OrderedDict(sorted(ei_int.items()))
    ei_ext = collections.OrderedDict(sorted(ei_ext.items()))
    mean_ei = round(sum(ei_indices.values())/len(ei_indices.values()),3)

    if verbose == True:
        print("***EI indices***\n")
        print("Community\tEI index")
        for i in ei_ord:
            print(str(i)+"\t"+str(ei_ord[i]))

        print("Mean EI:\t",mean_ei)

    n_nodes = {}
    for i in nodes:
        if i[1] in n_nodes:
            n_nodes[i[1]] += 1
        else:
            n_nodes[i[1]] = 1

    if pause == True:
        input('Press any key to continue...')

    if all_output == True:
        ei_out = _get_shared_ties(mu_top,top_edges,ei_int,ei_ext,n_nodes,verbose)
    else:
        ei_out = eiObject()

    if len(save_prefix) > 0:
        ei_list = []
        for i in ei_ord:
            ei_list.append([str(i),str(ei_ord[i])])
        ei_list.insert(0,['Community IDs','EI indices'])
        save_csv(save_prefix + '_ei_indices.csv',ei_list)
    print("\n")

    ei_out.n_nodes = collections.OrderedDict(sorted(n_nodes.items()))
    ei_out.ei_indices = ei_ord
    ei_out.internal_ties = ei_int
    ei_out.external_ties = ei_ext
    ei_out.mean_ei = mean_ei
    return ei_out

# %%
calc_ei(nodes_data, final)
# Out:
# Calculating EI indices using *weighted* edges.
#
# Data loaded.
# Data loaded.
# ***EI indices***
#
# Community	EI index
# 0	-0.476
# 1	-0.675
# 11	-0.636
# 14	-0.653
# 16	-0.299
# 17	-0.521
# 21	-0.602
# 25	-0.562
# 4	-0.449
# 6	-0.518
# Mean EI:	 -0.539
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 1	1303	0.837	0.16	0.003	0.157
#
# 6-s	0.001
# 6-r	0.036
# 14-r	0.01
# 17-r	0.022
# 4-s	0.001
# 4-r	0.052
# 25-r	0.009
# 0-s	0.001
# 0-r	0.013
# 16-r	0.018
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 6	1280	0.759	0.164	0.077	0.087
#
# 1-s	0.031
# 1-r	0.001
# 21-r	0.001
# 14-s	0.01
# 14-r	0.042
# 17-r	0.001
# 4-s	0.008
# 4-r	0.033
# 25-s	0.003
# 25-r	0.025
# 0-s	0.014
# 0-r	0.024
# 16-s	0.012
# 16-r	0.037
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 11	1264	0.818	0.14	0.042	0.099
#
# 21-s	0.037
# 21-r	0.093
# 14-s	0.001
# 17-s	0.004
# 17-r	0.045
# 4-r	0.002
# 25-s	0.001
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 21	1211	0.801	0.089	0.11	-0.022
#
# 6-s	0.001
# 11-s	0.085
# 11-r	0.034
# 17-s	0.022
# 17-r	0.054
# 4-s	0.001
# 4-r	0.001
# 25-r	0.001
# 16-s	0.001
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 14	1080	0.826	0.107	0.067	0.04
#
# 1-s	0.011
# 6-s	0.054
# 6-r	0.013
# 11-r	0.001
# 17-r	0.001
# 4-s	0.001
# 4-r	0.017
# 25-r	0.037
# 0-r	0.016
# 16-s	0.001
# 16-r	0.022
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 17	723	0.761	0.063	0.176	-0.113
#
# 1-s	0.015
# 6-s	0.001
# 11-s	0.033
# 11-r	0.003
# 21-s	0.042
# 21-r	0.017
# 14-s	0.0
# 4-s	0.082
# 4-r	0.043
# 25-s	0.001
# 25-r	0.0
# 0-s	0.001
# 16-s	0.001
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 4	697	0.724	0.109	0.166	-0.057
#
# 1-s	0.04
# 1-r	0.0
# 6-s	0.029
# 6-r	0.007
# 11-s	0.002
# 21-s	0.0
# 21-r	0.001
# 14-s	0.012
# 14-r	0.0
# 17-s	0.048
# 17-r	0.091
# 25-s	0.005
# 25-r	0.005
# 0-s	0.017
# 16-s	0.014
# 16-r	0.004
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 25	522	0.781	0.029	0.19	-0.161
#
# 1-s	0.018
# 6-s	0.058
# 6-r	0.008
# 11-r	0.001
# 21-s	0.001
# 14-s	0.067
# 17-s	0.001
# 17-r	0.004
# 4-s	0.014
# 4-r	0.013
# 0-s	0.019
# 16-s	0.013
# 16-r	0.004
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 0	519	0.738	0.139	0.123	0.016
#
# 1-s	0.029
# 1-r	0.001
# 6-s	0.06
# 6-r	0.034
# 14-s	0.031
# 17-r	0.003
# 4-r	0.046
# 25-r	0.02
# 16-s	0.003
# 16-r	0.034
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 16	406	0.649	0.102	0.249	-0.147
#
# 1-s	0.042
# 6-s	0.103
# 6-r	0.033
# 21-r	0.002
# 14-s	0.047
# 14-r	0.002
# 17-r	0.003
# 4-s	0.014
# 4-r	0.044
# 25-s	0.005
# 25-r	0.015
# 0-s	0.038
# 0-r	0.003

# %%
#  self.n_nodes = n_nodes
#         self.ei_indices = ei_indices
#         self.internal_ties = internal_ties
#         self.external_ties = external_ties
#         self.mean_ei = mean_ei
#         self.total_ties = total_ties
#         self.received_ties = received_ties
#         self.sent_ties = sent_ties
#         self.r_s = r_s
#         self.adj_out = adj_out
#         self.adj_in = adj_in

# %%
a = calc_ei(nodes_data, final)
# Out:
# Calculating EI indices using *weighted* edges.
#
# Data loaded.
# Data loaded.
# ***EI indices***
#
# Community	EI index
# 0	-0.476
# 1	-0.675
# 11	-0.636
# 14	-0.653
# 16	-0.299
# 17	-0.521
# 21	-0.602
# 25	-0.562
# 4	-0.449
# 6	-0.518
# Mean EI:	 -0.539
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 1	1303	0.837	0.16	0.003	0.157
#
# 6-s	0.001
# 6-r	0.036
# 14-r	0.01
# 17-r	0.022
# 4-s	0.001
# 4-r	0.052
# 25-r	0.009
# 0-s	0.001
# 0-r	0.013
# 16-r	0.018
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 6	1280	0.759	0.164	0.077	0.087
#
# 1-s	0.031
# 1-r	0.001
# 21-r	0.001
# 14-s	0.01
# 14-r	0.042
# 17-r	0.001
# 4-s	0.008
# 4-r	0.033
# 25-s	0.003
# 25-r	0.025
# 0-s	0.014
# 0-r	0.024
# 16-s	0.012
# 16-r	0.037
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 11	1264	0.818	0.14	0.042	0.099
#
# 21-s	0.037
# 21-r	0.093
# 14-s	0.001
# 17-s	0.004
# 17-r	0.045
# 4-r	0.002
# 25-s	0.001
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 21	1211	0.801	0.089	0.11	-0.022
#
# 6-s	0.001
# 11-s	0.085
# 11-r	0.034
# 17-s	0.022
# 17-r	0.054
# 4-s	0.001
# 4-r	0.001
# 25-r	0.001
# 16-s	0.001
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 14	1080	0.826	0.107	0.067	0.04
#
# 1-s	0.011
# 6-s	0.054
# 6-r	0.013
# 11-r	0.001
# 17-r	0.001
# 4-s	0.001
# 4-r	0.017
# 25-r	0.037
# 0-r	0.016
# 16-s	0.001
# 16-r	0.022
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 17	723	0.761	0.063	0.176	-0.113
#
# 1-s	0.015
# 6-s	0.001
# 11-s	0.033
# 11-r	0.003
# 21-s	0.042
# 21-r	0.017
# 14-s	0.0
# 4-s	0.082
# 4-r	0.043
# 25-s	0.001
# 25-r	0.0
# 0-s	0.001
# 16-s	0.001
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 4	697	0.724	0.109	0.166	-0.057
#
# 1-s	0.04
# 1-r	0.0
# 6-s	0.029
# 6-r	0.007
# 11-s	0.002
# 21-s	0.0
# 21-r	0.001
# 14-s	0.012
# 14-r	0.0
# 17-s	0.048
# 17-r	0.091
# 25-s	0.005
# 25-r	0.005
# 0-s	0.017
# 16-s	0.014
# 16-r	0.004
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 25	522	0.781	0.029	0.19	-0.161
#
# 1-s	0.018
# 6-s	0.058
# 6-r	0.008
# 11-r	0.001
# 21-s	0.001
# 14-s	0.067
# 17-s	0.001
# 17-r	0.004
# 4-s	0.014
# 4-r	0.013
# 0-s	0.019
# 16-s	0.013
# 16-r	0.004
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 0	519	0.738	0.139	0.123	0.016
#
# 1-s	0.029
# 1-r	0.001
# 6-s	0.06
# 6-r	0.034
# 14-s	0.031
# 17-r	0.003
# 4-r	0.046
# 25-r	0.02
# 16-s	0.003
# 16-r	0.034
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 16	406	0.649	0.102	0.249	-0.147
#
# 1-s	0.042
# 6-s	0.103
# 6-r	0.033
# 21-r	0.002
# 14-s	0.047
# 14-r	0.002
# 17-r	0.003
# 4-s	0.014
# 4-r	0.044
# 25-s	0.005
# 25-r	0.015
# 0-s	0.038
# 0-r	0.003

# %% [markdown]
# ## Dailydata

# %%
# subset data
tweets_data_20220801 = tweets_final[(tweets_final['created_at'] >= '2022-08-01') & (tweets_final['created_at'] < '2022-08-02')]
tweets_data_20220802 = tweets_final[(tweets_final['created_at'] >= '2022-08-02') & (tweets_final['created_at'] < '2022-08-03')]
tweets_data_20220803 = tweets_final[(tweets_final['created_at'] >= '2022-08-03') & (tweets_final['created_at'] < '2022-08-04')]
tweets_data_20220804 = tweets_final[(tweets_final['created_at'] >= '2022-08-04') & (tweets_final['created_at'] < '2022-08-05')]
tweets_data_20220805 = tweets_final[(tweets_final['created_at'] >= '2022-08-05') & (tweets_final['created_at'] < '2022-08-06')]
tweets_data_20220806 = tweets_final[(tweets_final['created_at'] >= '2022-08-06') & (tweets_final['created_at'] < '2022-08-07')]
tweets_data_20220807 = tweets_final[(tweets_final['created_at'] >= '2022-08-07') & (tweets_final['created_at'] < '2022-08-08')]

# %%
#csv
tweets_data_20220801.to_csv("data/processed/tweets_20220801_notverified_freelon.csv")
tweets_data_20220802.to_csv("data/processed/tweets_20220802_notverified_freelon.csv")
tweets_data_20220803.to_csv("data/processed/tweets_20220803_notverified_freelon.csv")
tweets_data_20220804.to_csv("data/processed/tweets_20220804_notverified_freelon.csv")
tweets_data_20220805.to_csv("data/processed/tweets_20220805_notverified_freelon.csv")
tweets_data_20220806.to_csv("data/processed/tweets_20220806_notverified_freelon.csv")
tweets_data_20220807.to_csv("data/processed/tweets_20220807_notverified_freelon.csv")

# %%
#20220801

f = open('data/processed/tweets_20220801_notverified_freelon.csv','r',encoding = 'utf-8',errors = 'replace')
csvreader_20220801 = csv.reader(f)
authors_20220801 = []
tweets_20220801 = []
for row in csvreader_20220801:
    authors_20220801.append(re.sub('[^A-Za-z0-9_]','',str(row[1]).lower().strip()))
    tweets_20220801.append(' ' + row[2].lower() + ' ')

final_20220801 = []
tweets_20220801 = [t.split('@') for t in tweets_20220801] #splits each tweet along @s
for n,chunk in enumerate(tweets_20220801):
    ment_users = [t[:re.search('[^A-Za-z0-9_]',t).start()].lower().strip() for t in chunk if re.search('[^A-Za-z0-9_]',t) is not None]
    final_20220801.extend([[authors_20220801[n],name] for name in ment_users if len(name.strip()) > 0])
outfile = '_edgelist_20220801.csv'
save_csv(outfile,final_20220801)
top_communities_20220801 = tsm.get_top_communities(final_20220801)
nodes_data_20220801 = top_communities_20220801.node_list
calc_ei(nodes_data_20220801, final_20220801)
# Out:
# Data saved to file "_edgelist_20220801.csv".
# Data loaded.
# Non-directed network created.
# Community partition complete.
# Total n of communities: 167
# Modularity: 0.88
# Community analysis complete. The top 10 communities in this network account for 66.77 % of all nodes.
# And 61.79 % of all edges.
# Calculating EI indices using *weighted* edges.
#
# Data loaded.
# Data loaded.
# ***EI indices***
#
# Community	EI index
# 0	-0.896
# 1	-0.678
# 14	-0.695
# 2	-0.728
# 20	-0.852
# 26	-0.634
# 44	-0.722
# 6	-0.83
# 7	-0.663
# 9	-0.835
# Mean EI:	 -0.753
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 6	458	0.915	0.085	0.0	0.085
#
# 20-r	0.004
# 7-r	0.032
# 44-r	0.016
# 14-r	0.014
# 1-r	0.02
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 0	349	0.948	0.052	0.0	0.052
#
# 2-r	0.01
# 9-r	0.021
# 26-r	0.021
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 20	224	0.926	0.047	0.027	0.02
#
# 6-s	0.005
# 2-s	0.005
# 2-r	0.012
# 7-s	0.002
# 44-s	0.005
# 44-r	0.015
# 14-s	0.005
# 14-r	0.002
# 26-s	0.005
# 26-r	0.017
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 2	146	0.864	0.083	0.053	0.03
#
# 0-s	0.024
# 20-s	0.03
# 20-r	0.012
# 9-r	0.006
# 14-r	0.006
# 26-r	0.059
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 7	139	0.831	0.072	0.096	-0.024
#
# 6-s	0.096
# 20-r	0.006
# 44-r	0.024
# 14-r	0.024
# 1-r	0.018
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 44	135	0.861	0.016	0.123	-0.107
#
# 6-s	0.043
# 20-s	0.032
# 20-r	0.011
# 7-s	0.021
# 14-s	0.011
# 1-s	0.016
# 1-r	0.005
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 9	123	0.917	0.015	0.068	-0.053
#
# 0-s	0.06
# 2-s	0.008
# 26-r	0.015
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 14	103	0.847	0.031	0.122	-0.092
#
# 6-s	0.053
# 20-s	0.008
# 20-r	0.015
# 2-s	0.008
# 7-s	0.031
# 44-r	0.015
# 1-s	0.015
# 26-s	0.008
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 1	94	0.839	0.042	0.119	-0.076
#
# 6-s	0.085
# 7-s	0.025
# 44-s	0.008
# 44-r	0.025
# 14-r	0.017
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 26	94	0.817	0.018	0.165	-0.146
#
# 0-s	0.049
# 20-s	0.043
# 20-r	0.012
# 2-s	0.061
# 9-s	0.012
# 14-r	0.006

# %%
#20220802

f = open('data/processed/tweets_20220802_notverified_freelon.csv','r',encoding = 'utf-8',errors = 'replace')
csvreader_20220802 = csv.reader(f)
authors_20220802 = []
tweets_20220802 = []
for row in csvreader_20220802:
    authors_20220802.append(re.sub('[^A-Za-z0-9_]','',str(row[1]).lower().strip()))
    tweets_20220802.append(' ' + row[2].lower() + ' ')

final_20220802 = []
tweets_20220802 = [t.split('@') for t in tweets_20220802] #splits each tweet along @s
for n,chunk in enumerate(tweets_20220802):
    ment_users = [t[:re.search('[^A-Za-z0-9_]',t).start()].lower().strip() for t in chunk if re.search('[^A-Za-z0-9_]',t) is not None]
    final_20220802.extend([[authors_20220802[n],name] for name in ment_users if len(name.strip()) > 0])
outfile = '_edgelist_20220802.csv'
save_csv(outfile,final_20220802)
top_communities_20220802 = tsm.get_top_communities(final_20220802)
nodes_data_20220802 = top_communities_20220802.node_list
calc_ei(nodes_data_20220802, final_20220802)
# Out:
# Data saved to file "_edgelist_20220802.csv".
# Data loaded.
# Non-directed network created.
# Community partition complete.
# Total n of communities: 168
# Modularity: 0.84
# Community analysis complete. The top 10 communities in this network account for 70.3 % of all nodes.
# And 73.97 % of all edges.
# Calculating EI indices using *weighted* edges.
#
# Data loaded.
# Data loaded.
# ***EI indices***
#
# Community	EI index
# 0	-0.756
# 11	-0.704
# 17	-0.61
# 3	-0.914
# 30	-0.701
# 5	-0.598
# 6	-0.898
# 7	-0.742
# 8	-0.871
# 9	-0.728
# Mean EI:	 -0.752
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 6	634	0.949	0.051	0.0	0.051
#
# 7-r	0.019
# 5-r	0.021
# 9-r	0.001
# 8-r	0.001
# 11-r	0.003
# 17-r	0.003
# 30-r	0.001
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 3	252	0.957	0.039	0.004	0.036
#
# 0-s	0.004
# 0-r	0.039
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 7	217	0.871	0.077	0.052	0.024
#
# 6-s	0.052
# 0-r	0.004
# 5-r	0.012
# 9-r	0.02
# 11-r	0.02
# 17-r	0.012
# 30-r	0.008
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 0	142	0.878	0.004	0.118	-0.114
#
# 3-s	0.043
# 3-r	0.004
# 7-s	0.004
# 5-s	0.071
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 5	120	0.799	0.092	0.109	-0.017
#
# 6-s	0.061
# 7-s	0.013
# 0-r	0.079
# 9-s	0.013
# 11-s	0.004
# 17-s	0.009
# 30-s	0.009
# 30-r	0.013
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 9	90	0.864	0.078	0.058	0.019
#
# 6-s	0.01
# 7-s	0.049
# 5-r	0.029
# 8-r	0.01
# 11-r	0.01
# 17-r	0.019
# 30-r	0.01
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 8	87	0.935	0.022	0.043	-0.022
#
# 6-s	0.011
# 9-s	0.011
# 17-s	0.011
# 17-r	0.022
# 30-s	0.011
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 11	69	0.852	0.037	0.111	-0.074
#
# 6-s	0.025
# 7-s	0.062
# 5-r	0.012
# 9-s	0.012
# 17-s	0.012
# 17-r	0.025
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 17	63	0.805	0.052	0.143	-0.091
#
# 6-s	0.026
# 7-s	0.039
# 5-r	0.026
# 9-s	0.026
# 8-s	0.026
# 8-r	0.013
# 11-s	0.026
# 11-r	0.013
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 30	56	0.851	0.045	0.104	-0.06
#
# 6-s	0.015
# 7-s	0.03
# 5-s	0.045
# 5-r	0.03
# 9-s	0.015
# 8-r	0.015

# %%
#20220803

f = open('data/processed/tweets_20220803_notverified_freelon.csv','r',encoding = 'utf-8',errors = 'replace')
csvreader_20220803 = csv.reader(f)
authors_20220803 = []
tweets_20220803 = []
for row in csvreader_20220803:
    authors_20220803.append(re.sub('[^A-Za-z0-9_]','',str(row[1]).lower().strip()))
    tweets_20220803.append(' ' + row[2].lower() + ' ')

final_20220803 = []
tweets_20220803 = [t.split('@') for t in tweets_20220803] #splits each tweet along @s
for n,chunk in enumerate(tweets_20220803):
    ment_users = [t[:re.search('[^A-Za-z0-9_]',t).start()].lower().strip() for t in chunk if re.search('[^A-Za-z0-9_]',t) is not None]
    final_20220803.extend([[authors_20220803[n],name] for name in ment_users if len(name.strip()) > 0])
outfile = '_edgelist_20220803.csv'
save_csv(outfile,final_20220803)
top_communities_20220803 = tsm.get_top_communities(final_20220803)
nodes_data_20220803 = top_communities_20220803.node_list
calc_ei(nodes_data_20220803, final_20220803)
# Out:
# Data saved to file "_edgelist_20220803.csv".
# Data loaded.
# Non-directed network created.
# Community partition complete.
# Total n of communities: 159
# Modularity: 0.79
# Community analysis complete. The top 10 communities in this network account for 78.48 % of all nodes.
# And 79.06 % of all edges.
# Calculating EI indices using *weighted* edges.
#
# Data loaded.
# Data loaded.
# ***EI indices***
#
# Community	EI index
# 0	-0.875
# 1	-0.777
# 15	-0.918
# 18	-0.768
# 22	-0.55
# 37	-0.698
# 4	-0.823
# 46	-0.759
# 5	-0.674
# 60	-0.497
# Mean EI:	 -0.734
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 0	827	0.938	0.062	0.0	0.062
#
# 4-r	0.019
# 37-r	0.009
# 1-r	0.002
# 60-r	0.007
# 18-r	0.022
# 5-r	0.003
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 4	768	0.911	0.067	0.021	0.046
#
# 0-s	0.02
# 37-r	0.015
# 1-r	0.007
# 60-s	0.001
# 60-r	0.019
# 46-r	0.004
# 5-r	0.012
# 22-r	0.011
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 37	149	0.849	0.027	0.124	-0.097
#
# 0-s	0.031
# 4-s	0.05
# 1-s	0.004
# 1-r	0.008
# 60-s	0.019
# 60-r	0.012
# 18-r	0.004
# 46-s	0.004
# 46-r	0.004
# 5-s	0.004
# 22-s	0.012
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 1	144	0.888	0.043	0.069	-0.027
#
# 0-s	0.011
# 4-s	0.032
# 37-s	0.011
# 37-r	0.005
# 60-s	0.016
# 46-r	0.027
# 22-r	0.011
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 60	110	0.748	0.082	0.17	-0.088
#
# 0-s	0.041
# 4-s	0.109
# 4-r	0.007
# 37-s	0.02
# 37-r	0.034
# 1-r	0.02
# 46-r	0.007
# 22-r	0.014
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 18	93	0.884	0.0	0.116	-0.116
#
# 0-s	0.1
# 37-s	0.005
# 15-s	0.011
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 46	92	0.88	0.009	0.111	-0.102
#
# 4-s	0.028
# 37-s	0.009
# 37-r	0.009
# 1-s	0.046
# 60-s	0.009
# 15-s	0.009
# 22-s	0.009
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 5	75	0.837	0.022	0.141	-0.12
#
# 0-s	0.033
# 4-s	0.109
# 37-r	0.011
# 22-r	0.011
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 15	66	0.959	0.041	0.0	0.041
#
# 18-r	0.027
# 46-r	0.014
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 22	57	0.775	0.05	0.175	-0.125
#
# 4-s	0.113
# 37-r	0.037
# 1-s	0.025
# 60-s	0.025
# 46-r	0.013
# 5-s	0.013

# %%
#20220804

f = open('data/processed/tweets_20220804_notverified_freelon.csv','r',encoding = 'utf-8',errors = 'replace')
csvreader_20220804 = csv.reader(f)
authors_20220804 = []
tweets_20220804 = []
for row in csvreader_20220804:
    authors_20220804.append(re.sub('[^A-Za-z0-9_]','',str(row[1]).lower().strip()))
    tweets_20220804.append(' ' + row[2].lower() + ' ')

final_20220804 = []
tweets_20220804 = [t.split('@') for t in tweets_20220804] #splits each tweet along @s
for n,chunk in enumerate(tweets_20220804):
    ment_users = [t[:re.search('[^A-Za-z0-9_]',t).start()].lower().strip() for t in chunk if re.search('[^A-Za-z0-9_]',t) is not None]
    final_20220804.extend([[authors_20220804[n],name] for name in ment_users if len(name.strip()) > 0])
outfile = '_edgelist_20220804.csv'
save_csv(outfile,final_20220804)
top_communities_20220804 = tsm.get_top_communities(final_20220804)
nodes_data_20220804 = top_communities_20220804.node_list
calc_ei(nodes_data_20220804, final_20220804)
# Out:
# Data saved to file "_edgelist_20220804.csv".
# Data loaded.
# Non-directed network created.
# Community partition complete.
# Total n of communities: 161
# Modularity: 0.81
# Community analysis complete. The top 10 communities in this network account for 80.0 % of all nodes.
# And 79.83 % of all edges.
# Calculating EI indices using *weighted* edges.
#
# Data loaded.
# Data loaded.
# ***EI indices***
#
# Community	EI index
# 1	-0.987
# 10	-0.843
# 11	-0.622
# 12	-0.759
# 19	-0.607
# 2	-0.778
# 3	-0.588
# 30	-0.6
# 4	-0.676
# 8	-0.685
# Mean EI:	 -0.714
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 1	1252	0.994	0.006	0.0	0.006
#
# 10-r	0.006
# 11-r	0.001
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 12	607	0.88	0.119	0.001	0.118
#
# 2-r	0.02
# 4-r	0.029
# 10-r	0.003
# 8-r	0.013
# 3-r	0.017
# 11-r	0.015
# 30-s	0.001
# 30-r	0.013
# 19-r	0.009
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 2	357	0.889	0.077	0.035	0.042
#
# 12-s	0.035
# 4-r	0.022
# 8-r	0.02
# 3-r	0.017
# 11-r	0.007
# 30-r	0.002
# 19-r	0.007
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 4	239	0.838	0.06	0.102	-0.042
#
# 12-s	0.07
# 2-s	0.032
# 10-r	0.021
# 8-r	0.004
# 3-r	0.007
# 11-r	0.018
# 30-r	0.004
# 19-r	0.007
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 10	221	0.921	0.014	0.065	-0.051
#
# 1-s	0.016
# 12-s	0.005
# 4-s	0.014
# 8-s	0.007
# 8-r	0.002
# 11-s	0.019
# 11-r	0.009
# 30-s	0.002
# 19-s	0.002
# 19-r	0.002
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 8	149	0.842	0.02	0.138	-0.118
#
# 12-s	0.044
# 2-s	0.039
# 4-s	0.005
# 10-s	0.005
# 10-r	0.015
# 3-s	0.015
# 11-s	0.01
# 30-s	0.005
# 30-r	0.005
# 19-s	0.015
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 3	126	0.794	0.061	0.145	-0.085
#
# 12-s	0.073
# 2-s	0.042
# 4-s	0.012
# 8-r	0.018
# 11-s	0.006
# 11-r	0.012
# 30-s	0.006
# 30-r	0.024
# 19-s	0.006
# 19-r	0.006
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 11	116	0.811	0.06	0.129	-0.07
#
# 1-s	0.005
# 12-s	0.05
# 2-s	0.015
# 4-s	0.025
# 10-s	0.02
# 10-r	0.04
# 8-r	0.01
# 3-s	0.01
# 3-r	0.005
# 30-r	0.005
# 19-s	0.005
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 30	98	0.8	0.032	0.168	-0.136
#
# 12-s	0.072
# 12-r	0.008
# 2-s	0.008
# 4-s	0.008
# 10-r	0.008
# 8-s	0.008
# 8-r	0.008
# 3-s	0.032
# 3-r	0.008
# 11-s	0.008
# 19-s	0.032
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 19	95	0.803	0.085	0.111	-0.026
#
# 12-s	0.051
# 2-s	0.026
# 4-s	0.017
# 10-s	0.009
# 10-r	0.009
# 8-r	0.026
# 3-s	0.009
# 3-r	0.009
# 11-r	0.009
# 30-r	0.034

# %%
#20220805

f = open('data/processed/tweets_20220805_notverified_freelon.csv','r',encoding = 'utf-8',errors = 'replace')
csvreader_20220805 = csv.reader(f)
authors_20220805 = []
tweets_20220805 = []
for row in csvreader_20220805:
    authors_20220805.append(re.sub('[^A-Za-z0-9_]','',str(row[1]).lower().strip()))
    tweets_20220805.append(' ' + row[2].lower() + ' ')

final_20220805 = []
tweets_20220805 = [t.split('@') for t in tweets_20220805] #splits each tweet along @s
for n,chunk in enumerate(tweets_20220805):
    ment_users = [t[:re.search('[^A-Za-z0-9_]',t).start()].lower().strip() for t in chunk if re.search('[^A-Za-z0-9_]',t) is not None]
    final_20220805.extend([[authors_20220805[n],name] for name in ment_users if len(name.strip()) > 0])
outfile = '_edgelist_20220805.csv'
save_csv(outfile,final_20220805)
top_communities_20220805 = tsm.get_top_communities(final_20220805)
nodes_data_20220805 = top_communities_20220805.node_list
calc_ei(nodes_data_20220805, final_20220805)
# Out:
# Data saved to file "_edgelist_20220805.csv".
# Data loaded.
# Non-directed network created.
# Community partition complete.
# Total n of communities: 155
# Modularity: 0.86
# Community analysis complete. The top 10 communities in this network account for 71.47 % of all nodes.
# And 75.37 % of all edges.
# Calculating EI indices using *weighted* edges.
#
# Data loaded.
# Data loaded.
# ***EI indices***
#
# Community	EI index
# 0	-0.922
# 13	-0.977
# 2	-0.848
# 3	-0.842
# 33	-0.644
# 35	-0.227
# 5	-0.972
# 7	-0.894
# 9	-0.732
# 94	-0.654
# Mean EI:	 -0.771
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 0	497	0.961	0.037	0.002	0.035
#
# 3-r	0.002
# 33-r	0.002
# 7-r	0.002
# 94-s	0.002
# 94-r	0.025
# 35-r	0.002
# 2-r	0.004
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 5	497	0.986	0.014	0.0	0.014
#
# 9-r	0.014
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 3	152	0.921	0.073	0.006	0.067
#
# 0-s	0.006
# 33-r	0.012
# 7-r	0.018
# 94-r	0.018
# 35-r	0.018
# 2-r	0.006
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 33	124	0.822	0.046	0.132	-0.087
#
# 0-s	0.005
# 3-s	0.009
# 9-s	0.027
# 9-r	0.041
# 35-s	0.091
# 35-r	0.005
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 9	115	0.866	0.02	0.114	-0.093
#
# 5-s	0.018
# 33-s	0.023
# 33-r	0.015
# 35-s	0.073
# 35-r	0.005
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 7	103	0.947	0.018	0.035	-0.018
#
# 0-s	0.009
# 3-s	0.027
# 2-r	0.018
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 13	88	0.989	0.011	0.0	0.011
#
# 35-r	0.011
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 94	87	0.827	0.019	0.154	-0.135
#
# 0-s	0.125
# 0-r	0.01
# 3-s	0.029
# 2-r	0.01
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 35	86	0.613	0.333	0.053	0.28
#
# 0-s	0.007
# 3-s	0.02
# 33-s	0.007
# 33-r	0.133
# 9-s	0.013
# 9-r	0.193
# 13-s	0.007
# 2-r	0.007
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 2	85	0.924	0.0	0.076	-0.076
#
# 0-s	0.022
# 3-s	0.011
# 7-s	0.022
# 94-s	0.011
# 35-s	0.011

# %%
#20220806

f = open('data/processed/tweets_20220806_notverified_freelon.csv','r',encoding = 'utf-8',errors = 'replace')
csvreader_20220806 = csv.reader(f)
authors_20220806 = []
tweets_20220806 = []
for row in csvreader_20220806:
    authors_20220806.append(re.sub('[^A-Za-z0-9_]','',str(row[1]).lower().strip()))
    tweets_20220806.append(' ' + row[2].lower() + ' ')

final_20220806 = []
tweets_20220806 = [t.split('@') for t in tweets_20220806] #splits each tweet along @s
for n,chunk in enumerate(tweets_20220806):
    ment_users = [t[:re.search('[^A-Za-z0-9_]',t).start()].lower().strip() for t in chunk if re.search('[^A-Za-z0-9_]',t) is not None]
    final_20220806.extend([[authors_20220806[n],name] for name in ment_users if len(name.strip()) > 0])
outfile = '_edgelist_20220806.csv'
save_csv(outfile,final_20220806)
top_communities_20220806 = tsm.get_top_communities(final_20220806)
nodes_data_20220806 = top_communities_20220806.node_list
calc_ei(nodes_data_20220806, final_20220806)
# Out:
# Data saved to file "_edgelist_20220806.csv".
# Data loaded.
# Non-directed network created.
# Community partition complete.
# Total n of communities: 157
# Modularity: 0.89
# Community analysis complete. The top 10 communities in this network account for 62.68 % of all nodes.
# And 65.81 % of all edges.
# Calculating EI indices using *weighted* edges.
#
# Data loaded.
# Data loaded.
# ***EI indices***
#
# Community	EI index
# 1	-0.903
# 11	-0.964
# 17	-1.0
# 19	-0.831
# 2	-0.865
# 20	-0.792
# 30	-0.825
# 4	-0.834
# 5	-0.982
# 63	-0.97
# Mean EI:	 -0.897
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 2	403	0.933	0.067	0.0	0.067
#
# 19-r	0.03
# 4-r	0.023
# 30-r	0.005
# 1-r	0.007
# 20-r	0.002
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 19	161	0.915	0.011	0.073	-0.062
#
# 2-s	0.073
# 4-r	0.011
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 11	160	0.982	0.018	0.0	0.018
#
# 5-r	0.006
# 63-r	0.012
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 4	127	0.917	0.0	0.083	-0.083
#
# 2-s	0.069
# 19-s	0.014
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 5	78	0.991	0.0	0.009	-0.009
#
# 11-s	0.009
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 30	74	0.913	0.029	0.058	-0.029
#
# 2-s	0.019
# 63-r	0.01
# 20-s	0.039
# 20-r	0.019
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 63	73	0.985	0.0	0.015	-0.015
#
# 11-s	0.008
# 30-s	0.004
# 20-s	0.004
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 1	60	0.952	0.0	0.048	-0.048
#
# 2-s	0.048
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 20	59	0.896	0.065	0.039	0.026
#
# 2-s	0.013
# 30-s	0.026
# 30-r	0.052
# 63-r	0.013
#
# Community	Size	Internal	Received	Sent	Received - Sent
# 17	53	1.0	0.0	0.0	0.0

# %%
#20220807

f = open('data/processed/tweets_20220807_notverified_freelon.csv','r',encoding = 'utf-8',errors = 'replace')
csvreader_20220807 = csv.reader(f)
authors_20220807 = []
tweets_20220807 = []
for row in csvreader_20220807:
    authors_20220807.append(re.sub('[^A-Za-z0-9_]','',str(row[1]).lower().strip()))
    tweets_20220807.append(' ' + row[2].lower() + ' ')

final_20220807 = []
tweets_20220807 = [t.split('@') for t in tweets_20220807] #splits each tweet along @s
for n,chunk in enumerate(tweets_20220807):
    ment_users = [t[:re.search('[^A-Za-z0-9_]',t).start()].lower().strip() for t in chunk if re.search('[^A-Za-z0-9_]',t) is not None]
    final_20220807.extend([[authors_20220807[n],name] for name in ment_users if len(name.strip()) > 0])
outfile = '_edgelist_20220807.csv'
save_csv(outfile,final_20220807)
top_communities_20220807 = tsm.get_top_communities(final_20220807)
nodes_data_20220807 = top_communities_20220807.node_list
calc_ei(nodes_data_20220807, final_20220807)
# Out:
# Data saved to file "_edgelist_20220807.csv".
# Data loaded.
# Non-directed network created.
# Community partition complete.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/6l/9sc4ys752w1_7xp_8yvrq3600000gn/T/ipykernel_72958/1472025516.py in <module>
#      16 outfile = '_edgelist_20220807.csv'
#      17 save_csv(outfile,final_20220807)
# ---> 18 top_communities_20220807 = tsm.get_top_communities(final_20220807)
#      19 nodes_data_20220807 = top_communities_20220807.node_list
#      20 calc_ei(nodes_data_20220807, final_20220807)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tsm/tsm.py in get_top_communities(edges_data, top_comm, randomize, prominence_metric, save_prefix)
#     246         del i[0]
#     247
# --> 248     mod = round(community.modularity(allmods,non_dir),2)
#     249     node_propor = round((len(filtered_nodes)/len(allmods))*100,2)
#     250     edge_propor = round((len(top_edge_list)/len(edge_list))*100,2)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/community/community_louvain.py in modularity(partition, graph, weight)
#     141     links = graph.size(weight=weight)
#     142     if links == 0:
# --> 143         raise ValueError("A graph without link has an undefined modularity")
#     144
#     145     for node in graph:
#
# ValueError: A graph without link has an undefined modularity
